# %%
# In this notebook:
# Clean the summary and review text fields of all game reviews
# Save to csv for easy access

# %%
import numpy as np
import pandas as pd
import json

# %%
pd.set_option('display.max_colwidth', 100)

# %%
# works for full version, however load time is slow
# method would be problematic if too many subsets...
# i.e. list in column helpful

gorig = pd.read_json('Video_Games_5.json', lines=True)

print(f'Dataset shape is {gorig.shape}')

gorig.head()
# Out:
# Dataset shape is (231780, 9)
#          asin  helpful  overall  \
# 0  0700099867  [8, 12]        1
# 1  0700099867   [0, 0]        4
# 2  0700099867   [0, 0]        1
# 3  0700099867  [7, 10]        3
# 4  0700099867   [2, 2]        4
#
#                                           reviewText   reviewTime  \
# 0  Installing the game was a struggle (because of...   07 9, 2012
# 1  If you like rally cars get this game you will ...  06 30, 2013
# 2  1st shipment received a book instead of the ga...  06 28, 2014
# 3  I got this version instead of the PS3 version,...  09 14, 2011
# 4  I had Dirt 2 on Xbox 360 and it was an okay ga...  06 14, 2011
#
#        reviewerID                        reviewerName  \
# 0  A2HD75EMZR8QLN                                 123
# 1  A3UR8NLLY1ZHCX  Alejandro Henao "Electronic Junky"
# 2  A1INA0F5CWW3J4          Amazon Shopper "Mr.Repsol"
# 3  A1DLMTOTHQ4AST                            ampgreen
# 4  A361M14PU2GUEG        Angry Ryan "Ryan A. Forrest"
#
#                                            summary  unixReviewTime
# 0         Pay to unlock content? I don't think so.      1341792000
# 1                                  Good rally game      1372550400
# 2                                        Wrong key      1403913600
# 3  awesome game, if it did not crash frequently !!      1315958400
# 4                                           DIRT 3      1308009600

# %%
print(f"overall has unique values of: {gorig['overall'].unique()}")
# Out:
# overall has unique values of: [1 4 3 5 2]

# %% [markdown]
# ## Preprocess text

# %%
from nltk.corpus import stopwords

# %%
gorig['cleansum'] = gorig['summary']
gorig['cleantxt'] = gorig['reviewText']

gorig.head(2)
# Out:
#          asin  helpful  overall  \
# 0  0700099867  [8, 12]        1
# 1  0700099867   [0, 0]        4
#
#                                           reviewText   reviewTime  \
# 0  Installing the game was a struggle (because of...   07 9, 2012
# 1  If you like rally cars get this game you will ...  06 30, 2013
#
#        reviewerID                        reviewerName  \
# 0  A2HD75EMZR8QLN                                 123
# 1  A3UR8NLLY1ZHCX  Alejandro Henao "Electronic Junky"
#
#                                     summary  unixReviewTime  \
# 0  Pay to unlock content? I don't think so.      1341792000
# 1                           Good rally game      1372550400
#
#                                    cleansum  \
# 0  Pay to unlock content? I don't think so.
# 1                           Good rally game
#
#                                             cleantxt
# 0  Installing the game was a struggle (because of...
# 1  If you like rally cars get this game you will ...

# %%
gorig['cleansum'] = gorig['cleansum'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))
gorig['cleantxt'] = gorig['cleantxt'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

gorig[['cleansum', 'cleantxt']].head(2)
# Out:
#                                    cleansum  \
# 0  pay to unlock content? i don't think so.
# 1                           good rally game
#
#                                             cleantxt
# 0  installing the game was a struggle (because of...
# 1  if you like rally cars get this game you will ...

# %%
def remove_sym(x):
    new_str = ''
    for c in x:
        if (c.isalnum() == False) & (c != ' '):
            pass
        else:
            new_str += c
    return new_str

# %%
gorig['cleansum'] = gorig['cleansum'].apply(remove_sym)
gorig['cleantxt'] = gorig['cleantxt'].apply(remove_sym)

gorig[['cleansum', 'cleantxt']].head(2)
# Out:
#                                 cleansum  \
# 0  pay to unlock content i dont think so
# 1                        good rally game
#
#                                                                                               cleantxt
# 0  installing the game was a struggle because of games for windows live bugssome championship races...
# 1  if you like rally cars get this game you will have funit is more oriented to 34european market34...

# %%
def remove_num(x):
    new_str = ''
    for c in x:
        if (c.isnumeric() == True):
            pass
        else:
            new_str += c
    return new_str

# %%
gorig['cleansum'] = gorig['cleansum'].apply(remove_num)
gorig['cleantxt'] = gorig['cleantxt'].apply(remove_num)

gorig[['cleansum', 'cleantxt']].head(2)
# Out:
#                                 cleansum  \
# 0  pay to unlock content i dont think so
# 1                        good rally game
#
#                                                                                               cleantxt
# 0  installing the game was a struggle because of games for windows live bugssome championship races...
# 1  if you like rally cars get this game you will have funit is more oriented to european market sin...

# %%
stop = stopwords.words('english')

gorig['cleansum'] = gorig['cleansum'].apply(lambda x: " ".join(x for x in str(x).split() if x not in stop))
gorig['cleantxt'] = gorig['cleantxt'].apply(lambda x: " ".join(x for x in str(x).split() if x not in stop))

gorig[['cleansum', 'cleantxt']].head(2)
# Out:
#                         cleansum  \
# 0  pay unlock content dont think
# 1                good rally game
#
#                                                                                               cleantxt
# 0  installing game struggle games windows live bugssome championship races cars unlocked buying add...
# 1  like rally cars get game funit oriented european market since america isnt huge rally fan party ...

# %%
sum_words = pd.Series(' '.join(gorig['cleansum']).split()).value_counts()
txt_words = pd.Series(' '.join(gorig['cleantxt']).split()).value_counts()

print(f'Summary unique words: {len(sum_words)}')
print(f'Review text unique words: {len(txt_words)}')
# Out:
# Summary unique words: 32172
# Review text unique words: 541498

# %%
sum_rare = sum_words[(sum_words <= 3)]
txt_rare = txt_words[(txt_words <= 4)]

print(f'Rare summary word count: {len(sum_rare)}')
print(f'Rare review text word count: {len(txt_rare)}')
# Out:
# Rare summary word count: 23554
# Rare review text word count: 471180

# %%
gorig['cleansum'] = gorig['cleansum'].apply(lambda x: " ".join(x for x in str(x).split() if x not in sum_rare))
gorig['cleantxt'] = gorig['cleantxt'].apply(lambda x: " ".join(x for x in str(x).split() if x not in txt_rare))

gorig[['cleansum', 'cleantxt']].head(5)
# Out:
#                         cleansum  \
# 0  pay unlock content dont think
# 1                good rally game
# 2                      wrong key
# 3  awesome game crash frequently
# 4                           dirt
#
#                                                                                               cleantxt
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 1  like rally cars get game funit oriented european market since america isnt huge rally fan party ...
# 2  st shipment received book instead shipment got fake one game arrived wrong key inside sealed box...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...

# %%
try:
    gorig.to_csv('amazon_games_all.csv',mode='x')
    print('File saved')
    
except:
    print('File exists')
# Out:
# File saved

# %%
gclean = gorig[['asin','helpful','overall','cleansum','cleantxt']]

gclean.head()
# Out:
#          asin  helpful  overall                       cleansum  \
# 0  0700099867  [8, 12]        1  pay unlock content dont think
# 1  0700099867   [0, 0]        4                good rally game
# 2  0700099867   [0, 0]        1                      wrong key
# 3  0700099867  [7, 10]        3  awesome game crash frequently
# 4  0700099867   [2, 2]        4                           dirt
#
#                                                                                               cleantxt
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 1  like rally cars get game funit oriented european market since america isnt huge rally fan party ...
# 2  st shipment received book instead shipment got fake one game arrived wrong key inside sealed box...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...

# %%
def ret_first(x):
    return x[0]

def ret_second(x):
    return x[1]

# %%
gclean['h_first'] = gclean['helpful'].apply(ret_first)
gclean['h_second'] = gclean['helpful'].apply(ret_second)

gclean.head()
# Out:
# C:\Users\liamk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\liamk\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          asin  helpful  overall                       cleansum  \
# 0  0700099867  [8, 12]        1  pay unlock content dont think
# 1  0700099867   [0, 0]        4                good rally game
# 2  0700099867   [0, 0]        1                      wrong key
# 3  0700099867  [7, 10]        3  awesome game crash frequently
# 4  0700099867   [2, 2]        4                           dirt
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 1  like rally cars get game funit oriented european market since america isnt huge rally fan party ...
# 2  st shipment received book instead shipment got fake one game arrived wrong key inside sealed box...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...
#
#    h_first  h_second
# 0        8        12
# 1        0         0
# 2        0         0
# 3        7        10
# 4        2         2

# %%
gclean = gclean[gclean['h_second'] != 0]

print(f'Removing 0 ratings, gclean shape is {gclean.shape}')

gclean.head(2)
# Out:
# Removing 0 ratings, gclean shape is (139855, 7)
#          asin  helpful  overall                       cleansum  \
# 0  0700099867  [8, 12]        1  pay unlock content dont think
# 3  0700099867  [7, 10]        3  awesome game crash frequently
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
#
#    h_first  h_second
# 0        8        12
# 3        7        10

# %%
gclean['helppercent'] = gclean['h_first'] / gclean['h_second']

gclean.head(5)
# Out:
#          asin   helpful  overall                          cleansum  \
# 0  0700099867   [8, 12]        1     pay unlock content dont think
# 3  0700099867   [7, 10]        3     awesome game crash frequently
# 4  0700099867    [2, 2]        4                              dirt
# 6  0700099867  [11, 13]        5                step dirt terrific
# 7  0700099867    [1, 4]        1  crash correct name aka microsoft
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...
# 6  loved playing dirt thought graphics good purchased dirt addition otherand graphics absolutely go...
# 7  cant tell piece dog game like everything else microsoft makes doesnt work going take cue apple m...
#
#    h_first  h_second  helppercent
# 0        8        12     0.666667
# 3        7        10     0.700000
# 4        2         2     1.000000
# 6       11        13     0.846154
# 7        1         4     0.250000

# %%
gclean = gclean[gclean['helppercent'] >= 0.50]

print(f'With helful rating >= 50%, gclean shape is {gclean.shape}')

gclean.head(5)
# Out:
# With helful rating >= 50%, gclean shape is (98144, 8)
#          asin   helpful  overall                       cleansum  \
# 0  0700099867   [8, 12]        1  pay unlock content dont think
# 3  0700099867   [7, 10]        3  awesome game crash frequently
# 4  0700099867    [2, 2]        4                           dirt
# 6  0700099867  [11, 13]        5             step dirt terrific
# 9  0700099867    [1, 1]        2           couldnt get one work
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...
# 6  loved playing dirt thought graphics good purchased dirt addition otherand graphics absolutely go...
# 9  still havent figured one everything instructed game never installed strange since dont like rate...
#
#    h_first  h_second  helppercent
# 0        8        12     0.666667
# 3        7        10     0.700000
# 4        2         2     1.000000
# 6       11        13     0.846154
# 9        1         1     1.000000

# %%
gclean.pop('helpful')
gclean.pop('h_first')
gclean.pop('h_second')

gclean.head()
# Out:
#          asin  overall                       cleansum  \
# 0  0700099867        1  pay unlock content dont think
# 3  0700099867        3  awesome game crash frequently
# 4  0700099867        4                           dirt
# 6  0700099867        5             step dirt terrific
# 9  0700099867        2           couldnt get one work
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
# 4  dirt xbox okay game started playing games laptop bought new games build collection game fun play...
# 6  loved playing dirt thought graphics good purchased dirt addition otherand graphics absolutely go...
# 9  still havent figured one everything instructed game never installed strange since dont like rate...
#
#    helppercent
# 0     0.666667
# 3     0.700000
# 4     1.000000
# 6     0.846154
# 9     1.000000

# %%
gclean['cleanboth'] = gclean['cleansum'] + ' ' + gclean['cleantxt']

gclean.head(2)
# Out:
#          asin  overall                       cleansum  \
# 0  0700099867        1  pay unlock content dont think
# 3  0700099867        3  awesome game crash frequently
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
#
#    helppercent  \
# 0     0.666667
# 3     0.700000
#
#                                                                                              cleanboth
# 0  pay unlock content dont think installing game struggle games windows live championship races car...
# 3  awesome game crash frequently got version instead ps version turned mistake console versions gam...

# %%
gclean = gclean[['asin', 'helppercent', 'overall', 'cleansum', 'cleantxt', 'cleanboth']]

gclean.head(2)
# Out:
#          asin  helppercent  overall                       cleansum  \
# 0  0700099867     0.666667        1  pay unlock content dont think
# 3  0700099867     0.700000        3  awesome game crash frequently
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 3  got version instead ps version turned mistake console versions games look percent good pc versio...
#
#                                                                                              cleanboth
# 0  pay unlock content dont think installing game struggle games windows live championship races car...
# 3  awesome game crash frequently got version instead ps version turned mistake console versions gam...

# %%
gclean.reset_index(inplace=True)

gclean.head(2)
# Out:
#    index        asin  helppercent  overall                       cleansum  \
# 0      0  0700099867     0.666667        1  pay unlock content dont think
# 1      3  0700099867     0.700000        3  awesome game crash frequently
#
#                                                                                               cleantxt  \
# 0  installing game struggle games windows live championship races cars unlocked buying addon game p...
# 1  got version instead ps version turned mistake console versions games look percent good pc versio...
#
#                                                                                              cleanboth
# 0  pay unlock content dont think installing game struggle games windows live championship races car...
# 1  awesome game crash frequently got version instead ps version turned mistake console versions gam...

# %%
try:
    gclean.to_csv('amazon_games_clean.csv',mode='x')
    print('File saved')
    
except:
    print('File exists')
# Out:
# File saved

# %%
# this concludes pt 2
