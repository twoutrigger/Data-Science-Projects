# %%
# In this notebook:

# Premise: Games titles are not labeled in the dataset,
# title identification is also difficult by simply reading reviews, 
# so I deploy TFIDF (ngrams 1 & 2) to attempt to guess the game title

# Result: Max TFIDF 2-ngrams was effective at identifying game titles

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 100)

# %%
gorig = pd.read_csv('amazon_games_clean.csv',index_col=0)

print(f'Dataset has {gorig.shape[0]} samples')

gorig.head(5)
# Out:
# Dataset has 98144 samples
#          asin  helppercent  overall                       cleansum  \
# 0  0700099867     0.666667        1  pay unlock content dont think
# 1  0700099867     0.700000        3  awesome game crash frequently
# 2  0700099867     1.000000        4                           dirt
# 3  0700099867     0.846154        5             step dirt terrific
# 4  0700099867     1.000000        2           couldnt get one work
#
#                                                                                               cleantxt  \
# 0  instal game wa struggle game window live championship race car unlock buy addon game pay nearly ...
# 1  get version instead p version turn mistake console version game look percent good pc version dea...
# 2  dirt xbox wa okay game start play game laptop buy new game build collection game fun play much b...
# 3  love play dirt think graphic good purchase dirt addition otherand graphic absolutely gorgeous li...
# 4  still havent figure one everything instruct game never instal strange since dont like rate somet...
#
#                                                                                              cleanboth
# 0  pay unlock content dont think instal game wa struggle game window live championship race car unl...
# 1  awesome game crash frequently get version instead p version turn mistake console version game lo...
# 2  dirt dirt xbox wa okay game start play game laptop buy new game build collection game fun play m...
# 3  step dirt terrific love play dirt think graphic good purchase dirt addition otherand graphic abs...
# 4  couldnt get one work still havent figure one everything instruct game never instal strange since...

# %%
# we see some null values in cleansum & cleantxt
gorig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98144 entries, 0 to 98143
# Data columns (total 6 columns):
# asin           98144 non-null object
# helppercent    98144 non-null float64
# overall        98144 non-null int64
# cleansum       97082 non-null object
# cleantxt       98110 non-null object
# cleanboth      98144 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.2+ MB

# %%
# forward fill with 'game' which wont affect TFIDF
gorig.fillna(value='game', inplace=True)

# %%
vc_asin = gorig['asin'].value_counts()
vc_asin = vc_asin[(vc_asin >= 50) & (vc_asin <= 52)]

print(f'Unique games with 50~52 reviews: {len(vc_asin)}')
# Out:
# Unique games with 50~52 reviews: 34

# %%
# this gives us a good population for visualization
gedit = gorig[gorig['asin'].isin(list(vc_asin.index))]
gedit.reset_index(drop=True, inplace=True)

print(f'Dataset size of 50~52 reviews games: {gedit.shape[0]}')
print(f"Dataset unique word size is: {len(pd.Series(' '.join(gedit['cleanboth']).split()).value_counts())}")
# Out:
# Dataset size of 50~52 reviews games: 1728
# Dataset unique word size is: 14262

# %% [markdown]
# ## TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf1 = TfidfVectorizer(max_features=50000, lowercase=True, analyzer='word',
                        stop_words = 'english', ngram_range=(1,1))
tf2 = TfidfVectorizer(max_features=500000, lowercase=True, analyzer='word',
                        stop_words = 'english', ngram_range=(2,2))

tfvec1 = tf1.fit_transform(gedit['cleanboth'])
tfvec2 = tf2.fit_transform(gedit['cleanboth'])

print(f'TFIDF 1 ngrams shape: {tfvec1.shape}')
print(f'TFIDF 2 ngrams shape: {tfvec2.shape}')
# Out:
# TFIDF 1 ngrams shape: (1728, 14071)
# TFIDF 2 ngrams shape: (1728, 165299)

# %% [markdown]
# ## Guessing game title

# %%
from collections import Counter

# %%
# Return 3 most common words with the highest TFIDF; 1 ngrams
# we see ok results that help us deduce the game title
vocab_lookup = {v:k for k,v in tf1.vocabulary_.items()}

for i in set(gedit['asin']):
    asin_unique = gedit[gedit['asin'] == i].index
    asin_tfidf = Counter([vocab_lookup[np.argmax(v)] for v in tfvec1[asin_unique]])
    print (f'Asin: {i}  1-ngrams Top 3: {asin_tfidf.most_common(3)}')
# Out:
# Asin: B0047THYWC  1-ngrams Top 3: [('origin', 8), ('dragon', 7), ('da', 5)]
# Asin: B0076ZQSFI  1-ngrams Top 3: [('gta', 8), ('crime', 3), ('mission', 3)]
# Asin: B00DC7G2W8  1-ngrams Top 3: [('kart', 13), ('wii', 6), ('battle', 3)]
# Asin: B00006IR62  1-ngrams Top 3: [('war', 5), ('jedi', 5), ('game', 4)]
# Asin: B000TI836G  1-ngrams Top 3: [('ops', 4), ('game', 3), ('moh', 3)]
# Asin: B0000C6EB4  1-ngrams Top 3: [('honor', 3), ('mohaa', 2), ('ww', 2)]
# Asin: B000B69E9G  1-ngrams Top 3: [('resident', 7), ('version', 4), ('leon', 4)]
# Asin: B00004YRQ9  1-ngrams Top 3: [('controller', 23), ('analog', 3), ('shock', 2)]
# Asin: B00005QEFD  1-ngrams Top 3: [('gamecube', 15), ('gc', 6), ('nintendo', 5)]
# Asin: B005C2D2MO  1-ngrams Top 3: [('dishonor', 3), ('game', 3), ('stealth', 3)]
# Asin: B000M17AVO  1-ngrams Top 3: [('remote', 26), ('button', 7), ('movie', 3)]
# Asin: B003O6JKLC  1-ngrams Top 3: [('xbox', 10), ('gb', 8), ('console', 2)]
# Asin: B004PAGJOC  1-ngrams Top 3: [('zombie', 20), ('game', 4), ('island', 4)]
# Asin: B00D4WTO1M  1-ngrams Top 3: [('cod', 7), ('duty', 3), ('battlefield', 2)]
# Asin: B000PS2XES  1-ngrams Top 3: [('steam', 7), ('portal', 5), ('episode', 5)]
# Asin: B00CXCCB64  1-ngrams Top 3: [('bf', 4), ('battlefield', 2), ('game', 2)]
# Asin: B002I0H2AG  1-ngrams Top 3: [('gear', 16), ('horde', 5), ('gow', 3)]
# Asin: B00000F1GM  1-ngrams Top 3: [('mario', 17), ('game', 2), ('super', 2)]
# Asin: B004NRN5DU  1-ngrams Top 3: [('soul', 9), ('game', 8), ('challenge', 1)]
# Asin: B00004UE0O  1-ngrams Top 3: [('creature', 9), ('god', 3), ('white', 3)]
# Asin: B003O6E67A  1-ngrams Top 3: [('resistance', 22), ('weapon', 3), ('fps', 3)]
# Asin: B00005ME6O  1-ngrams Top 3: [('hill', 15), ('silent', 4), ('game', 2)]
# Asin: B002I096AA  1-ngrams Top 3: [('nintendo', 4), ('dsi', 3), ('game', 2)]
# Asin: B002NN7AKU  1-ngrams Top 3: [('gow', 9), ('god', 8), ('game', 5)]
# Asin: B0087OZ5FG  1-ngrams Top 3: [('headset', 18), ('headphone', 10), ('crack', 1)]
# Asin: B00000DMB3  1-ngrams Top 3: [('zelda', 7), ('link', 5), ('ocarina', 4)]
# Asin: B007W8S2MG  1-ngrams Top 3: [('persona', 14), ('vita', 8), ('game', 4)]
# Asin: B001COQW14  1-ngrams Top 3: [('wii', 16), ('sport', 9), ('family', 2)]
# Asin: B000P46NMA  1-ngrams Top 3: [('assassin', 5), ('assassination', 4), ('game', 3)]
# Asin: B004FYJFNA  1-ngrams Top 3: [('mass', 8), ('end', 7), ('cover', 2)]
# Asin: B000B9RI14  1-ngrams Top 3: [('point', 9), ('code', 8), ('card', 5)]
# Asin: B000X1PE16  1-ngrams Top 3: [('space', 9), ('isaac', 2), ('scare', 2)]
# Asin: B00EFFW0HC  1-ngrams Top 3: [('bf', 7), ('battlefield', 6), ('freeze', 4)]
# Asin: B001COV1CY  1-ngrams Top 3: [('mag', 9), ('squad', 3), ('online', 2)]

# %%
# Return 3 most common words with the highest TFIDF; 2 ngrams
# we see great results that often guesses the title in the first suggestion
vocab_lookup = {v:k for k,v in tf2.vocabulary_.items()}

for i in set(gedit['asin']):
    asin_unique = gedit[gedit['asin'] == i].index
    asin_tfidf = Counter([vocab_lookup[np.argmax(v)] for v in tfvec2[asin_unique]])
    print (f'Asin: {i}  2-ngrams Top 3: {asin_tfidf.most_common(3)}')
# Out:
# Asin: B0047THYWC  2-ngrams Top 3: [('dragon age', 15), ('wa bite', 1), ('believe bother', 1)]
# Asin: B0076ZQSFI  2-ngrams Top 3: [('hong kong', 5), ('true crime', 3), ('sleep dog', 3)]
# Asin: B00DC7G2W8  2-ngrams Top 3: [('mario kart', 17), ('battle mode', 2), ('blue shell', 2)]
# Asin: B00006IR62  2-ngrams Top 3: [('star war', 16), ('adventureyou choose', 1), ('act review', 1)]
# Asin: B000TI836G  2-ngrams Top 3: [('black ops', 4), ('single player', 3), ('medal honor', 2)]
# Asin: B0000C6EB4  2-ngrams Top 3: [('medal honor', 5), ('person shooter', 2), ('ability player', 1)]
# Asin: B000B69E9G  2-ngrams Top 3: [('resident evil', 11), ('gamecube version', 2), ('biggest bait', 1)]
# Asin: B00004YRQ9  2-ngrams Top 3: [('dual shock', 5), ('great controller', 2), ('double edge', 1)]
# Asin: B00005QEFD  2-ngrams Top 3: [('memory card', 3), ('nintendo ha', 2), ('game boy', 2)]
# Asin: B005C2D2MO  2-ngrams Top 3: [('play style', 2), ('conclusion finish', 1), ('feel connect', 1)]
# Asin: B000M17AVO  2-ngrams Top 3: [('stop button', 4), ('power button', 2), ('remote control', 1)]
# Asin: B003O6JKLC  2-ngrams Top 3: [('hard drive', 5), ('new xbox', 2), ('gb console', 2)]
# Asin: B004PAGJOC  2-ngrams Top 3: [('dead island', 8), ('zombie game', 2), ('weapon degradation', 1)]
# Asin: B00D4WTO1M  2-ngrams Top 3: [('lag compensation', 1), ('bo game', 1), ('atleast far', 1)]
# Asin: B000PS2XES  2-ngrams Top 3: [('half life', 8), ('team fortress', 2), ('orange box', 2)]
# Asin: B00CXCCB64  2-ngrams Top 3: [('join game', 1), ('lag lag', 1), ('bf campaign', 1)]
# Asin: B002I0H2AG  2-ngrams Top 3: [('horde mode', 3), ('gear war', 3), ('gear game', 2)]
# Asin: B00000F1GM  2-ngrams Top 3: [('super mario', 10), ('mario ha', 2), ('paint mario', 1)]
# Asin: B004NRN5DU  2-ngrams Top 3: [('dark soul', 6), ('wa bite', 1), ('accomplishment good', 1)]
# Asin: B00004UE0O  2-ngrams Top 3: [('black white', 5), ('wait patch', 1), ('village impress', 1)]
# Asin: B003O6E67A  2-ngrams Top 3: [('new york', 2), ('code redeem', 1), ('campaign mode', 1)]
# Asin: B00005ME6O  2-ngrams Top 3: [('silent hill', 25), ('mystery solve', 1), ('access certain', 1)]
# Asin: B002I096AA  2-ngrams Top 3: [('amaze buy', 1), ('dsi originally', 1), ('game play', 1)]
# Asin: B002NN7AKU  2-ngrams Top 3: [('god war', 20), ('basic attack', 1), ('absolute delve', 1)]
# Asin: B0087OZ5FG  2-ngrams Top 3: [('bass break', 1), ('annoy depend', 1), ('abuse careful', 1)]
# Asin: B00000DMB3  2-ngrams Top 3: [('ocarina time', 5), ('legend zelda', 3), ('zelda game', 3)]
# Asin: B007W8S2MG  2-ngrams Top 3: [('social link', 3), ('vita buy', 2), ('conversation social', 1)]
# Asin: B001COQW14  2-ngrams Top 3: [('wii sport', 10), ('sport resort', 4), ('absolutely best', 1)]
# Asin: B000P46NMA  2-ngrams Top 3: [('assassin creed', 4), ('look cool', 1), ('assasin mission', 1)]
# Asin: B004FYJFNA  2-ngrams Top 3: [('mass effect', 13), ('wa hugely', 1), ('bite linear', 1)]
# Asin: B000B9RI14  2-ngrams Top 3: [('point card', 2), ('credit card', 2), ('online code', 2)]
# Asin: B000X1PE16  2-ngrams Top 3: [('dead space', 15), ('game hand', 1), ('advice yopu', 1)]
# Asin: B00EFFW0HC  2-ngrams Top 3: [('battlefield begin', 1), ('campaign order', 1), ('ok best', 1)]
# Asin: B001COV1CY  2-ngrams Top 3: [('squad leader', 3), ('jan game', 1), ('game domination', 1)]

# %% [markdown]
# ## Verification

# %%
# Example of correct guessing; Game is likely Dragon Age
# High 1st max TFIDF count relative to 2nd/ 3rd tends to be a good guess
gedit[gedit['asin'] == 'B0047THYWC'][:15]
# Out:
#             asin  helppercent  overall  \
# 1119  B0047THYWC     0.714286        1
# 1120  B0047THYWC     0.833333        3
# 1121  B0047THYWC     0.615385        1
# 1122  B0047THYWC     0.600000        3
# 1123  B0047THYWC     1.000000        5
# 1124  B0047THYWC     0.625000        3
# 1125  B0047THYWC     0.780488        3
# 1126  B0047THYWC     1.000000        3
# 1127  B0047THYWC     0.583333        4
# 1128  B0047THYWC     0.932914        2
# 1129  B0047THYWC     0.666667        3
# 1130  B0047THYWC     0.500000        3
# 1131  B0047THYWC     0.600000        4
# 1132  B0047THYWC     1.000000        3
# 1133  B0047THYWC     0.500000        4
#
#                                                          cleansum  \
# 1119           every step forward bioware take two step backwards
# 1120                                                   bad origin
# 1121                                                   disappoint
# 1122                                                  take rp rpg
# 1123                               go annoy first absolutely love
# 1124                                           lazy sloppy sequel
# 1125                                            rpg pc go console
# 1126                                           fairly decent game
# 1127                                       new approach help hurt
# 1128  time mediocre usually painfully average handful good moment
# 1129                  love dragon age universe little disapointed
# 1130                                           dragon age average
# 1131                              enjoyable expect disappointment
# 1132                                                  expect game
# 1133                                             wish game better
#
#                                                                                                  cleantxt  \
# 1119  everyone go mass effect despite game dumbed mass title come second next dragon put game terrible...
# 1120  overall like game however cant help compare dragon age origin im afraid pale comparison dao wa o...
# 1121  cant believe even bother spend money expect first game apparently didnt learn youre fence wait g...
# 1122  dragon age classic rpg pretty much element could think make game worthwhile intrigue instance gi...
# 1123  find helpful list pc game enjoy heck begin find nod head say game good title review might helpfu...
# 1124  dragon age ii decent game next predecessor though shameful product slap face series gamers gener...
# 1125  agree review already game disappointment especially terrific leadin dragon age play rpgs since f...
# 1126  overall seem like average decent game however two significant problem battle scene first often h...
# 1127  dragon age doe really need introduction biowares fantasy mass effect counterpart make good appea...
# 1128  tldr crowd da isnt bad game per se rush often schizophrenic kind game want fan origin particular...
# 1129  first like say love dragon age universe love story warden dark spawn aswell story mages templar ...
# 1130  let start say dragon age bad game average game problem think bioware rpgs dont think average thi...
# 1131  dragon age wa good game predecessor wa great game comparison da still throw great roleplay choic...
# 1132  first one wa great game one much guess high expectation game world wa smaller story wa le epic p...
# 1133  despite negative review hear dragon age da still think wa great game delay purchase da long time...
#
#                                                                                                 cleanboth
# 1119  every step forward bioware take two step backwards everyone go mass effect despite game dumbed m...
# 1120  bad origin overall like game however cant help compare dragon age origin im afraid pale comparis...
# 1121  disappoint cant believe even bother spend money expect first game apparently didnt learn youre f...
# 1122  take rp rpg dragon age classic rpg pretty much element could think make game worthwhile intrigue...
# 1123  go annoy first absolutely love find helpful list pc game enjoy heck begin find nod head say game...
# 1124  lazy sloppy sequel dragon age ii decent game next predecessor though shameful product slap face ...
# 1125  rpg pc go console agree review already game disappointment especially terrific leadin dragon age...
# 1126  fairly decent game overall seem like average decent game however two significant problem battle ...
# 1127  new approach help hurt dragon age doe really need introduction biowares fantasy mass effect coun...
# 1128  time mediocre usually painfully average handful good moment tldr crowd da isnt bad game per se r...
# 1129  love dragon age universe little disapointed first like say love dragon age universe love story w...
# 1130  dragon age average let start say dragon age bad game average game problem think bioware rpgs don...
# 1131  enjoyable expect disappointment dragon age wa good game predecessor wa great game comparison da ...
# 1132  expect game first one wa great game one much guess high expectation game world wa smaller story ...
# 1133  wish game better despite negative review hear dragon age da still think wa great game delay purc...

# %%
# Example of weak guessing; Game is likely Sleeping Dog
# Low and leveled 1st/ 2nd/ 3rd max TFIDF count tends to be a bad guess
# 1-ngram actually guessed GTA, as often comparisons to another game can mislead guessing
gedit[gedit['asin'] == 'B0076ZQSFI'][:15]
# Out:
#             asin  helppercent  overall                     cleansum  \
# 1373  B0076ZQSFI     0.923077        5                   sleep game
# 1374  B0076ZQSFI     1.000000        5        fav sandbox game ever
# 1375  B0076ZQSFI     1.000000        5                          fun
# 1376  B0076ZQSFI     0.500000        5           one best game ever
# 1377  B0076ZQSFI     0.500000        5                   prefer gta
# 1378  B0076ZQSFI     0.500000        5         best game wait gta v
# 1379  B0076ZQSFI     1.000000        5            totally underrate
# 1380  B0076ZQSFI     1.000000        4         gta meet jackie chan
# 1381  B0076ZQSFI     0.500000        5                  vote dollar
# 1382  B0076ZQSFI     0.920635        5  far east take gta saint row
# 1383  B0076ZQSFI     0.500000        5               excellent game
# 1384  B0076ZQSFI     1.000000        5               love love love
# 1385  B0076ZQSFI     1.000000        5      beautiful game full fun
# 1386  B0076ZQSFI     0.500000        4                      gta fun
# 1387  B0076ZQSFI     0.666667        4         true crime hong kong
#
#                                                                                                  cleantxt  \
# 1373  remember true crime street hong kong wa gonna come devs decide gut last year hear nothing else g...
# 1374  dont make statement lightly perhaps wa even know game exist saw p simply put blow away doe every...
# 1375  didnt know expect first hear game sleep dog wtf wa edge get game eventually free playstation plu...
# 1376  game ridiculously game lack nowadays game ha top notch everything control scenery graphic color ...
# 1377  blunt direct essentially hong kong version gta tweak notable difference instead gun sleep dog ha...
# 1378  sleep dog ha best open world game square enix ha ever make enjoy everything game ha great story ...
# 1379  look game play gta v come well find first square enix make game good sign square enix generally ...
# 1380  trailer look awesome buy still havent get past half american im hard time relate character altho...
# 1381  great game want company invest make new product like annual update cod madden whathaveyou vote d...
# 1382  game square enix sleeper game nobody ha hear may slip radar spiritual successor true crime serie...
# 1383  like gta never finish game gta action kind easy move aim fight like batman like even though ha d...
# 1384  cannot recommend game enough youre fan saint row gta love game gameplay similar hong kong underc...
# 1385  ive wait game go price finally jump immediately love game put many hour enjoy beautiful graphic ...
# 1386  wa strange adapt gameplay expect something closer gta anyway story solid ha lot nice thing offer...
# 1387  many way gta ha dethrone game sleep dog lot fun seriously addictive may lack complete freedom gt...
#
#                                                                                                 cleanboth
# 1373  sleep game remember true crime street hong kong wa gonna come devs decide gut last year hear not...
# 1374  fav sandbox game ever dont make statement lightly perhaps wa even know game exist saw p simply p...
# 1375  fun didnt know expect first hear game sleep dog wtf wa edge get game eventually free playstation...
# 1376  one best game ever game ridiculously game lack nowadays game ha top notch everything control sce...
# 1377  prefer gta blunt direct essentially hong kong version gta tweak notable difference instead gun s...
# 1378  best game wait gta v sleep dog ha best open world game square enix ha ever make enjoy everything...
# 1379  totally underrate look game play gta v come well find first square enix make game good sign squa...
# 1380  gta meet jackie chan trailer look awesome buy still havent get past half american im hard time r...
# 1381  vote dollar great game want company invest make new product like annual update cod madden whatha...
# 1382  far east take gta saint row game square enix sleeper game nobody ha hear may slip radar spiritua...
# 1383  excellent game like gta never finish game gta action kind easy move aim fight like batman like e...
# 1384  love love love cannot recommend game enough youre fan saint row gta love game gameplay similar h...
# 1385  beautiful game full fun ive wait game go price finally jump immediately love game put many hour ...
# 1386  gta fun wa strange adapt gameplay expect something closer gta anyway story solid ha lot nice thi...
# 1387  true crime hong kong many way gta ha dethrone game sleep dog lot fun seriously addictive may lac...

# %%
# this concludes pt 03
