# %% [markdown]
# ## Purpose of script:
# #### Light-weight market basket analysis
# #### Will separately create a dockerized version
# #### tutorial url:
# #### https://www.geeksforgeeks.org/implementing-apriori-algorithm-in-python/

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
orig = pd.read_excel('../Datasets/Online Retail.xlsx')
print(orig.shape)
orig.head(2)
# Out:
# (541909, 8)
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data = orig.copy()

# %%
data.Country.value_counts()[:20]
# Out:
# United Kingdom     495478
# Germany              9495
# France               8557
# EIRE                 8196
# Spain                2533
# Netherlands          2371
# Belgium              2069
# Switzerland          2002
# Portugal             1519
# Australia            1259
# Norway               1086
# Italy                 803
# Channel Islands       758
# Finland               695
# Cyprus                622
# Sweden                462
# Unspecified           446
# Austria               401
# Denmark               389
# Japan                 358
# Name: Country, dtype: int64

# %%
# Stripping extra spaces in the description
data['Description'] = data['Description'].str.strip()
  
# Dropping the rows without any invoice number
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
  
# Dropping all transactions which were done on credit
data = data[~data['InvoiceNo'].str.contains('C')]
data.shape
# Out:
# (532621, 8)

# %%
# Transactions done in the United Kingdom
basket_UK = (data[data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

# %%
basket_encoded = basket_UK.applymap(hot_encode)
basket_UK = basket_encoded

basket_UK.shape
# Out:
# (18667, 4175)

# %%
frq_items = apriori(basket_UK.astype('bool'), min_support = 0.01, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
print(rules.shape)
rules.head(10)
# Out:
# (3760, 9)
#                                             antecedents  \
# 117                (BEADED CRYSTAL HEART PINK ON STICK)
# 2018       (JAM MAKING SET PRINTED, SUKI  SHOULDER BAG)
# 2295              (HERB MARKER THYME, HERB MARKER MINT)
# 2302        (HERB MARKER ROSEMARY, HERB MARKER PARSLEY)
# 2301           (HERB MARKER THYME, HERB MARKER PARSLEY)
# 2278             (HERB MARKER THYME, HERB MARKER BASIL)
# 3357  (REGENCY TEA PLATE PINK, REGENCY TEA PLATE ROSES)
# 3374  (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN T...
# 2288              (HERB MARKER THYME, HERB MARKER MINT)
# 2277          (HERB MARKER ROSEMARY, HERB MARKER BASIL)
#
#                                consequents  antecedent support  \
# 117                       (DOTCOM POSTAGE)            0.011036
# 2018                      (DOTCOM POSTAGE)            0.011625
# 2295                (HERB MARKER ROSEMARY)            0.010714
# 2302                   (HERB MARKER THYME)            0.011089
# 2301                (HERB MARKER ROSEMARY)            0.011089
# 2278                (HERB MARKER ROSEMARY)            0.010875
# 3357             (REGENCY TEA PLATE GREEN)            0.012643
# 3374  (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.012428
# 2288                 (HERB MARKER PARSLEY)            0.010714
# 2277                   (HERB MARKER THYME)            0.011036
#
#       consequent support   support  confidence       lift  leverage  \
# 117             0.037928  0.010768    0.975728  25.725872  0.010349
# 2018            0.037928  0.011196    0.963134  25.393807  0.010755
# 2295            0.012375  0.010232    0.955000  77.173095  0.010099
# 2302            0.012321  0.010553    0.951691  77.240055  0.010417
# 2301            0.012375  0.010553    0.951691  76.905682  0.010416
# 2278            0.012375  0.010339    0.950739  76.828759  0.010205
# 3357            0.018000  0.011946    0.944915  52.496229  0.011719
# 3374            0.025660  0.011732    0.943966  36.787065  0.011413
# 2288            0.012214  0.010071    0.940000  76.960439  0.009940
# 2277            0.012321  0.010339    0.936893  76.039067  0.010203
#
#       conviction
# 117    39.637371
# 2018   26.096206
# 2295   21.947227
# 2302   20.444951
# 2301   20.443842
# 2278   20.048792
# 3357   17.827083
# 3374   17.388217
# 2288   16.463099
# 2277   15.650910

# %%
## Sample of associations
rules[rules.antecedents == frozenset({'JUMBO BAG TOYS'})]
# Out:
#            antecedents                                        consequents  \
# 913   (JUMBO BAG TOYS)                          (JUMBO BAG RED RETROSPOT)
# 1055  (JUMBO BAG TOYS)                           (JUMBO STORAGE BAG SUKI)
# 1051  (JUMBO BAG TOYS)                       (JUMBO BAG WOODLAND ANIMALS)
# 841   (JUMBO BAG TOYS)                          (JUMBO BAG PINK POLKADOT)
# 343   (JUMBO BAG TOYS)                                   (DOTCOM POSTAGE)
# 1052  (JUMBO BAG TOYS)                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 2761  (JUMBO BAG TOYS)  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)
# 2563  (JUMBO BAG TOYS)  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...
# 2749  (JUMBO BAG TOYS)  (JUMBO BAG RED RETROSPOT, JUMBO BAG WOODLAND A...
# 2083  (JUMBO BAG TOYS)          (JUMBO BAG RED RETROSPOT, DOTCOM POSTAGE)
# 2754  (JUMBO BAG TOYS)  (JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAG...
# 2893  (JUMBO BAG TOYS)  (JUMBO STORAGE BAG SUKI, JUMBO BAG WOODLAND AN...
# 2897  (JUMBO BAG TOYS)  (JUMBO STORAGE BAG SUKI, JUMBO SHOPPER VINTAGE...
