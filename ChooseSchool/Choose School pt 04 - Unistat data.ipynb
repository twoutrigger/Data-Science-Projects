# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Explore Unistat data regarding student Employment and Salary

# %%
aorig = pd.read_csv('Unistats/KISCOURSE.csv', header=0)

print(aorig.shape)
aorig.head()
# Out:
# (37893, 35)
# C:\Users\liamk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (3,5,8,23,28,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    PUBUKPRN     UKPRN                                             ASSURL  \
# 0  10000047  10001143  https://www.canterbury.ac.uk/study-here/course...
# 1  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 2  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 3  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 4  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
#
#   ASSURLW                                            CRSEURL CRSEURLW  \
# 0     NaN  https://www.canterbury.ac.uk/study-here/course...      NaN
# 1     NaN  http://www.abingdon-witney.ac.uk/course/?code=...      NaN
# ...

# %%
print(len(aorig.PUBUKPRN.unique()))
print(len(aorig.UKPRN.unique()))
# Out:
# 460
# 414

# %%
eorig = pd.read_csv('Unistats/EMPLOYMENT.csv', header=0)

print(eorig.shape)
eorig.head()
# Out:
# (47994, 15)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE  EMPUNAVAILREASON  EMPPOP  \
# 0  10000047  10001143  PSSFDOPTDIS        1                 0    20.0
# 1  10000055  10000055         AB20        1                 0    15.0
# 2  10000055  10000055         AB27        1                 1    20.0
# 3  10000055  10000055         AB28        1                 0    20.0
# 4  10000055  10000055         AB29        1                 0    20.0
#
#    EMPRESP_RATE  EMPAGG       EMPSBJ  WORKSTUDY  STUDY  ASSUNEMP  BOTH  \
# 0          70.0    14.0          NaN      100.0   40.0       0.0  35.0
# 1         100.0    14.0          NaN       95.0   80.0       5.0   5.0
# 2          88.0    13.0  CAH06-01-01      100.0   15.0       0.0  10.0
# 3          90.0    24.0          NaN      100.0   30.0       0.0  40.0
# 4          91.0    22.0     CAH10-01      100.0   35.0       0.0  40.0
#
#    NOAVAIL  WORK
# 0      0.0  30.0
# 1      0.0   5.0
# 2      0.0  75.0
# 3      0.0  35.0
# ...

# %%
sorig = pd.read_csv('Unistats/SALARY.csv', header=0)

print(sorig.shape)
sorig.head()
# Out:
# (46627, 18)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 0  10000047  10001143  PSSFDOPTDIS        1                 0     NaN
# 1  10000055  10000055         AB20        1                 0     NaN
# 2  10000055  10000055         AB27        1                 1     NaN
# 3  10000055  10000055         AB28        1                 0     NaN
# 4  10000055  10000055         AB29        1                 0     NaN
#
#    SALRESP_RATE  SALAGG SALSBJ  LDLQ  LDMED  LDUQ  LQ  MED  UQ  INSTLQ  \
# 0           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 1           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 2           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 3           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 4           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
#
#    INSTMED  INSTUQ
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# ...

# %%
sorig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46627 entries, 0 to 46626
# Data columns (total 18 columns):
# PUBUKPRN            46627 non-null int64
# UKPRN               46627 non-null int64
# KISCOURSEID         46627 non-null object
# KISMODE             46627 non-null int64
# SALUNAVAILREASON    46627 non-null int64
# SALPOP              37197 non-null float64
# SALRESP_RATE        37197 non-null float64
# SALAGG              37197 non-null float64
# SALSBJ              33003 non-null object
# LDLQ                36597 non-null float64
# LDMED               36597 non-null float64
# LDUQ                36597 non-null float64
# LQ                  36732 non-null float64
# MED                 36732 non-null float64
# UQ                  36732 non-null float64
# INSTLQ              37197 non-null float64
# INSTMED             37197 non-null float64
# INSTUQ              37197 non-null float64
# dtypes: float64(12), int64(4), object(2)
# memory usage: 6.4+ MB

# %%
iorig = pd.read_csv('Unistats/INSTITUTION.csv', header=0)

print(iorig.shape)
iorig.head()
# Out:
# (460, 8)
#    PUBUKPRN     UKPRN COUNTRY PUBUKPRNCOUNTRY           TEFOutcome  \
# 0  10000047  10001143      XF              XF  Did not participate
# 1  10000055  10000055      XF              XF               Silver
# 2  10000163  10000163      XF              XF               Silver
# 3  10000216  10000216      XF              XF  Did not participate
# 4  10000248  10000248      XF              XF               Silver
#
#            APROutcome                                              SUURL  \
# 0                 NaN                                 http://ccsu.co.uk/
# 1  Meets requirements  http://www.nus.org.uk/en/students-unions/abing...
# 2                 NaN     http://www.aecc.ac.uk/undergrad/su/suhome.aspx
# 3                 NaN        https://www.allnations.ac.uk/community-life
# 4                 NaN                             https://www.nus.org.uk
#
#   SUURLW
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
iorig.COUNTRY.value_counts() # need to identify these
# Out:
# XF    418
# XH     19
# XI     19
# XG      4
# Name: COUNTRY, dtype: int64

# %%
lorig = pd.read_csv('Unistats/LOCATION.csv', header=0)

print(lorig.shape)
lorig.head()
# Out:
# (950, 12)
#       UKPRN                                           ACCOMURL ACCOMURLW  \
# 0  10000055  http://www.brookes.ac.uk/studying-at-brookes/a...       NaN
# 1  10000055  http://www.brookes.ac.uk/studying-at-brookes/a...       NaN
# 2  10000055  http://www.brookes.ac.uk/studying-at-brookes/a...       NaN
# 3  10000163  http://www.aecc.ac.uk/undergrad/accommodation....       NaN
# 4  10000216            https://www.allnations.ac.uk/fees-sheet       NaN
#
#   LOCID                                            LOCNAME LOCNAMEW  \
# 0    AB    Abingdon &amp; Witney College (Abingdon Campus)      NaN
# 1    CL  Abingdon &amp; Witney College (Common Leys Cam...      NaN
# 2    WI      Abingdon &amp; Witney College (Witney Campus)      NaN
# 3    AE                            AECC University College      NaN
# 4    AN                      All Nations Christian College      NaN
#
#     LATITUDE  LONGITUDE    LOCUKPRN LOCCOUNTRY  \
# 0  51.680769  -1.286935  10000055.0         XF
# ...

# %%
lorig.UKPRN.value_counts()[:10] # we see repeats in unique ID
# Out:
# 10006299    21
# 10007114    16
# 10007141    11
# 10007166    11
# 10007155    10
# 10031982    10
# 10007848    10
# 10007793     9
# 10003678     9
# 10000291     9
# Name: UKPRN, dtype: int64

# %%
lorig[lorig.UKPRN == 10006299][:10]
# Out:
#         UKPRN                                ACCOMURL ACCOMURLW LOCID  \
# 400  10006299  https://www.eastwoodparktraining.co.uk       NaN    21
# 401  10006299                                     NaN       NaN    01
# 402  10006299                                     NaN       NaN    02
# 403  10006299                                     NaN       NaN    03
# 404  10006299                                     NaN       NaN    06
# 405  10006299                                     NaN       NaN    07
# 406  10006299                                     NaN       NaN    08
# 407  10006299                                     NaN       NaN    09
# 408  10006299                                     NaN       NaN    11
# 409  10006299                                     NaN       NaN    12
#
#                                  LOCNAME LOCNAMEW   LATITUDE  LONGITUDE  \
# 400                Eastwood Park Limited      NaN  51.629614  -2.471932
# ...

# %%
lorig[lorig.LOCNAME.str.contains('Stafford')]
# Out:
#         UKPRN ACCOMURL ACCOMURLW LOCID  \
# 401  10006299      NaN       NaN    01
# 409  10006299      NaN       NaN    12
# 418  10006299      NaN       NaN    97
# 419  10006299      NaN       NaN    98
# 864  10023526      NaN       NaN    L1
# 865  10023526      NaN       NaN    R1
# 866  10023526      NaN       NaN    T1
#
#                                           LOCNAME LOCNAMEW   LATITUDE  \
# 401                              Stafford College      NaN  52.806828
# 409                               Stafford Campus      NaN  52.813066
# 418  South Staffordshire College - Lichfield Site      NaN  52.683518
# 419  South Staffordshire College - Rodbaston Site      NaN  52.702912
# 864  South Staffordshire College Lichfield Campus      NaN  52.679684
# 865  South Staffordshire College Rodbaston Campus      NaN  52.702419
# 866   South Staffordshire College Tamworth Campus      NaN  52.639364
#
#      LONGITUDE    LOCUKPRN LOCCOUNTRY  \
# 401  -2.120574  10004603.0         XF
# ...

# %%
len(lorig.LOCNAME.unique()) # we see some repeats in name
# Out:
# 886

# %%
lorig.LOCNAME.value_counts()[:10]
# Out:
# Main Campus           24
# London                 5
# City Campus            5
# City Centre Campus     4
# Medway Campus          3
# Carmel College         3
# Canterbury             3
# London Campus          3
# Luton Campus           2
# Southwark Campus       2
# Name: LOCNAME, dtype: int64

# %%
lorig[lorig.LOCNAME == 'London']
# Out:
#         UKPRN                                           ACCOMURL  \
# 650  10007784  http://www.ucl.ac.uk/prospective-students/acco...
# 690  10007800                                                NaN
# 777  10007858              http://www.uwtsd.ac.uk/accommodation/
# 914  10037544                                                NaN
# 930  10039956  http://www.law.ac.uk/locations/london-bloomsbu...
#
#                             ACCOMURLW LOCID LOCNAME  LOCNAMEW   LATITUDE  \
# 650                               NaN    AA  London       NaN  51.524716
# 690                               NaN    LO  London       NaN  51.498515
# 777  http://www.uwtsd.ac.uk/cy/llety/    LO  London  Llundain  51.479817
# 914                               NaN    E1  London       NaN  51.479385
# 930                               NaN    LO  London       NaN  51.520022
#
#      LONGITUDE    LOCUKPRN LOCCOUNTRY  \
# 650  -0.133553  10007784.0         XF
# 690  -0.099752  10007800.0         XH
# ...

# %%
lorig[lorig.UKPRN == 10001143]
# Out:
#        UKPRN                                           ACCOMURL ACCOMURLW  \
# 88  10001143  http://www.canterbury.ac.uk/study-here/accommo...       NaN
# 89  10001143  http://www.canterbury.ac.uk/study-here/accommo...       NaN
# 90  10001143                                                NaN       NaN
#
#    LOCID       LOCNAME LOCNAMEW   LATITUDE  LONGITUDE    LOCUKPRN LOCCOUNTRY  \
# 88    A0    Canterbury      NaN  51.279569   1.088586         NaN         XF
# 89    M0        Medway      NaN  51.398966   0.539067         NaN         XF
# 90    A1  ABDO College      NaN  51.219857   0.952200  10000047.0         XF
#
#                  SUURL SUURLW
# 88  http://ccsu.co.uk/    NaN
# 89  http://ccsu.co.uk/    NaN
# 90  http://ccsu.co.uk/    NaN

# %%
lorig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 12 columns):
# UKPRN         950 non-null int64
# ACCOMURL      667 non-null object
# ACCOMURLW     31 non-null object
# LOCID         950 non-null object
# LOCNAME       950 non-null object
# LOCNAMEW      48 non-null object
# LATITUDE      950 non-null float64
# LONGITUDE     950 non-null float64
# LOCUKPRN      691 non-null float64
# LOCCOUNTRY    950 non-null object
# SUURL         869 non-null object
# SUURLW        39 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 89.1+ KB

# %%
jorig = pd.read_csv('Unistats/JOBLIST.csv', header=0)

print(jorig.shape)
jorig.head()
# Out:
# (362699, 8)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE       COMSBJ  \
# 0  10000047  10001143  PSSFDOPTDIS        1          NaN
# 1  10000047  10001143  PSSFDOPTDIS        1          NaN
# 2  10000055  10000055         AB27        1  CAH06-01-01
# 3  10000055  10000055         AB27        1  CAH06-01-01
# 4  10000055  10000055         AB27        1  CAH06-01-01
#
#                                                  JOB  PERC  ORDER
# 0                     Health associate professionals    80      1
# 1                                  Sales occupations    20      2
# 2  Business and Public Service Associate Professi...    30      1
# 3                   Animal Care and Control Services    25      2
# 4           Managers, Directors and Senior Officials    10      3

# %%
jorig.JOB.value_counts()[:10]
# Out:
# Business and public service associate professionals            36525
# Sales occupations                                              28220
# Administrative occupations                                     28057
# Elementary occupations                                         27327
# Managers, directors and senior officials                       26038
# Teaching and educational professionals                         22258
# Business, research and administrative professionals            20918
# Customer service occupations                                   14991
# Artistic, literary and media occupations                       14088
# Science, engineering and technology associate professionals    13498
# Name: JOB, dtype: int64

# %%
# for i in aorig.Country.unique():
#     schoolnum = len(aorig[aorig.Country == i].Provider.unique())
#     print(f"{i} has {schoolnum} schools")

# %%
# ni2_test = pd.pivot_table(ni2, values='Response', index=['Level', 'Provider', 'Question Number'], aggfunc=np.sum)

# ni2_test

# %%
# q_keep = ['Scale01','Scale02','Scale03','Scale04','Scale05','Scale06','Scale07','Scale08','Q26','Q27',]

# aedit = aorig[aorig['Question Number'].isin(q_keep)]

# print(aedit.shape)
# aedit.head(2)
