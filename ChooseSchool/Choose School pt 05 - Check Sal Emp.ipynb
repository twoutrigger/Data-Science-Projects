# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Explore and merge Salary data to NAtional Student Survey data

# %%
aorig = pd.read_csv('he_choose_detail.csv', header=0, index_col=0)

print(aorig.shape)
aorig.head()
# Out:
# (66177, 9)
#       UKPRN                Provider Subject Code                  Subject  \
# 0  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 1  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 2  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 3  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 4  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
#
#           Level Question Number  Actual value  Response   Country
# 0  First degree         Scale01        0.9394        99  Scotland
# 1  First degree         Scale02        0.9158        99  Scotland
# 2  First degree         Scale03        0.6944        99  Scotland
# 3  First degree         Scale04        0.8838        99  Scotland
# 4  First degree         Scale05        0.8636        99  Scotland

# %% [markdown]
# ## Explore EMP dataset

# %%
eorig = pd.read_csv('Unistats/EMPLOYMENT.csv', header=0)

print(eorig.shape)
eorig.head()
# Out:
# (47994, 15)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE  EMPUNAVAILREASON  EMPPOP  \
# 0  10000047  10001143  PSSFDOPTDIS        1                 0    20.0
# 1  10000055  10000055         AB20        1                 0    15.0
# 2  10000055  10000055         AB27        1                 1    20.0
# 3  10000055  10000055         AB28        1                 0    20.0
# 4  10000055  10000055         AB29        1                 0    20.0
#
#    EMPRESP_RATE  EMPAGG       EMPSBJ  WORKSTUDY  STUDY  ASSUNEMP  BOTH  \
# 0          70.0    14.0          NaN      100.0   40.0       0.0  35.0
# 1         100.0    14.0          NaN       95.0   80.0       5.0   5.0
# 2          88.0    13.0  CAH06-01-01      100.0   15.0       0.0  10.0
# 3          90.0    24.0          NaN      100.0   30.0       0.0  40.0
# 4          91.0    22.0     CAH10-01      100.0   35.0       0.0  40.0
#
#    NOAVAIL  WORK
# 0      0.0  30.0
# 1      0.0   5.0
# 2      0.0  75.0
# 3      0.0  35.0
# ...

# %%
aorig[aorig['Subject Code'] == 'CAH06-01-01']['Subject'].unique()
# Out:
# array(['Animal science'], dtype=object)

# %%
aorig[aorig['Subject Code'].str.contains('CAH10-01')]['Subject'].unique()
# Out:
# array(['Mechanical engineering', 'Civil engineering',
#        'Electrical and electronic engineering',
#        'Chemical, process and energy engineering',
#        'Production and manufacturing engineering',
#        'Bioengineering, medical and biomedical engineering',
#        'Engineering (non-specific)',
#        'Aeronautical and aerospace engineering'], dtype=object)

# %%
eorig = eorig[eorig.EMPSBJ.isnull() == False]
print(eorig.shape)
# Out:
# (34070, 15)

# %%
eorig[eorig.EMPSBJ.str.contains('CAH10-01')].EMPSBJ.unique()
# Out:
# array(['CAH10-01', 'CAH10-01-08', 'CAH10-01-02', 'CAH10-01-07',
#        'CAH10-01-03', 'CAH10-01-01', 'CAH10-01-04', 'CAH10-01-09',
#        'CAH10-01-05', 'CAH10-01-06'], dtype=object)

# %%
# EMPPOP - Number of students in the population from which the employment data is derived for the course
# EMPRESP_RATE - Response rate of students in the population from which the employment data is derived for the course
# EMPAGG - unclear; skip
# EMPSBJ - for matching
# WORK - important; Proportion of students in work six months after their course ended
# ASSUNEMP - flip for most unemployed
eorig[eorig.EMPSBJ == 'CAH10-01-08'].iloc[0,:]
# Out:
# PUBUKPRN               10000291
# UKPRN                  10000291
# KISCOURSEID              K00033
# KISMODE                       1
# EMPUNAVAILREASON              0
# EMPPOP                       15
# EMPRESP_RATE                 80
# EMPAGG                       23
# EMPSBJ              CAH10-01-08
# WORKSTUDY                    70
# STUDY                        20
# ASSUNEMP                     20
# BOTH                          0
# NOAVAIL                       5
# WORK                         50
# Name: 54, dtype: object

# %%
eorig.describe()
# Out:
#            PUBUKPRN         UKPRN       KISMODE  EMPUNAVAILREASON  \
# count  3.407000e+04  3.407000e+04  34070.000000      34070.000000
# mean   1.002547e+07  1.002543e+07      1.082213          0.645847
# std    1.289841e+06  1.289841e+06      0.274693          0.478263
# min    1.000006e+07  1.000006e+07      1.000000          0.000000
# 25%    1.000684e+07  1.000684e+07      1.000000          0.000000
# 50%    1.000717e+07  1.000717e+07      1.000000          1.000000
# 75%    1.000780e+07  1.000780e+07      1.000000          1.000000
# max    1.000000e+08  1.000000e+08      2.000000          1.000000
#
#              EMPPOP  EMPRESP_RATE        EMPAGG     WORKSTUDY         STUDY  \
# count  34070.000000  34070.000000  34070.000000  34070.000000  34070.000000
# mean      71.314910     76.975345     14.714001     88.988436     20.630320
# std      118.639039      6.981396      4.036143      7.445674     13.412842
# ...

# %%
eorig.EMPAGG.value_counts()
# Out:
# 13.0    20458
# 12.0     5382
# 23.0     5101
# 11.0     1344
# 22.0     1176
# 21.0      609
# Name: EMPAGG, dtype: int64

# %%
# check KISCOURSEID
eorig[eorig.EMPSBJ == 'CAH10-01-08']
# Out:
#        PUBUKPRN     UKPRN            KISCOURSEID  KISMODE  EMPUNAVAILREASON  \
# 54     10000291  10000291                 K00033        1                 0
# 90     10000291  10000291                 K00101        1                 1
# 1318   10000747  10000747              ST2523C16        1                 1
# 1409   10000820  10000820             ED18_DP_PT        2                 1
# 1410   10000820  10000820             ED18_FD_PT        2                 1
# 1596   10000840  10000840              WBAH5001B        2                 0
# 1708   10000886  10000886             J4CA003MUU        1                 0
# 1712   10000886  10000886             J4ED003MUU        1                 1
# 1713   10000886  10000886             J4ED004MUU        1                 0
# 1769   10000886  10000886             P1CA001MUU        1                 0
# 1773   10000886  10000886             P1ED001MUU        1                 0
# ...

# %%
len(eorig[eorig.EMPSBJ == 'CAH10-01-08'].UKPRN.unique())
# Out:
# 79

# %% [markdown]
# ## KIS Course Validation

# %%
korig = pd.read_csv('Unistats/KISCOURSE.csv', header=0)

print(korig.shape)
korig.head()
# Out:
# (37893, 35)
# C:\Users\liamk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (3,5,8,23,28,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    PUBUKPRN     UKPRN                                             ASSURL  \
# 0  10000047  10001143  https://www.canterbury.ac.uk/study-here/course...
# 1  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 2  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 3  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
# 4  10000055  10000055  http://www.abingdon-witney.ac.uk/course/?code=...
#
#   ASSURLW                                            CRSEURL CRSEURLW  \
# 0     NaN  https://www.canterbury.ac.uk/study-here/course...      NaN
# 1     NaN  http://www.abingdon-witney.ac.uk/course/?code=...      NaN
# ...

# %%
# check uni name
aorig[aorig.UKPRN == 10000747].head(1)
# Out:
#          UKPRN           Provider Subject Code  \
# 6208  10000747  Blackburn College  CAH02-03-08
#
#                                                 Subject                Level  \
# 6208  Counselling, psychotherapy and occupational th...  Other undergraduate
#
#      Question Number  Actual value  Response  Country
# 6208         Scale01        0.6062        51  England

# %% [markdown]
# ## Explore SAL dataset

# %%
sorig = pd.read_csv('Unistats/SALARY.csv', header=0)

print(sorig.shape)
sorig.head()
# Out:
# (46627, 18)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 0  10000047  10001143  PSSFDOPTDIS        1                 0     NaN
# 1  10000055  10000055         AB20        1                 0     NaN
# 2  10000055  10000055         AB27        1                 1     NaN
# 3  10000055  10000055         AB28        1                 0     NaN
# 4  10000055  10000055         AB29        1                 0     NaN
#
#    SALRESP_RATE  SALAGG SALSBJ  LDLQ  LDMED  LDUQ  LQ  MED  UQ  INSTLQ  \
# 0           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 1           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 2           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 3           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
# 4           NaN     NaN    NaN   NaN    NaN   NaN NaN  NaN NaN     NaN
#
#    INSTMED  INSTUQ
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# ...

# %%
sorig = sorig[sorig.SALSBJ.isnull() == False]
print(sorig.shape)
# Out:
# (33003, 18)

# %%
# SALPOP - Number of students in the population from which the salary data is derived for the course
# SALRESP_RATE - Response rate of students in the population from which the salary data is derived for the course
# SALSBJ - JACS Level subject code
# LDMED - (?) Sector Median salary for subject (40 months after graduation)
# MED - (?) Sector Median salary for subject (6 months after graduation)
# INSTMED - (?) Course Median salary (6 months after graduation)
# also do we care about tariffs?
sorig[sorig.SALSBJ == 'CAH10-01-08'].iloc[0,:]
# Out:
# PUBUKPRN               10000820
# UKPRN                  10000820
# KISCOURSEID          ED18_DP_PT
# KISMODE                       2
# SALUNAVAILREASON              1
# SALPOP                       10
# SALRESP_RATE                100
# SALAGG                       13
# SALSBJ              CAH10-01-08
# LDLQ                        NaN
# LDMED                       NaN
# LDUQ                        NaN
# LQ                        24000
# MED                       25000
# UQ                        32000
# INSTLQ                    23000
# INSTMED                   28000
# INSTUQ                    40000
# Name: 1290, dtype: object

# %%
aorig[aorig.UKPRN == 10000820].Provider.unique()
# Out:
# array(['Bournemouth and Poole College, The'], dtype=object)

# %% [markdown]
# ## Salary Validation

# %%
sorig.SALSBJ.value_counts()[:10]
# Out:
# CAH19-03       2836
# CAH17-01       1413
# CAH20-01-01    1061
# CAH15-03-01     982
# CAH19           937
# CAH17-01-02     840
# CAH15-01-02     829
# CAH11-01-01     817
# CAH15           774
# CAH09-01-01     734
# Name: SALSBJ, dtype: int64

# %%
aorig[aorig['Subject Code'] == 'CAH20-01-01'].Subject.unique()
# Out:
# array(['History'], dtype=object)

# %%
sorig[sorig.SALSBJ == 'CAH20-01-01'][:5]
# Out:
#      PUBUKPRN     UKPRN KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 63   10000291  10000291      K00044        1                 1    25.0
# 496  10000571  10000571    BA-EDAHY        1                 0    20.0
# 544  10000571  10000571      BA-HHP        1                 1    20.0
# 546  10000571  10000571   BA-HHP-SW        1                 1    20.0
# 548  10000571  10000571    BA-HY-SW        1                 1    20.0
#
#      SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 63           65.0    23.0  CAH20-01-01  20000.0  25000.0  29000.0  16000.0
# 496          55.0    23.0  CAH20-01-01  19000.0  24000.0  27000.0  16000.0
# 544          55.0    23.0  CAH20-01-01  19000.0  24000.0  27000.0  16000.0
# 546          55.0    23.0  CAH20-01-01  19000.0  24000.0  27000.0  16000.0
# 548          55.0    23.0  CAH20-01-01  19000.0  24000.0  27000.0  16000.0
#
#          MED       UQ   INSTLQ  INSTMED   INSTUQ
# ...

# %%
sorig[sorig.SALSBJ == 'CAH20-01-01'].UKPRN.unique()[:10]
# Out:
# array([10000291, 10000571, 10000961, 10001282, 10001726, 10001883,
#        10002718, 10003614, 10003645, 10003861], dtype=int64)

# %%
aorig[aorig.UKPRN == 10000961].Provider.unique()
# Out:
# array(['Brunel University London'], dtype=object)

# %%
sorig[(sorig.SALSBJ == 'CAH20-01-01') & (sorig.UKPRN == 10000961)]
# Out:
#       PUBUKPRN     UKPRN         KISCOURSEID  KISMODE  SALUNAVAILREASON  \
# 1923  10000961  10000961  LV21UPLT-HY-FT-BSC        1                 0
# 1925  10000961  10000961  LV21UPLT-HY-KW-BSC        1                 0
# 1974  10000961  10000961  V140UHISTORY-KW-BA        1                 0
# 1975  10000961  10000961  V391UMILINTH-FT-BA        1                 1
# 1976  10000961  10000961  V391UMILINTH-KW-BA        1                 1
#
#       SALPOP  SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ  \
# 1923    15.0         100.0    13.0  CAH20-01-01  25000.0  29000.0  36000.0
# 1925    15.0         100.0    13.0  CAH20-01-01  25000.0  29000.0  36000.0
# 1974    15.0         100.0    13.0  CAH20-01-01  25000.0  29000.0  36000.0
# 1975    15.0         100.0    13.0  CAH20-01-01  25000.0  29000.0  36000.0
# 1976    15.0         100.0    13.0  CAH20-01-01  25000.0  29000.0  36000.0
#
#            LQ      MED       UQ   INSTLQ  INSTMED   INSTUQ
# ...

# %%
aorig[aorig.Provider.str.contains('Bournemouth')].Provider.unique()
# Out:
# array(['Arts University Bournemouth, the',
#        'Bournemouth and Poole College, The', 'Bournemouth University'],
#       dtype=object)

# %%
aorig[aorig['Subject Code'] == 'CAH10-01-08'].Subject.unique()
# Out:
# array(['Electrical and electronic engineering'], dtype=object)

# %% [markdown]
# Test 3

# %%
aorig[aorig['Subject Code'] == 'CAH15-03-01'].Subject.unique()
# Out:
# array(['Politics'], dtype=object)

# %%
sorig[sorig.SALSBJ == 'CAH15-03-01'].sample(5)
# Out:
#        PUBUKPRN     UKPRN     KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 14635  10006842  10006842       BA_TIPPCS        1                 1    20.0
# 27782  10007768  10007768          005199        1                 0    15.0
# 5289   10003678  10003678  BAHUFHRG2SOC20        1                 0    15.0
# 14970  10006842  10006842       BA_TPMIPP        1                 1    20.0
# 22070  10007157  10007157            RL60        1                 1    35.0
#
#        SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 14635          75.0    13.0  CAH15-03-01  22000.0  26000.0  32000.0  17000.0
# 27782          80.0    13.0  CAH15-03-01  20000.0  25000.0  31000.0  17000.0
# 5289           75.0    13.0  CAH15-03-01  26000.0  30000.0  36000.0  20000.0
# 14970          75.0    13.0  CAH15-03-01  22000.0  26000.0  32000.0  17000.0
# 22070          70.0    13.0  CAH15-03-01  21000.0  26000.0  31000.0  17000.0
#
# ...

# %%
aorig[aorig.UKPRN == 10007783].Provider.unique()
# Out:
# array(['University of Aberdeen'], dtype=object)

# %%
len(sorig[sorig.SALSBJ == 'CAH15-03-01'].LDMED.unique())
# Out:
# 11

# %%
stest = sorig[(sorig.SALSBJ == 'CAH15-03-01')]
print(len(stest))
# Out:
# 982

# %%
s_piv = pd.pivot_table(stest, values='INSTMED', index=['UKPRN'], aggfunc=np.mean)

print(s_piv[s_piv.INSTMED == s_piv.INSTMED.min()])
print(s_piv.nlargest(3, 'INSTMED'))
# Out:
#           INSTMED
# UKPRN
# 10007848  16000.0
#           INSTMED
# UKPRN
# 10007773  30000.0
# 10004063  28000.0
# 10007760  27000.0

# %%
print(aorig[aorig.UKPRN == 10007848].Provider.unique())
print(aorig[aorig.UKPRN == 10004063].Provider.unique())
# Out:
# ['University of Chester']
# ['The London School of Economics and Political Science']

# %%
sorig[(sorig.UKPRN == 10007848) & (sorig.SALSBJ == 'CAH15-03-01')].head(1)
# Out:
#        PUBUKPRN     UKPRN KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 40668  10007848  10007848   UBAECIR-K        1                 1    15.0
#
#        SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 40668          95.0    23.0  CAH15-03-01  20000.0  24000.0  30000.0  17000.0
#
#            MED       UQ   INSTLQ  INSTMED   INSTUQ
# 40668  19000.0  23000.0  14000.0  16000.0  20000.0

# %%
sorig[sorig.SALSBJ.str.contains('CAH15')].SALSBJ.unique()
# Out:
# array(['CAH15-01-02', 'CAH15', 'CAH15-01', 'CAH15-04', 'CAH15-04-03',
#        'CAH15-04-01', 'CAH15-01-03', 'CAH15-02-01', 'CAH15-03-01',
#        'CAH15-01-04', 'CAH15-04-02', 'CAH15-01-01', 'CAH15-01-05'],
#       dtype=object)

# %%
sorig[(sorig.UKPRN == 10004063) & (sorig.SALSBJ == 'CAH15-03-01')].head(1)
# Out:
#       PUBUKPRN     UKPRN     KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 6944  10004063  10004063  F9L1-UBENPOWEC        1                 0    35.0
#
#       SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 6944          80.0    13.0  CAH15-03-01  26000.0  30000.0  36000.0  20000.0
#
#           MED       UQ   INSTLQ  INSTMED   INSTUQ
# 6944  24000.0  28000.0  24000.0  28000.0  30000.0

# %% [markdown]
# Test 4

# %%
aorig[aorig['Subject Code'] == 'CAH17-01-02'].Subject.unique()
# Out:
# array(['Business studies'], dtype=object)

# %%
sorig[sorig.SALSBJ == 'CAH17-01-02'].UKPRN.unique()[-10:]
# Out:
# array([10007850, 10007852, 10007854, 10007857, 10023777, 10028216,
#        10030129, 10033187, 10042570, 10000975], dtype=int64)

# %%
print(aorig[aorig.UKPRN == 10007850].Provider.unique())
print(aorig[aorig.UKPRN == 10007852].Provider.unique())
# Out:
# ['The University of Bath']
# ['University of Dundee']

# %%
sorig[(sorig.UKPRN == 10007850) & (sorig.SALSBJ == 'CAH17-01-02')]
# Out:
#        PUBUKPRN     UKPRN            KISCOURSEID  KISMODE  SALUNAVAILREASON  \
# 41247  10007850  10007850  UUUC1-NN12~UMMN-AYB06        1                 1
#
#        SALPOP  SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ  \
# 41247    50.0          84.0    13.0  CAH17-01-02  24000.0  30000.0  38000.0
#
#             LQ      MED       UQ   INSTLQ  INSTMED   INSTUQ
# 41247  20000.0  23000.0  28000.0  26000.0  30000.0  36000.0

# %%
sorig[(sorig.UKPRN == 10007850) & (sorig.SALSBJ == 'CAH17-01')].head(5)
# Out:
#        PUBUKPRN     UKPRN            KISCOURSEID  KISMODE  SALUNAVAILREASON  \
# 41245  10007850  10007850  UUUC1-N200~UMMN-AFB04        1                 0
# 41246  10007850  10007850  UUUC1-N201~UMMN-AKB04        1                 1
# 41248  10007850  10007850  UUUC1-NN25~UMMN-AKB05        1                 1
# 41325  10007850  10007850  UUUI1-F145~USCH-AFB03        1                 0
# 41327  10007850  10007850  UUUI1-F146~USCH-AKB04        1                 0
#
#        SALPOP  SALRESP_RATE  SALAGG    SALSBJ     LDLQ    LDMED     LDUQ  \
# 41245    80.0          83.0    12.0  CAH17-01  24000.0  30000.0  37000.0
# 41246    80.0          83.0    12.0  CAH17-01  24000.0  30000.0  37000.0
# 41248    80.0          83.0    12.0  CAH17-01  24000.0  30000.0  37000.0
# 41325    80.0          83.0    12.0  CAH17-01  24000.0  30000.0  37000.0
# 41327    80.0          83.0    12.0  CAH17-01  24000.0  30000.0  37000.0
#
#             LQ      MED       UQ   INSTLQ  INSTMED   INSTUQ
# ...

# %%
sorig[(sorig.UKPRN == 10007852) & (sorig.SALSBJ == 'CAH17-01-02')].head(1)
# Out:
#        PUBUKPRN     UKPRN KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 43286  10007852  10007852        N120        1                 0    10.0
#
#        SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 43286         100.0    13.0  CAH17-01-02  21000.0  26000.0  34000.0  18000.0
#
#            MED       UQ   INSTLQ  INSTMED   INSTUQ
# 43286  20000.0  24000.0  18000.0  20000.0  20000.0

# %% [markdown]
# Test 5

# %%
aorig[aorig['Subject Code'] == 'CAH09-01-01'].Subject.unique()
# Out:
# array(['Mathematics'], dtype=object)

# %%
sorig[sorig.SALSBJ == 'CAH09-01-01'].UKPRN.unique()[20:30]
# Out:
# array([10007154, 10007155, 10007157, 10007158, 10007160, 10007163,
#        10007164, 10007166, 10007167, 10007759], dtype=int64)

# %%
print(aorig[aorig.UKPRN == 10007155].Provider.unique())
print(aorig[aorig.UKPRN == 10007157].Provider.unique())
# Out:
# ['University of Portsmouth']
# ['The University of Sheffield']

# %%
sorig[(sorig.UKPRN == 10007155) & (sorig.SALSBJ == 'CAH09-01-01')]
# Out:
#        PUBUKPRN     UKPRN KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 21323  10007155  10007155       C2684        1                 1    35.0
#
#        SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 21323          95.0    13.0  CAH09-01-01  25000.0  30000.0  39000.0  20000.0
#
#            MED       UQ   INSTLQ  INSTMED   INSTUQ
# 21323  25000.0  29000.0  19000.0  21000.0  24000.0

# %%
sorig[(sorig.UKPRN == 10007157) & (sorig.SALSBJ == 'CAH09-01-01')].head(1)
# Out:
#        PUBUKPRN     UKPRN KISCOURSEID  KISMODE  SALUNAVAILREASON  SALPOP  \
# 21834  10007157  10007157        G102        1                 1    40.0
#
#        SALRESP_RATE  SALAGG       SALSBJ     LDLQ    LDMED     LDUQ       LQ  \
# 21834          85.0    13.0  CAH09-01-01  24000.0  27000.0  35000.0  19000.0
#
#            MED       UQ   INSTLQ  INSTMED   INSTUQ
# 21834  22000.0  27000.0  18000.0  23000.0  27000.0

# %% [markdown]
# ## Merge Salary data

# %%
aorig.head()
# Out:
#       UKPRN                Provider Subject Code                  Subject  \
# 0  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 1  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 2  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 3  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
# 4  10007783  University of Aberdeen  CAH01-01-02  Medicine (non-specific)
#
#           Level Question Number  Actual value  Response   Country
# 0  First degree         Scale01        0.9394        99  Scotland
# 1  First degree         Scale02        0.9158        99  Scotland
# 2  First degree         Scale03        0.6944        99  Scotland
# 3  First degree         Scale04        0.8838        99  Scotland
# 4  First degree         Scale05        0.8636        99  Scotland

# %%
len(aorig['Subject Code'].unique())
# Out:
# 114

# %%
len(sorig.SALSBJ.unique())
# Out:
# 167

# %%
sedit = sorig.copy()

sedit['SBJLEN'] = sedit['SALSBJ'].apply(len)

sedit.SBJLEN.value_counts()
# Out:
# 11    20726
# 8      9709
# 5      2568
# Name: SBJLEN, dtype: int64

# %%
# we see more subjects in sorig
len(sedit[sedit.SBJLEN == 11].SALSBJ.unique())
# Out:
# 134

# %%
sorig.KISMODE.value_counts()
# Out:
# 1    31420
# 2     1583
# Name: KISMODE, dtype: int64

# %%
sedit = sedit[sedit.KISMODE == 1]

len(sedit[sedit.SBJLEN == 11].SALSBJ.unique())
# Out:
# 132

# %%
smerge = sedit[['UKPRN', 'SALSBJ', 'INSTMED']]

smerge.head(2)
# Out:
#        UKPRN       SALSBJ  INSTMED
# 23  10000248  CAH21-01-06  26000.0
# 24  10000248  CAH21-01-06  26000.0

# %%
first_degree_sbj = aorig[aorig.Level == 'First degree'].Subject.unique()
other_und_sbj = aorig[aorig.Level != 'First degree'].Subject.unique()
print(len(first_degree_sbj))
print(len(other_und_sbj))
# Out:
# 114
# 78

# %%
len(set(first_degree_sbj).difference(set(other_und_sbj)))
# Out:
# 36

# %%
# all other subjects are in first degree subjects
len(set(other_und_sbj).difference(set(first_degree_sbj)))
# Out:
# 0

# %%
# same as .difference
len(set(first_degree_sbj) - set(other_und_sbj))
# Out:
# 36

# %% [markdown]
# ## Explore LEO dataset

# %%
lorig = pd.read_csv('Unistats/LEO.csv', header=0)

print(lorig.shape)
lorig.head()
# Out:
# (45213, 11)
#    PUBUKPRN     UKPRN  KISCOURSEID  KISMODE  LEOUNAVAILREASON  LEOPOP  LEOAGG  \
# 0  10000047  10001143  PSSFDOPTDIS        1                 0    25.0    23.0
# 1  10000055  10000055         AB20        1                 0    15.0    23.0
# 2  10000055  10000055         AB27        1                 1     NaN     NaN
# 3  10000055  10000055         AB28        1                 1     NaN     NaN
# 4  10000055  10000055         AB29        1                 1     NaN     NaN
#
#         LEOSBJ    LEOLQ   LEOMED    LEOUQ
# 0  CAH02-03-03  19500.0  22000.0  25500.0
# 1  CAH06-01-01  14000.0  17000.0  23500.0
# 2          NaN      NaN      NaN      NaN
# 3          NaN      NaN      NaN      NaN
# 4          NaN      NaN      NaN      NaN

# %%
lorig = lorig[lorig.LEOSBJ.isnull() == False]
print(lorig.shape)
# Out:
# (31453, 11)

# %%
# LEOMED - (?) Median Longitudinal Education Outcomes data for the subject
lorig[lorig.LEOSBJ == 'CAH10-01-08'].iloc[0,:]
# Out:
# PUBUKPRN               10000291
# UKPRN                  10000291
# KISCOURSEID              K00033
# KISMODE                       1
# LEOUNAVAILREASON              0
# LEOPOP                       20
# LEOAGG                       23
# LEOSBJ              CAH10-01-08
# LEOLQ                     12500
# LEOMED                    19000
# LEOUQ                     28500
# Name: 54, dtype: object

# %%
lorig[lorig.LEOSBJ == 'CAH10-01-08'].iloc[110,:]
# Out:
# PUBUKPRN               10007140
# UKPRN                  10007140
# KISCOURSEID           US0669-00
# KISMODE                       1
# LEOUNAVAILREASON              0
# LEOPOP                      295
# LEOAGG                       23
# LEOSBJ              CAH10-01-08
# LEOLQ                     15500
# LEOMED                    20500
# LEOUQ                     26500
# Name: 17440, dtype: object

# %% [markdown]
# ## Misc Test

# %%
test = sorted(aorig.Subject.unique())

# %%
test[:5]
# Out:
# ['Accounting',
#  'Adult nursing',
#  'Aeronautical and aerospace engineering',
#  'Agriculture',
#  'American and Australasian studies']

# %%
atest = aorig[(aorig['Question Number'] == 'Scale01') | (aorig['Question Number'] == 'Scale02') | (aorig['Question Number'] == 'Q26')]

# %%
atest = atest[(atest.Subject == 'Economics') & (atest.Country == 'England')]

# %%
a_val = atest.Provider.value_counts()
print(a_val.shape)
# Out:
# (68,)

# %%
len(a_val[a_val == 3].index.tolist())
# Out:
# 65

# %%
anno = aorig[(aorig.Provider == 'University of Aberdeen') & (aorig.Subject == 'Economics')]

# %%
anno[anno['Question Number'] == 'Scale04']['Actual value'].values[0]
# Out:
# 0.8184

# %%
test2 = anno[anno['Question Number'] == 'Nope']

# %%
len(test2)
# Out:
# 0

# %%
# for i in aorig.Country.unique():
#     schoolnum = len(aorig[aorig.Country == i].Provider.unique())
#     print(f"{i} has {schoolnum} schools")

# %%
# ni2_test = pd.pivot_table(ni2, values='Response', index=['Level', 'Provider', 'Question Number'], aggfunc=np.sum)

# ni2_test

# %%
# q_keep = ['Scale01','Scale02','Scale03','Scale04','Scale05','Scale06','Scale07','Scale08','Q26','Q27',]

# aedit = aorig[aorig['Question Number'].isin(q_keep)]

# print(aedit.shape)
# aedit.head(2)

# %%
scale_dict = {'01SalMedian':'Median Salary', '02Employment':'Graduate Employment', '03Q27':'Overall Satisfaction',
              'Scale01':'Teaching Quality', 'Scale02':'Learning Opportunities', 'Scale03':'Academic Fairness', 'Scale04':'Academic Support',
              'Scale05':'Organisation and Management', 'Scale06':'Resource Availability', 'Scale07':'Sense of Community',
              'Scale08':'Student Voice', 'ZQ26':"Students' Union"
              }

# %%
cat_list = list(scale_dict.keys())

# %%
cat_list.remove('Scale08')

cat_list
# Out:
# ['01SalMedian',
#  '02Employment',
#  '03Q27',
#  'Scale01',
#  'Scale02',
#  'Scale03',
#  'Scale04',
#  'Scale05',
#  'Scale06',
#  'Scale07',
#  'ZQ26']

# %%
cat_set = set(scale_dict.keys())

cat_set
# Out:
# {'01SalMedian',
#  '02Employment',
#  '03Q27',
#  'Scale01',
#  'Scale02',
#  'Scale03',
#  'Scale04',
#  'Scale05',
#  'Scale06',
#  'Scale07',
#  'Scale08',
#  'ZQ26'}

# %%
cat_set.discard('ZQ200')

cat_set
# Out:
# {'01SalMedian',
#  '02Employment',
#  '03Q27',
#  'Scale01',
#  'Scale02',
#  'Scale03',
#  'Scale04',
#  'Scale05',
#  'Scale06',
#  'Scale07',
#  'Scale08'}

# %%
for i in sorted(cat_set):
    print(i)
# Out:
# 01SalMedian
# 02Employment
# 03Q27
# Scale01
# Scale02
# Scale03
# Scale04
# Scale05
# Scale06
# Scale07
# Scale08
