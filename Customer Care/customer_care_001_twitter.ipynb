# %%
import pandas as pd
import numpy as np

# %%
#### Purpose of script:

#### Analyze customer care data and look for patterns
#### Data is Twitter customer care data from Twitter, from:
#### https://www.kaggle.com/datasets/thoughtvector/customer-support-on-twitter?resource=download

# %%
orig = pd.read_csv('../../../large_datasets/twcs.csv', header=0)

print(orig.shape)
orig.head(5)
# Out:
# (2811774, 7)
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# ...

# %%
orig.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2811774 entries, 0 to 2811773
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tweet_id                 2811774 non-null  int64
#  1   author_id                2811774 non-null  object
#  2   inbound                  2811774 non-null  bool
#  3   created_at               2811774 non-null  object
#  4   text                     2811774 non-null  object
#  5   response_tweet_id        1771145 non-null  object
#  6   in_response_to_tweet_id  2017439 non-null  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 131.4+ MB

# %%
orig.iloc[0]['text']
# Out:
# '@115712 I understand. I would like to assist you. We would need to get you into a private secured link to further assist.'

# %%
orig.iloc[1]['text']
# Out:
# '@sprintcare and how do you propose we do that'

# %%
orig[orig.response_tweet_id.isnull()]
# Out:
#          tweet_id     author_id  inbound                      created_at  \
# 1               2        115712     True  Tue Oct 31 22:11:45 +0000 2017
# 7              11    sprintcare    False  Tue Oct 31 22:10:35 +0000 2017
# 13             19    sprintcare    False  Tue Oct 31 22:10:10 +0000 2017
# 19             27  Ask_Spectrum    False  Tue Oct 31 22:21:26 +0000 2017
# 20             23        115716     True  Tue Oct 31 22:16:05 +0000 2017
# ...           ...           ...      ...                             ...
# 2811766    139628  ArgosHelpers    False  Wed Nov 22 08:03:26 +0000 2017
# 2811767   2987945  VirginTrains    False  Wed Nov 22 08:27:34 +0000 2017
# 2811769   2987947    sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811771   2812240        121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949        AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %%
orig[orig.author_id == 'AldiUK']
# Out:
#          tweet_id author_id  inbound                      created_at  \
# 4921         7437    AldiUK    False  Tue Nov 07 16:36:40 +0000 2017
# 17627       22725    AldiUK    False  Wed Nov 01 08:38:24 +0000 2017
# 17635       22733    AldiUK    False  Wed Nov 01 08:37:29 +0000 2017
# 17637       22735    AldiUK    False  Wed Nov 01 08:34:51 +0000 2017
# 17639       22737    AldiUK    False  Wed Nov 01 08:34:07 +0000 2017
# ...           ...       ...      ...                             ...
# 2807862   2984116    AldiUK    False  Tue Oct 31 21:06:30 +0000 2017
# 2807864   2984118    AldiUK    False  Tue Oct 31 21:05:57 +0000 2017
# 2810776   2986977    AldiUK    False  Tue Nov 21 18:45:16 +0000 2017
# 2810778   2986979    AldiUK    False  Tue Nov 21 18:39:33 +0000 2017
# 2811772   2987949    AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
#
#                                                       text response_tweet_id  \
# ...

# %%
orig[orig.tweet_id == 22734.0]
# Out:
#        tweet_id author_id  inbound                      created_at  \
# 17636     22734    120970     True  Tue Oct 31 21:39:51 +0000 2017
#
#                                                     text response_tweet_id  \
# 17636  @AldiUK spoiling myself with this beauty of a ...             22733
#
#        in_response_to_tweet_id
# 17636                      NaN

# %%
# print shows only truncated text
print(orig[orig.tweet_id == 22734.0]['text'])
# Out:
# 17636    @AldiUK spoiling myself with this beauty of a ...
# Name: text, dtype: object

# %%
# text stored as a series
type(orig[orig.tweet_id == 22734.0]['text'])
# Out:
# pandas.core.series.Series

# %%
# able to visualize full text 
orig[orig.tweet_id == 22734.0]['text'].values[0]
# Out:
# '@AldiUK spoiling myself with this beauty of a Halloween treat!  A zesty Italian white that is truly spooktacular. #aldiwineclub https://t.co/Fo3UwrztLm'

# %%
orig[orig.tweet_id == 22733.0]['text'].values[0]
# Out:
# '@120970 Glad you enjoyed it, Nicola! 🎃🍷'
