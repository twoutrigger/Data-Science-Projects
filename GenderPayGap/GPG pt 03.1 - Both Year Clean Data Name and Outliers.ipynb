# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# steps done:
# Uppercase
# remove duplicates
# remove outliers
# name comparison

# %%
aorig = pd.read_csv('UK Gender Pay Gap Data - 2017 to 2018.csv', header=0)
borig = pd.read_csv('UK Gender Pay Gap Data - 2018 to 2019.csv', header=0)

print(aorig.shape)
print(borig.shape)
# Out:
# (10560, 25)
# (10776, 25)

# %%
aorig.head(3)
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...      00226143    85310
# 1  19 Smith's Place,\r\nLeith Walk,\r\nEdinburgh,...      SC016876    47730
# 2  Fusion Point,\r\nDumballs Road,\r\nCardiff,\r\...      03951948    61900
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# 2                    1.7                      2.8                  13.1
#
#    DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# 0                     0.0               0.0                 0.0
# 1                    37.5              15.6                66.7
# 2                    13.6              70.0                57.0
#
#           ...           FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0         ...                                50.8             51.5
# 1         ...                                89.7             18.1
# 2         ...                                50.0             58.0
#
#    FemaleTopQuartile                    CompanyLinkToGPGInfo  \
# 0               48.5  https://www.bryanston.co.uk/employment
# 1               81.9                                     NaN
# 2               42.0                                     NaN
#
#                                  ResponsiblePerson  EmployerSize  \
# 0  Nick McRobb (Bursar and Clerk to the Governors)    500 to 999
# 1                  Philip Galt (Managing Director)    250 to 499
# 2                 Emma Crowe (VP, Human Resources)    500 to 999
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 0       "Bryanston School",Incorporated                      False
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED                      False
# 2                           118 LIMITED                      False
#
#                DueDate        DateSubmitted
# 0  05/04/2018 00:00:00  27/03/2018 11:42:49
# 1  05/04/2018 00:00:00  28/03/2018 16:44:25
# 2  05/04/2018 00:00:00  27/03/2018 19:10:41
#
# [3 rows x 25 columns]

# %%
borig.head(3)
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...      00226143    85310
# 1  19 Smith's Place,\r\nLeith Walk,\r\nEdinburgh,...      SC016876    47730
# 2  Fusion Point,\r\nDumballs Road,\r\nCardiff,\r\...      03951948    61900
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   19.6                     32.5                   NaN
# 1                    7.7                     -4.2                  23.7
# 2                    7.7                     12.7                  11.3
#
#    DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# 0                     NaN               0.0                 0.0
# 1                   -75.2              22.2                82.0
# 2                    10.9              67.0                52.0
#
#           ...           FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0         ...                                55.1             53.3
# 1         ...                                88.4             20.3
# 2         ...                                50.0             56.0
#
#    FemaleTopQuartile                    CompanyLinkToGPGInfo  \
# 0               46.7  https://www.bryanston.co.uk/employment
# 1               79.7                                     NaN
# 2               44.0                                     NaN
#
#                             ResponsiblePerson  EmployerSize  \
# 0  Michael McGovern (Chief Operating Officer)    500 to 999
# 1             Philip Galt (Managing Director)    250 to 499
# 2                        Michael Graham (CEO)  1000 to 4999
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 0       "Bryanston School",Incorporated                      False
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED                      False
# 2                           118 LIMITED                      False
#
#                DueDate        DateSubmitted
# 0  05/04/2019 00:00:00  03/04/2019 13:43:34
# 1  05/04/2019 00:00:00  01/04/2019 12:37:21
# 2  05/04/2019 00:00:00  06/03/2019 13:26:24
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Uppercase

# %%
aorig['EmployerName'] = aorig['EmployerName'].str.upper()
borig['EmployerName'] = borig['EmployerName'].str.upper()

# %% [markdown]
# ## Remove quotation marks

# %%
aorig['EmployerName'] = aorig['EmployerName'].str.replace('"', '')
borig['EmployerName'] = borig['EmployerName'].str.replace('"', '')

aorig.head(2)
# Out:
#                          EmployerName  \
# 0       BRYANSTON SCHOOL,INCORPORATED
# 1  RED BAND CHEMICAL COMPANY, LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...      00226143    85310
# 1  19 Smith's Place,\r\nLeith Walk,\r\nEdinburgh,...      SC016876    47730
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
#
#    DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# 0                     0.0               0.0                 0.0
# 1                    37.5              15.6                66.7
#
#           ...           FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0         ...                                50.8             51.5
# 1         ...                                89.7             18.1
#
#    FemaleTopQuartile                    CompanyLinkToGPGInfo  \
# 0               48.5  https://www.bryanston.co.uk/employment
# 1               81.9                                     NaN
#
#                                  ResponsiblePerson  EmployerSize  \
# 0  Nick McRobb (Bursar and Clerk to the Governors)    500 to 999
# 1                  Philip Galt (Managing Director)    250 to 499
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 0       "Bryanston School",Incorporated                      False
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED                      False
#
#                DueDate        DateSubmitted
# 0  05/04/2018 00:00:00  27/03/2018 11:42:49
# 1  05/04/2018 00:00:00  28/03/2018 16:44:25
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Remove trailing space

# %%
aorig['EmployerName'] = aorig['EmployerName'].str.strip()
borig['EmployerName'] = borig['EmployerName'].str.strip()

# %% [markdown]
# # Remove 2017 duplicates

# %%
aorig['EmployerName'].value_counts()[:5]
# Out:
# TALBOT UNDERWRITING SERVICES LTD    2
# P.D. HOOK (BREEDERS) LIMITED        1
# HUGHES ELECTRICAL LIMITED           1
# DOUGLAS PARK LIMITED                1
# SCOTT DUNN LIMITED                  1
# Name: EmployerName, dtype: int64

# %%
aorig[aorig['EmployerName'] == 'TALBOT UNDERWRITING SERVICES LTD']
# Out:
#                           EmployerName  \
# 8744  TALBOT UNDERWRITING SERVICES LTD
# 8745  TALBOT UNDERWRITING SERVICES LTD
#
#                                                 Address CompanyNumber  \
# 8744     60 Threadneedle Street,\r\nLondon,\r\nEC2R 8HP      03043304
# 8745  60 Threadneedle Street,\r\nLondon,\r\nUnited K...      00100010
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 8744      NaN                   35.0                     28.0
# 8745    82990                   35.0                     28.0
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 8744                  78.0                    47.0              96.0
# 8745                  78.0                    47.0              96.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 8744                91.0         ...                                28.0
# 8745                91.0         ...                                28.0
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 8744             85.0               15.0
# 8745             85.0               15.0
#
#                                    CompanyLinkToGPGInfo  \
# 8744  https://www.validusholdings.com/media/137680/t...
# 8745  https://www.validusholdings.com/about-us/resou...
#
#                                       ResponsiblePerson  EmployerSize  \
# 8744  Dominic Scarlett (Global Director of Human Res...    250 to 499
# 8745  Dominic Scarlett (Chief Corporate Services Off...    250 to 499
#
#                            CurrentName  SubmittedAfterTheDeadline  \
# 8744           TALBOT UNDERWRITING LTD                      False
# 8745  Talbot Underwriting Services Ltd                      False
#
#                   DueDate        DateSubmitted
# 8744  05/04/2018 00:00:00  04/04/2018 10:44:48
# 8745  05/04/2018 00:00:00  03/04/2019 12:59:21
#
# [2 rows x 25 columns]

# %%
aorig.drop(8744, inplace=True)

# %% [markdown]
# ## Remove 2018 duplicates

# %%
borig['EmployerName'].value_counts()[:5]
# Out:
# GROUP EMPLOYMENT SERVICES LIMITED    2
# CHOICE SUPPORT                       2
# ITC INFOTECH LIMITED                 2
# MACKAYS STORES GROUP LIMITED         1
# REDDE PLC                            1
# Name: EmployerName, dtype: int64

# %%
borig[borig['EmployerName'] == 'CHOICE SUPPORT']
# Out:
#         EmployerName                                            Address  \
# 1985  CHOICE SUPPORT  100 Westminster Bridge Road,\r\nLondon,\r\nUni...
# 1986  CHOICE SUPPORT  One Hermitage Court,\r\nHermitage Lane,\r\nMai...
#
#      CompanyNumber SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 1985      02189556    87200                   -1.6                      1.5
# 1986      08971493    87200                    9.7                      3.6
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 1985                   NaN                     NaN               0.0
# 1986                   NaN                     NaN               0.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 1985                 0.0         ...                                75.0
# 1986                 0.0         ...                                77.0
#
#       MaleTopQuartile  FemaleTopQuartile  CompanyLinkToGPGInfo  \
# 1985             25.0               75.0                   NaN
# 1986             31.0               69.0                   NaN
#
#                              ResponsiblePerson  EmployerSize     CurrentName  \
# 1985  Mark Ferry (Director of Human Resources)  1000 to 4999  Choice Support
# 1986  Mark Ferry (Director of Human Resources)  1000 to 4999  CHOICE SUPPORT
#
#       SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 1985                      False  05/04/2019 00:00:00  04/04/2019 20:27:02
# 1986                      False  05/04/2019 00:00:00  04/04/2019 20:43:18
#
# [2 rows x 25 columns]

# %%
print(borig.at[1986, 'EmployerName'])
borig.at[1986, 'EmployerName'] = 'CHOICE SUPPORT LONDON'
print(borig.at[1986, 'EmployerName'])
# Out:
# CHOICE SUPPORT
# CHOICE SUPPORT LONDON

# %%
borig[(borig['EmployerName'] == 'GROUP EMPLOYMENT SERVICES LIMITED') | (borig['EmployerName'] == 'ITC INFOTECH LIMITED') ]
# Out:
#                            EmployerName  \
# 4015  GROUP EMPLOYMENT SERVICES LIMITED
# 4016  GROUP EMPLOYMENT SERVICES LIMITED
# 4813               ITC INFOTECH LIMITED
# 4814               ITC INFOTECH LIMITED
#
#                                                 Address CompanyNumber  \
# 4015  Venlaw,\r\n349 Bath Street,\r\nGlasgow,\r\nLan...      SC352278
# 4016  Venlaw,\r\n349 Bath Street,\r\nGlasgow,\r\nLan...      SC352278
# 4813  Building 5 Caldecotte Lake Drive,\r\nCaldecott...      02777705
# 4814  Building 5 Caldecotte Lake Drive,\r\nCaldecott...      02777705
#
#                                  SicCodes  DiffMeanHourlyPercent  \
# 4015                                82990                   -1.2
# 4016                                82990                   -1.2
# 4813  62012,\r\n62020,\r\n62030,\r\n62090                   12.2
# 4814  62012,\r\n62020,\r\n62030,\r\n62090                   12.2
#
#       DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 4015                     -0.9                   NaN                     NaN
# 4016                     -0.9                   NaN                     NaN
# 4813                      4.6                  19.0                    52.4
# 4814                      4.6                  19.0                    52.4
#
#       MaleBonusPercent  FemaleBonusPercent         ...           \
# 4015               0.0                 0.0         ...
# 4016               0.0                 0.0         ...
# 4813              63.9                45.8         ...
# 4814              63.9                45.8         ...
#
#       FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile  \
# 4015                       11.7             89.0               11.0
# 4016                       11.7             89.0               11.0
# 4813                       10.5             89.5               10.5
# 4814                       10.5             89.5               10.5
#
#                                    CompanyLinkToGPGInfo  \
# 4015  https://www.securigroup.co.uk/news/gender-pay-...
# 4016  https://www.securigroup.co.uk/news/gender-pay-...
# 4813                                                NaN
# 4814  https://www.itcinfotech.com/docs/resources/Gen...
#
#                       ResponsiblePerson   EmployerSize  \
# 4015           Sarah Grant (HR Manager)   1000 to 4999
# 4016           Sarah Grant (HR Manager)   1000 to 4999
# 4813  Hardeep Singh Garewal (President)     250 to 499
# 4814  Hardeep Singh Garewal (President)  Less than 250
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 4015  GROUP EMPLOYMENT SERVICES LIMITED                      False
# 4016  GROUP EMPLOYMENT SERVICES LIMITED                      False
# 4813               ITC INFOTECH LIMITED                      False
# 4814               ITC INFOTECH LIMITED                      False
#
#                   DueDate        DateSubmitted
# 4015  05/04/2019 00:00:00  03/04/2019 09:56:07
# 4016  05/04/2019 00:00:00  03/04/2019 09:56:26
# 4813  05/04/2019 00:00:00  04/04/2019 16:59:13
# 4814  05/04/2019 00:00:00  05/04/2019 09:41:39
#
# [4 rows x 25 columns]

# %%
borig.drop(4813, inplace=True)
borig.drop(4015, inplace=True)

# %% [markdown]
# ## Remove 2017 outliers

# %%
aorig.loc[aorig['DiffMedianHourlyPercent'].nlargest(5).index]
# Out:
#                      EmployerName  \
# 8046   SHREWSBURY ACADEMIES TRUST
# 5970       MINT PAY SOLUTIONS LTD
# 9946      VIDA HEALTHCARE LIMITED
# 1192          BOUX AVENUE LIMITED
# 5607  MALLING HEALTH (UK) LIMITED
#
#                                                 Address CompanyNumber  \
# 8046  Shrewsbury Academies Trust,\r\nMount Pleasant ...      08407961
# 5970  A&L,\r\nWindfall House D1, The Courtyard,\r\nA...      08189359
# 9946  The Power House, 156 Hookstone Drive,\r\nHarro...      09106261
# 1192  1 St Georges Road,\r\nWimbledon,\r\nLondon,\r\...      07191520
# 5607  10th Floor 1 City Approach Albert Street,\r\nE...      07034946
#
#                              SicCodes  DiffMeanHourlyPercent  \
# 8046  1,\r\n85100,\r\n85200,\r\n85310                   47.4
# 5970                  78200,\r\n82990                   94.0
# 9946                            41100                   68.3
# 1192                            47710                   75.4
# 5607                            82990                   51.6
#
#       DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 8046                    121.2                   0.0                     0.0
# 5970                     97.0                   0.0                     0.0
# 9946                     79.8                   0.0                     0.0
# 1192                     75.7                -100.0                  -100.0
# 5607                     73.0                  33.3                    33.3
#
#       MaleBonusPercent  FemaleBonusPercent         ...           \
# 8046               0.0                 0.0         ...
# 5970               0.0                 0.0         ...
# 9946               0.0                 0.0         ...
# 1192               0.0                81.0         ...
# 5607               2.7                 0.4         ...
#
#       FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile  \
# 8046                       80.3             25.8               74.2
# 5970                        4.0             99.0                1.0
# 9946                       50.0             33.0               67.0
# 1192                      100.0              9.0               91.0
# 5607                       94.3             32.9               67.1
#
#            CompanyLinkToGPGInfo                    ResponsiblePerson  \
# 8046            http://sat.coop                                  NaN
# 5970                        NaN  Mo El-Bassyouni (Managing Director)
# 9946                        NaN    JAMES RYCROFT (MANAGING DIRECTOR)
# 1192  http://www.bouxavenue.com      Laura Keane (Group HR Director)
# 5607                        NaN                  Richard Power (CEO)
#
#       EmployerSize                  CurrentName  SubmittedAfterTheDeadline  \
# 8046    250 to 499   Shrewsbury Academies Trust                       True
# 5970    250 to 499       MINT PAY SOLUTIONS LTD                       True
# 9946    250 to 499      VIDA HEALTHCARE LIMITED                       True
# 1192    500 to 999          BOUX AVENUE LIMITED                      False
# 5607    250 to 499  MALLING HEALTH (UK) LIMITED                      False
#
#                   DueDate        DateSubmitted
# 8046  31/03/2018 00:00:00  16/04/2018 14:22:27
# 5970  05/04/2018 00:00:00  02/07/2018 11:30:39
# 9946  05/04/2018 00:00:00  04/05/2018 15:13:33
# 1192  05/04/2018 00:00:00  03/04/2018 15:45:54
# 5607  05/04/2018 00:00:00  28/02/2018 10:31:58
#
# [5 rows x 25 columns]

# %%
borig[borig['EmployerName'] == 'SHREWSBURY ACADEMIES TRUST']
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
borig[borig['CompanyNumber'] == '08407961']
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
borig[borig['EmployerName'] == 'MINT PAY SOLUTIONS LTD']
# Out:
#                 EmployerName  \
# 6116  MINT PAY SOLUTIONS LTD
#
#                                                 Address CompanyNumber  \
# 6116  A&L,\r\nWindfall House D1, The Courtyard,\r\nA...      08189359
#
#              SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 6116  42120,\r\n82990                   59.0                     65.0
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 6116                   0.0                     0.0               0.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 6116                 0.0         ...                                 4.0
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 6116             99.0                1.0
#
#                                    CompanyLinkToGPGInfo  \
# 6116  https://www.mintpaysolutions.co.uk/index.php/g...
#
#                              ResponsiblePerson  EmployerSize  \
# 6116  Mohamed El-Bassyouni (Managing Director)    250 to 499
#
#                  CurrentName  SubmittedAfterTheDeadline              DueDate  \
# 6116  MINT PAY SOLUTIONS LTD                      False  05/04/2019 00:00:00
#
#             DateSubmitted
# 6116  14/03/2019 12:27:09
#
# [1 rows x 25 columns]

# %%
# dropped SHREWSBURY ACADEMIES TRUST; not in 2018 data
aorig.drop(8046, inplace=True)

# %%
aorig.loc[aorig['DiffMedianHourlyPercent'].nsmallest(5).index]
# Out:
#                        EmployerName  \
# 838                BAR 2010 LIMITED
# 4496               INBRELLA LIMITED
# 7302  RANDSTAD HR SOLUTIONS LIMITED
# 7017  PLUS PAYROLL SERVICES LIMITED
# 2340  CREST PLUS OPERATIONS LIMITED
#
#                                                 Address CompanyNumber  \
# 838   Mitre House,\r\nNorth Park Road,\r\nHarrogate,...      04172269
# 4496  5th Floor Hampton By Hilton,\r\n42-50 Kimpton ...      08274708
# 7302  450 Capability Green,\r\nLuton,\r\nBedfordshir...      02904400
# 7017  5th Floor Hampton By Hilton,\r\n42-50 Kimpton ...      08811568
# 2340  Suite A1, The Quadrant Mercury Court,\r\nChest...      04620624
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 838     70229                 -148.0                   -196.5
# 4496    69201                 -150.0                   -164.0
# 7302    78200                  -21.3                   -103.6
# 7017    78109                  -64.4                   -100.1
# 2340    74909                  -66.5                    -85.2
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 838                    0.0                     0.0               0.0
# 4496                   0.0                     0.0               0.0
# 7302                  31.6                    -2.0               2.9
# 7017                   0.0                     0.0               0.0
# 2340                   0.0                     0.0               0.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 838                  0.0         ...                                 0.0
# 4496                 0.0         ...                                25.9
# 7302                 1.2         ...                                68.7
# 7017                 0.0         ...                                 9.9
# 2340                 0.0         ...                                 3.2
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 838              99.5                0.5
# 4496             96.1                3.9
# 7302             31.1               68.9
# 7017             30.9               69.1
# 2340             81.2               18.8
#
#                                    CompanyLinkToGPGInfo  \
# 838                                                 NaN
# 4496                                                NaN
# 7302  https://www.randstad.co.uk/about-us/about-rand...
# 7017                                                NaN
# 2340       https://www.crestplus.com/pay-gap-report.pdf
#
#                       ResponsiblePerson  EmployerSize  \
# 838         Jason Hargreaves (Director)    250 to 499
# 4496     David Smith (Finance Director)    250 to 499
# 7302        Graham Trevor (HR Director)  1000 to 4999
# 7017     David Smith (Finance Director)    500 to 999
# 2340  Derek Harling (Managing Director)  1000 to 4999
#
#                         CurrentName  SubmittedAfterTheDeadline  \
# 838                BAR 2010 LIMITED                       True
# 4496               INBRELLA LIMITED                       True
# 7302  RANDSTAD HR SOLUTIONS LIMITED                      False
# 7017  PLUS PAYROLL SERVICES LIMITED                      False
# 2340  CREST PLUS OPERATIONS LIMITED                      False
#
#                   DueDate        DateSubmitted
# 838   05/04/2018 00:00:00  20/04/2018 13:08:53
# 4496  05/04/2018 00:00:00  17/09/2018 10:21:11
# 7302  05/04/2018 00:00:00  03/04/2018 19:51:29
# 7017  05/04/2018 00:00:00  04/04/2018 16:21:42
# 2340  05/04/2018 00:00:00  19/03/2018 14:01:24
#
# [5 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'BAR 2010 LIMITED') | (borig['CompanyNumber'] == '04172269')]
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'INBRELLA LIMITED') | (borig['CompanyNumber'] == '08274708')]
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'RANDSTAD HR SOLUTIONS LIMITED') | (borig['CompanyNumber'] == '02904400')]
# Out:
#                        EmployerName  \
# 7459  RANDSTAD HR SOLUTIONS LIMITED
#
#                                                 Address CompanyNumber  \
# 7459  450 Capability Green,\r\nLuton,\r\nBedfordshir...      02904400
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 7459    78200                  -15.2                    -87.1
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 7459                 -39.1                    -1.9              80.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 7459                67.0         ...                               100.0
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 7459             85.0               15.0
#
#                                    CompanyLinkToGPGInfo  \
# 7459  https://www.randstad.co.uk/about-us/about-rand...
#
#                 ResponsiblePerson  EmployerSize  \
# 7459  Graham Trevor (HR Director)  1000 to 4999
#
#                         CurrentName  SubmittedAfterTheDeadline  \
# 7459  RANDSTAD HR SOLUTIONS LIMITED                      False
#
#                   DueDate        DateSubmitted
# 7459  05/04/2019 00:00:00  29/03/2019 14:25:33
#
# [1 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'PLUS PAYROLL SERVICES LIMITED') | (borig['CompanyNumber'] == '08811568')]
# Out:
#                        EmployerName  \
# 7163  PLUS PAYROLL SERVICES LIMITED
#
#                                                 Address CompanyNumber  \
# 7163  5th Floor Hampton By Hilton,\r\n42-50 Kimpton ...      08811568
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 7163    78109                  -34.8                    -45.8
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 7163                   NaN                     NaN               0.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 7163                 0.0         ...                                13.3
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 7163             38.7               61.3
#
#                               CompanyLinkToGPGInfo       ResponsiblePerson  \
# 7163  http://pluspay.uk.com/gender-pay-gap-report/  David Smith (Director)
#
#       EmployerSize                    CurrentName  SubmittedAfterTheDeadline  \
# 7163    250 to 499  PLUS PAYROLL SERVICES LIMITED                      False
#
#                   DueDate        DateSubmitted
# 7163  05/04/2019 00:00:00  04/04/2019 15:14:50
#
# [1 rows x 25 columns]

# %%
aorig.drop(838, inplace=True)
aorig.drop(4496, inplace=True)

# %%
aorig.at[7302, 'DiffMedianHourlyPercent'] = -100.0
aorig.at[7017, 'DiffMedianHourlyPercent'] = -100.0

# %% [markdown]
# ## Remove 2018 outliers

# %%
borig.loc[borig['DiffMedianHourlyPercent'].nlargest(5).index]
# Out:
#                                  EmployerName  \
# 626               ASH & LACY FINISHES LIMITED
# 8923                T. CLASS SECURITY LIMITED
# 10162                 VIDA HEALTHCARE LIMITED
# 8793             SUFFOLK GP FEDERATION C.I.C.
# 6406   NEW MILLENNIA PAYROLL SERVICES LIMITED
#
#                                                  Address CompanyNumber  \
# 626    Ash & Lacy House, Bromford Lane,\r\nWest Bromw...      10805186
# 8923   6 Skylines Village,\r\nLimeharbour,\r\nLondon,...      03622392
# 10162  The Power House, 156 Hookstone Drive,\r\nHarro...      09106261
# 8793   Riverside Clinic, 2 Landseer Road,\r\nIpswich,...      06183049
# 6406     1121 Ashton Old Road,\r\nManchester,\r\nM11 1AA      04254121
#
#       SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 626      32990                  100.0                    100.0
# 8923     80100                  100.0                    100.0
# 10162    41100                   70.4                     79.3
# 8793     86210                   59.5                     74.8
# 6406     78200                    6.6                     74.3
#
#        DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 626                     NaN                     NaN               0.0
# 8923                  100.0                   100.0             100.0
# 10162                   0.0                     0.0               0.0
# 8793                    NaN                     NaN               0.0
# 6406                   36.6                    60.0               2.0
#
#        FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 626                   0.0         ...                                 0.0
# 8923                100.0         ...                                50.0
# 10162                 0.0         ...                                67.0
# 8793                  0.0         ...                                87.5
# 6406                  2.2         ...                                10.6
#
#        MaleTopQuartile  FemaleTopQuartile  \
# 626              100.0                0.0
# 8923              50.0               50.0
# 10162             50.0               50.0
# 8793              37.5               62.5
# 6406              92.1                7.9
#
#                                     CompanyLinkToGPGInfo  \
# 626    http://www.ashandlacy.com/construction/about-u...
# 8923                              https://t-class.co.uk/
# 10162                                                NaN
# 8793                          https://suffolkfed.org.uk/
# 6406                                                 NaN
#
#                             ResponsiblePerson  EmployerSize  \
# 626           Jonathan Evans (CEO & Chairman)    250 to 499
# 8923            Demi Larner (Vetting Officer)    250 to 499
# 10162       James Rycroft (Managing Director)    250 to 499
# 8793   Katrina Pollard (Financial Controller)    250 to 499
# 6406                Nicholas Hynes (Director)  1000 to 4999
#
#                                   CurrentName  SubmittedAfterTheDeadline  \
# 626               ASH & LACY FINISHES LIMITED                      False
# 8923                T. CLASS SECURITY LIMITED                       True
# 10162                 VIDA HEALTHCARE LIMITED                      False
# 8793             SUFFOLK GP FEDERATION C.I.C.                      False
# 6406   NEW MILLENNIA PAYROLL SERVICES LIMITED                      False
#
#                    DueDate        DateSubmitted
# 626    05/04/2019 00:00:00  03/04/2019 08:56:20
# 8923   05/04/2019 00:00:00  08/05/2019 11:08:24
# 10162  05/04/2019 00:00:00  18/03/2019 11:10:56
# 8793   05/04/2019 00:00:00  26/03/2019 13:36:06
# 6406   05/04/2019 00:00:00  27/03/2019 11:45:19
#
# [5 rows x 25 columns]

# %%
aorig[(aorig['EmployerName'] == 'ASH & LACY FINISHES LIMITED') | (aorig['CompanyNumber'] == '10805186')]
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
aorig[(aorig['EmployerName'] == 'T. CLASS SECURITY LIMITED') | (aorig['CompanyNumber'] == '03622392')]
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
# dropped ASH & LACY FINISHES LIMITED; not in 2017 data
borig.drop(626, inplace=True)
# dropped T. CLASS SECURITY LIMITED; not in 2017 data
borig.drop(8923, inplace=True)

# %%
borig.loc[borig['DiffMedianHourlyPercent'].nsmallest(5).index]
# Out:
#                         EmployerName  \
# 7288              PRIME LIFE LIMITED
# 7497             REALISE FUTURES CIC
# 7459   RANDSTAD HR SOLUTIONS LIMITED
# 6442   NEWSQUEST MEDIA GROUP LIMITED
# 10706    YELLOW DOT HOLDINGS LIMITED
#
#                                                  Address CompanyNumber  \
# 7288   Caenarvon House,\r\n121 Knighton Church Road,\...      02779611
# 7497   Realise Futures Cic,\r\nLovetofts Drive,\r\nIp...      07828443
# 7459   450 Capability Green,\r\nLuton,\r\nBedfordshir...      02904400
# 6442   Loudwater Mill,\r\nStation Road,\r\nHigh Wycom...      01676637
# 10706  2 Crown Court,\r\nCrown Way,\r\nRushden,\r\nNo...      11159598
#
#                         SicCodes  DiffMeanHourlyPercent  \
# 7288                       86900                    5.5
# 7497   56102,\r\n82990,\r\n85590                  -39.5
# 7459                       78200                  -15.2
# 6442                       58130                  -11.0
# 10706                      64209                  -39.7
#
#        DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 7288                     -92.3                 -25.7                   -93.0
# 7497                     -90.7                   0.0                     0.0
# 7459                     -87.1                 -39.1                    -1.9
# 6442                     -82.0                   1.2                   -42.7
# 10706                    -80.7                 -66.0                  -636.4
#
#        MaleBonusPercent  FemaleBonusPercent         ...           \
# 7288                1.0                 1.6         ...
# 7497                0.0                 0.0         ...
# 7459               80.0                67.0         ...
# 6442               11.0                25.0         ...
# 10706              66.7                64.7         ...
#
#        FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile  \
# 7288                        84.8             19.4               80.6
# 7497                        78.8              9.5               90.5
# 7459                       100.0             85.0               15.0
# 6442                        58.0             53.0               47.0
# 10706                       98.8              2.4               97.6
#
#                                     CompanyLinkToGPGInfo  \
# 7288                        https://www.prime-life.co.uk
# 7497                      https://www.realisefutures.org
# 7459   https://www.randstad.co.uk/about-us/about-rand...
# 6442   http://www.newsquest.co.uk/wp-content/uploads/...
# 10706  https://www.brighthorizons.co.uk/statutory-inf...
#
#                             ResponsiblePerson    EmployerSize  \
# 7288         Jay Hairsine (Company Secretary)    1000 to 4999
# 7497   Ramon Garcia (Human Resources Manager)      250 to 499
# 7459              Graham Trevor (HR Director)    1000 to 4999
# 6442       Tracey Olaleye (Group HR Director)  5000 to 19,999
# 10706              John Handley (HR Director)      250 to 499
#
#                          CurrentName  SubmittedAfterTheDeadline  \
# 7288              PRIME LIFE LIMITED                      False
# 7497             Realise Futures Cic                      False
# 7459   RANDSTAD HR SOLUTIONS LIMITED                      False
# 6442   NEWSQUEST MEDIA GROUP LIMITED                      False
# 10706    YELLOW DOT HOLDINGS LIMITED                      False
#
#                    DueDate        DateSubmitted
# 7288   05/04/2019 00:00:00  28/03/2019 12:36:23
# 7497   05/04/2019 00:00:00  15/03/2019 11:21:14
# 7459   05/04/2019 00:00:00  29/03/2019 14:25:33
# 6442   05/04/2019 00:00:00  02/04/2019 11:47:06
# 10706  05/04/2019 00:00:00  15/03/2019 15:24:35
#
# [5 rows x 25 columns]

# %%
# no smallest hour% removed for 2018 GPG consistency

# %% [markdown]
# ## Remove 2017 mean outliers

# %%
aorig.loc[aorig['DiffMeanHourlyPercent'].nlargest(5).index]
# Out:
#                                            EmployerName  \
# 5950                              MILLWALL HOLDINGS PLC
# 5970                             MINT PAY SOLUTIONS LTD
# 8561                   STOKE CITY FOOTBALL CLUB LIMITED
# 1447  BURNLEY FOOTBALL & ATHLETIC COMPANY, LIMITED(THE)
# 8666  SWANSEA CITY ASSOCIATION FOOTBALL CLUB LIMITED...
#
#                                                 Address CompanyNumber  \
# 5950        The Den, Zampa Road,\r\nLondon,\r\nSE16 3LN      02355508
# 5970  A&L,\r\nWindfall House D1, The Courtyard,\r\nA...      08189359
# 8561  Bet365 Stadium Stanley Matthews Way,\r\nStoke-...      00099885
# 1447     Turf Moor, Burnley,\r\nLancashire,\r\nBB10 4BX      00054222
# 8666  The Liberty Stadium,\r\nLandore,\r\nSwansea,\r...      00123414
#
#              SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 5950  93110,\r\n93199                  159.0                      0.0
# 5970  78200,\r\n82990                   94.0                     97.0
# 8561            93120                   92.5                     30.5
# 1447            93110                   88.4                     15.6
# 8666            93120                   87.8                     26.4
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 5950                  99.0                    99.0              29.0
# 5970                   0.0                     0.0               0.0
# 8561                  98.9                    93.7              28.6
# 1447                  98.2                    36.0              46.3
# 8666                  97.2                    91.1              23.2
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 5950                 3.0         ...                                31.0
# 5970                 0.0         ...                                 4.0
# 8561                17.5         ...                                22.6
# 1447                11.6         ...                                46.0
# 8666                16.0         ...                                18.6
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 5950             64.0               36.0
# 5970             99.0                1.0
# 8561             97.8                2.2
# 1447             90.6                9.4
# 8666             93.8                6.2
#
#                                    CompanyLinkToGPGInfo  \
# 5950                                                NaN
# 5970                                                NaN
# 8561                                                NaN
# 1447                                                NaN
# 8666  https://www.swanseacity.com/news/gender-pay-ga...
#
#                                    ResponsiblePerson   EmployerSize  \
# 5950            Gina Walas (Human Resources Manager)  Less than 250
# 5970             Mo El-Bassyouni (Managing Director)     250 to 499
# 8561                  John Pelling (Head of Finance)     250 to 499
# 1447           Ian Hargreaves (Financial Controller)     500 to 999
# 8666  CHRISTOPHER PEARLMAN (CHIEF OPERATING OFFICER)     250 to 499
#
#                                             CurrentName  \
# 5950                              MILLWALL HOLDINGS PLC
# 5970                             MINT PAY SOLUTIONS LTD
# 8561                   STOKE CITY FOOTBALL CLUB LIMITED
# 1447   BURNLEY FOOTBALL & ATHLETIC COMPANY,LIMITED(THE)
# 8666  SWANSEA CITY ASSOCIATION FOOTBALL CLUB LIMITED...
#
#       SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 5950                      False  05/04/2018 00:00:00  05/04/2018 13:57:48
# 5970                       True  05/04/2018 00:00:00  02/07/2018 11:30:39
# 8561                      False  05/04/2018 00:00:00  29/03/2018 13:42:37
# 1447                      False  05/04/2018 00:00:00  29/03/2018 14:02:54
# 8666                      False  05/04/2018 00:00:00  29/03/2018 16:10:08
#
# [5 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'MILLWALL HOLDINGS PLC') | (borig['CompanyNumber'] == '02355508')]
# Out:
# Empty DataFrame
# Columns: [EmployerName, Address, CompanyNumber, SicCodes, DiffMeanHourlyPercent, DiffMedianHourlyPercent, DiffMeanBonusPercent, DiffMedianBonusPercent, MaleBonusPercent, FemaleBonusPercent, MaleLowerQuartile, FemaleLowerQuartile, MaleLowerMiddleQuartile, FemaleLowerMiddleQuartile, MaleUpperMiddleQuartile, FemaleUpperMiddleQuartile, MaleTopQuartile, FemaleTopQuartile, CompanyLinkToGPGInfo, ResponsiblePerson, EmployerSize, CurrentName, SubmittedAfterTheDeadline, DueDate, DateSubmitted]
# Index: []
#
# [0 rows x 25 columns]

# %%
aorig.drop(5950, inplace=True)

# %%
aorig.loc[aorig['DiffMeanHourlyPercent'].nsmallest(5).index]
# Out:
#                         EmployerName  \
# 2148  COMPLETE CARE HOLDINGS LIMITED
# 9767  UNITY CONTRACTING SERVICES LTD
# 2340   CREST PLUS OPERATIONS LIMITED
# 7017   PLUS PAYROLL SERVICES LIMITED
# 5685            MARS FOOD UK LIMITED
#
#                                                 Address CompanyNumber  \
# 2148  1310 Solihull Parkway,\r\nBirmingham Business ...      04522416
# 9767  164-168 Cricklewood Broadway,\r\nLondon,\r\nUn...      05952128
# 2340  Suite A1, The Quadrant Mercury Court,\r\nChest...      04620624
# 7017  5th Floor Hampton By Hilton,\r\n42-50 Kimpton ...      08811568
# 5685  3d Dundee Road,\r\nSlough,\r\nBerkshire,\r\nUn...      06649971
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 2148    86900                 -400.0                    -11.0
# 9767    43999                  -69.4                     -3.4
# 2340    74909                  -66.5                    -85.2
# 7017    78109                  -64.4                   -100.0
# 5685    10890                  -51.5                    -18.3
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 2148                 100.0                   100.0               1.0
# 9767                  45.1                     6.2              10.2
# 2340                   0.0                     0.0               0.0
# 7017                   0.0                     0.0               0.0
# 5685                -301.8                  -157.5              96.6
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 2148                 0.0         ...                                60.0
# 9767                 8.3         ...                                 1.4
# 2340                 0.0         ...                                 3.2
# 7017                 0.0         ...                                 9.9
# 5685                97.9         ...                                39.1
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 2148              7.0               93.0
# 9767             40.0               60.0
# 2340             81.2               18.8
# 7017             30.9               69.1
# 5685             59.4               40.6
#
#                                    CompanyLinkToGPGInfo  \
# 2148                                                NaN
# 9767                                                NaN
# 2340       https://www.crestplus.com/pay-gap-report.pdf
# 7017                                                NaN
# 5685  http://www.mars.com/uk/en/about-us/gender-pay-...
#
#                                       ResponsiblePerson  EmployerSize  \
# 2148                 Steve Jeffers (Director of People)    250 to 499
# 9767              Bhavin Ruparelia (Operations Manager)    250 to 499
# 2340                  Derek Harling (Managing Director)  1000 to 4999
# 7017                     David Smith (Finance Director)    500 to 999
# 5685  Justine Weston (People and Organisation Manage...    250 to 499
#
#                          CurrentName  SubmittedAfterTheDeadline  \
# 2148  COMPLETE CARE HOLDINGS LIMITED                      False
# 9767  Unity Contracting Services Ltd                      False
# 2340   CREST PLUS OPERATIONS LIMITED                      False
# 7017   PLUS PAYROLL SERVICES LIMITED                      False
# 5685            MARS FOOD UK LIMITED                      False
#
#                   DueDate        DateSubmitted
# 2148  05/04/2018 00:00:00  02/04/2018 19:25:17
# 9767  05/04/2018 00:00:00  04/04/2018 19:37:32
# 2340  05/04/2018 00:00:00  19/03/2018 14:01:24
# 7017  05/04/2018 00:00:00  04/04/2018 16:21:42
# 5685  05/04/2018 00:00:00  29/03/2018 16:35:15
#
# [5 rows x 25 columns]

# %%
borig[(borig['EmployerName'] == 'COMPLETE CARE HOLDINGS LIMITED') | (borig['CompanyNumber'] == '04522416')]
# Out:
#                         EmployerName  \
# 2217  COMPLETE CARE HOLDINGS LIMITED
#
#                                                 Address CompanyNumber  \
# 2217  1310 Solihull Parkway,\r\nBirmingham Business ...      04522416
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 2217    86900                   26.7                    -11.0
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 2217                   0.0                     0.0               1.1
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 2217                 0.7         ...                                92.0
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 2217             18.0               82.0
#
#                                    CompanyLinkToGPGInfo  \
# 2217  http://www.completecare.co.uk/getmedia/52d5dee...
#
#                        ResponsiblePerson  EmployerSize  \
# 2217  Steve Jeffers (Director of People)    250 to 499
#
#                          CurrentName  SubmittedAfterTheDeadline  \
# 2217  COMPLETE CARE HOLDINGS LIMITED                      False
#
#                   DueDate        DateSubmitted
# 2217  05/04/2019 00:00:00  03/04/2019 12:35:58
#
# [1 rows x 25 columns]

# %%
aorig.at[2148, 'DiffMeanHourlyPercent'] = -40.0

# %% [markdown]
# ## Remove 2018 mean outliers

# %%
# No mean outliers to be removed
borig.loc[borig['DiffMeanHourlyPercent'].nlargest(5).index]
# Out:
#                                            EmployerName  \
# 1219                                  BOOST PAY LIMITED
# 9320  THE HUDDERSFIELD TOWN ASSOCIATION FOOTBALL CLU...
# 8746                   STOKE CITY FOOTBALL CLUB LIMITED
# 1501   BURNLEY FOOTBALL & ATHLETIC COMPANY,LIMITED(THE)
# 8856  SWANSEA CITY ASSOCIATION FOOTBALL CLUB LIMITED...
#
#                                                 Address CompanyNumber  \
# 1219  Unit X, The Park The Street, Walberton,\r\nAru...      07123990
# 9320  The John Smith's Stadium Stadium Way, Leeds Ro...      01771361
# 8746  Bet365 Stadium Stanley Matthews Way,\r\nStoke-...      00099885
# 1501     Turf Moor, Burnley,\r\nLancashire,\r\nBB10 4BX      00054222
# 8856  The Liberty Stadium,\r\nLandore,\r\nSwansea,\r...      00123414
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 1219    78200                   93.1                     41.7
# 9320    93120                   91.7                     39.6
# 8746    93120                   91.5                     25.7
# 1501    93110                   87.6                     15.2
# 8856    93120                   87.6                     23.9
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 1219                   NaN                     NaN               0.0
# 9320                  95.5                    92.5              39.0
# 8746                  98.2                    53.5              31.0
# 1501                  98.4                    28.3              42.9
# 8856                  92.2                    83.7              17.4
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 1219                 0.0         ...                                 1.0
# 9320                28.2         ...                                28.6
# 8746                17.3         ...                                18.1
# 1501                10.3         ...                                51.8
# 8856                11.8         ...                                18.9
#
#       MaleTopQuartile  FemaleTopQuartile  CompanyLinkToGPGInfo  \
# 1219             99.3                0.7                   NaN
# 9320             90.5                9.5                   NaN
# 8746             94.7                5.3                   NaN
# 1501             83.1               16.9                   NaN
# 8856             94.3                5.7                   NaN
#
#                              ResponsiblePerson  EmployerSize  \
# 1219  Stephen Farrington (Operations Director)    500 to 999
# 9320   Julian Winter (Chief Executive Officer)    250 to 499
# 8746            John Pelling (Head of Finance)    250 to 499
# 1501     Ian Hargreaves (Financial Controller)    500 to 999
# 8856                CHRISTOPHER PEARLMAN (COO)    250 to 499
#
#                                             CurrentName  \
# 1219                                  BOOST PAY LIMITED
# 9320  THE HUDDERSFIELD TOWN ASSOCIATION FOOTBALL CLU...
# 8746                   STOKE CITY FOOTBALL CLUB LIMITED
# 1501   BURNLEY FOOTBALL & ATHLETIC COMPANY,LIMITED(THE)
# 8856  SWANSEA CITY ASSOCIATION FOOTBALL CLUB LIMITED...
#
#       SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 1219                       True  05/04/2019 00:00:00  14/04/2019 12:16:23
# 9320                      False  05/04/2019 00:00:00  28/03/2019 15:17:42
# 8746                      False  05/04/2019 00:00:00  29/03/2019 14:16:58
# 1501                      False  05/04/2019 00:00:00  28/03/2019 08:49:12
# 8856                      False  05/04/2019 00:00:00  04/04/2019 15:16:07
#
# [5 rows x 25 columns]

# %%
# No mean outliers to be removed
borig.loc[borig['DiffMeanHourlyPercent'].nsmallest(5).index]
# Out:
#                                    EmployerName  \
# 6080                         MIHOMECARE LIMITED
# 5601                           LONDONENERGY LTD
# 5548                      LOGOPLASTE UK LIMITED
# 5832                       MARS FOOD UK LIMITED
# 4024  GS YUASA BATTERY MANUFACTURING UK LIMITED
#
#                                                 Address CompanyNumber  \
# 6080  1310 Solihull Parkway Birmingham Business Park...      03203080
# 5601  Ecopark, Advent Way, Edmonton,\r\nLondon,\r\nN...      02732548
# 5548  Suite 7 East Wing,\r\n100 Longwater Avenue,\r\...      03834369
# 5832  3d Dundee Road,\r\nSlough,\r\nBerkshire,\r\nUn...      06649971
# 4024  Unit 22,\r\nRassau Industrial Estate,\r\nEbbw ...      01561536
#
#                        SicCodes  DiffMeanHourlyPercent  \
# 6080                      86900                  -98.7
# 5601  35110,\r\n38210,\r\n38320                  -65.1
# 5548  22220,\r\n70229,\r\n82990                  -65.0
# 5832                      10890                  -62.0
# 4024                      27200                  -56.2
#
#       DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 6080                      7.5                  61.6                    65.3
# 5601                    -11.7                  23.3                     0.0
# 5548                    -18.0                 -25.0                    22.0
# 5832                    -31.3                -439.1                   -73.9
# 4024                    -66.8                 100.0                   100.0
#
#       MaleBonusPercent  FemaleBonusPercent         ...           \
# 6080               3.5                 2.9         ...
# 5601              75.6                70.0         ...
# 5548              13.0                35.0         ...
# 5832              97.6                92.3         ...
# 4024               1.0                 0.0         ...
#
#       FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile  \
# 6080                       84.0             17.0               83.0
# 5601                        6.6             90.7                9.3
# 5548                        3.0             89.0               11.0
# 5832                       26.4             52.1               47.9
# 4024                        0.0             99.0                1.0
#
#                                    CompanyLinkToGPGInfo  \
# 6080  http://www.mihomecare.com/wp-content/uploads/2...
# 5601                                                NaN
# 5548                                                NaN
# 5832  https://www.mars.co.uk/docs/default-source/def...
# 4024  https://www.yuasa.co.uk/csr-policies-modern-sl...
#
#                                      ResponsiblePerson  EmployerSize  \
# 6080                Steve Jeffers (Director of People)  1000 to 4999
# 5601                 Mary Czulowski (Finance Director)    250 to 499
# 5548                Lisa Hillburn (HR Director Europe)    250 to 499
# 5832  Justine Weston (People and Organisation Manager)    250 to 499
# 4024                               Andrew Taylor (CEO)    250 to 499
#
#                                     CurrentName  SubmittedAfterTheDeadline  \
# 6080                         MIHOMECARE LIMITED                      False
# 5601                           LONDONENERGY LTD                      False
# 5548                      LOGOPLASTE UK LIMITED                      False
# 5832                       MARS FOOD UK LIMITED                      False
# 4024  GS YUASA BATTERY MANUFACTURING UK LIMITED                      False
#
#                   DueDate        DateSubmitted
# 6080  05/04/2019 00:00:00  03/04/2019 12:36:21
# 5601  05/04/2019 00:00:00  03/04/2019 05:53:13
# 5548  05/04/2019 00:00:00  09/04/2018 09:47:47
# 5832  05/04/2019 00:00:00  03/04/2019 19:05:45
# 4024  05/04/2019 00:00:00  04/04/2019 09:58:55
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Both years name consistency

# %%
a_in_b = 0

for i in list(aorig['EmployerName']):
    if i in list(borig['EmployerName']):
        a_in_b += 1
    
print(f'2017 in 2018: {a_in_b}')
print(f'2017 not in 2018: {aorig.shape[0] - a_in_b}')
# Out:
# 2017 in 2018: 9602
# 2017 not in 2018: 953

# %%
b_in_a = 0

for i in list(borig['EmployerName']):
    if i in list(aorig['EmployerName']):
        b_in_a += 1
    
print(f'2018 in 2017: {b_in_a}')
print(f'2018 not in 2017: {borig.shape[0] - b_in_a}')
# Out:
# 2018 in 2017: 9602
# 2018 not in 2017: 1170

# %%
repeat_list = []

for i in list(aorig['EmployerName']):
    if i in list(borig['EmployerName']):
        repeat_list.append(i)
    
print(f'List length: {len(repeat_list)}')
print(f'{repeat_list[:5]}')
# Out:
# List length: 9602
# ['BRYANSTON SCHOOL,INCORPORATED', 'RED BAND CHEMICAL COMPANY, LIMITED', '118 LIMITED', '123 EMPLOYEES LTD', '1610 LIMITED']

# %%
# checking aorig NaNs
diff_comp_num = []

for i in repeat_list:
    if (pd.isnull(aorig[aorig['EmployerName'] == i].CompanyNumber.item()) == False) & \
    (aorig[aorig['EmployerName'] == i].CompanyNumber.item() != \
    borig[borig['EmployerName'] == i].CompanyNumber.item()):
            diff_comp_num.append(i)
            
print(f'# of companies with different company numbers: {len(diff_comp_num)}')
print(f'{diff_comp_num[:5]}')
# Out:
# # of companies with different company numbers: 1
# ['CONNECT HEALTH LIMITED']

# %%
# checking borig NaNs
diff_comp_num = []

for i in repeat_list:
    if (pd.isnull(borig[borig['EmployerName'] == i].CompanyNumber.item()) == False) & \
    (aorig[aorig['EmployerName'] == i].CompanyNumber.item() != \
    borig[borig['EmployerName'] == i].CompanyNumber.item()):
            diff_comp_num.append(i)
            
print(f'# of companies with different company numbers: {len(diff_comp_num)}')
print(f'{diff_comp_num[:5]}')
# Out:
# # of companies with different company numbers: 2
# ['CONNECT HEALTH LIMITED', 'TAUNTON SCHOOL EDUCATIONAL CHARITY']

# %%
aorig[aorig['EmployerName'] == 'CONNECT HEALTH LIMITED']
# Out:
#                 EmployerName  \
# 2168  CONNECT HEALTH LIMITED
#
#                                                 Address CompanyNumber  \
# 2168  Q2 Benton Lane,,\r\nNewcastle Upon Tyne,\r\nEn...      09701038
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 2168    99999                   16.2                     20.5
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 2168                  -8.0                     0.0               2.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 2168                 4.0         ...                                52.0
#
#       MaleTopQuartile  FemaleTopQuartile            CompanyLinkToGPGInfo  \
# 2168             51.0               49.0  http://www.connecthealth.co.uk
#
#                 ResponsiblePerson  EmployerSize  \
# 2168  Lisa Davidson (HR Director)    250 to 499
#
#                                   CurrentName  SubmittedAfterTheDeadline  \
# 2168  CONNECT PHYSICAL HEALTH CENTRES LIMITED                      False
#
#                   DueDate        DateSubmitted
# 2168  05/04/2018 00:00:00  03/04/2018 08:37:57
#
# [1 rows x 25 columns]

# %%
borig[borig['EmployerName'] == 'CONNECT HEALTH LIMITED']
# Out:
#                 EmployerName  \
# 2240  CONNECT HEALTH LIMITED
#
#                                                 Address CompanyNumber  \
# 2240  The Light Box Quorum Business Park,\r\nBenton ...      02337692
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 2240    86900                   18.4                      9.4
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 2240                  48.2                     0.0               9.7
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 2240                 7.9         ...                                56.0
#
#       MaleTopQuartile  FemaleTopQuartile  \
# 2240             45.0               55.0
#
#                                    CompanyLinkToGPGInfo  \
# 2240  https://www.connecthealth.co.uk/wp-content/upl...
#
#                 ResponsiblePerson  EmployerSize             CurrentName  \
# 2240  Lisa Davidson (HR Director)    500 to 999  CONNECT HEALTH LIMITED
#
#       SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 2240                      False  05/04/2019 00:00:00  21/03/2019 10:39:12
#
# [1 rows x 25 columns]

# %%
print(aorig.at[2168, 'CompanyNumber'])
aorig.at[2168, 'CompanyNumber'] = '02337692'
print(aorig.at[2168, 'CompanyNumber'])
# Out:
# 09701038
# 02337692

# %%
aorig[aorig['EmployerName'] == 'TAUNTON SCHOOL EDUCATIONAL CHARITY']
# Out:
#                             EmployerName  \
# 8791  TAUNTON SCHOOL EDUCATIONAL CHARITY
#
#                                                 Address CompanyNumber  \
# 8791  Clerk To The Governors,\r\nTaunton,\r\nSomerse...           NaN
#
#      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 8791    85310                    9.4                     13.7
#
#       DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 8791                  23.9                    17.9               1.0
#
#       FemaleBonusPercent         ...           FemaleUpperMiddleQuartile  \
# 8791                 2.3         ...                                62.5
#
#       MaleTopQuartile  FemaleTopQuartile  CompanyLinkToGPGInfo  \
# 8791             44.1               55.9                   NaN
#
#                 ResponsiblePerson  EmployerSize  \
# 8791  Johanne Davey (HR Director)    500 to 999
#
#                              CurrentName  SubmittedAfterTheDeadline  \
# 8791  Taunton School Educational Charity                      False
#
#                   DueDate        DateSubmitted
# 8791  05/04/2018 00:00:00  27/03/2018 13:55:38
#
# [1 rows x 25 columns]

# %%
borig[borig['EmployerName'] == 'TAUNTON SCHOOL EDUCATIONAL CHARITY']
# Out:
#                             EmployerName  \
# 8991  TAUNTON SCHOOL EDUCATIONAL CHARITY
#
#                                                 Address CompanyNumber  \
# 8991  Taunton School, Staplegrove Road,\r\nTaunton,\...      04005803
#
#                        SicCodes  DiffMeanHourlyPercent  \
# 8991  85100,\r\n85200,\r\n85310                   12.4
#
#       DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 8991                     21.9                  -2.0                    -1.7
#
#       MaleBonusPercent  FemaleBonusPercent         ...           \
# 8991               2.0                 3.0         ...
#
#       FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile  \
# 8991                       58.4             40.6               59.4
#
#       CompanyLinkToGPGInfo            ResponsiblePerson  EmployerSize  \
# 8991                   NaN  Johanne Davey (HR Director)    500 to 999
#
#                              CurrentName  SubmittedAfterTheDeadline  \
# 8991  TAUNTON SCHOOL EDUCATIONAL CHARITY                      False
#
#                   DueDate        DateSubmitted
# 8991  05/04/2019 00:00:00  04/04/2019 09:12:38
#
# [1 rows x 25 columns]

# %%
print(aorig.at[8791, 'CompanyNumber'])
aorig.at[8791, 'CompanyNumber'] = '04005803'
print(aorig.at[8791, 'CompanyNumber'])
# Out:
# nan
# 04005803

# %%
# companies with same names are checked

# %%
diff_list = []

for i in list(aorig['EmployerName']):
    if i not in list(borig['EmployerName']):
        diff_list.append(i)
        
for i in list(borig['EmployerName']):
    if i not in list(aorig['EmployerName']):
        diff_list.append(i) 
    
print(f'List length of non-repeating companies: {len(diff_list)}')
print(f'{diff_list[:5]}')
# Out:
# List length of non-repeating companies: 2123
# ['1879 EVENTS MANAGEMENT LIMITED', '2 SISTERS RED MEAT LIMITED', 'A M SUPPORT SERVICES LIMITED', 'A NOVO UK LTD', 'A P SECURITY (APS) LTD']

# %%
new_comp_num = []

for i in diff_list:
    
    if i in list(aorig['EmployerName']):
        if pd.isnull(aorig[aorig['EmployerName'] == i].CompanyNumber.item()) == False:
            new_comp_num.append(aorig[aorig['EmployerName'] == i].CompanyNumber.item())
            
    if i in list(borig['EmployerName']):
        if pd.isnull(borig[borig['EmployerName'] == i].CompanyNumber.item()) == False:
            new_comp_num.append(borig[borig['EmployerName'] == i].CompanyNumber.item())
            
            
new_comp_num = list(set([x for x in new_comp_num if new_comp_num.count(x) > 1]))
    
print(f'# of companies that share company number but different names: {len(new_comp_num)}')
# Out:
# # of companies that share company number but different names: 265

# %%
# show high variation in names
for i in new_comp_num[:5]:
    print(aorig[aorig.CompanyNumber == i].EmployerName.item())
    print(borig[borig.CompanyNumber == i].EmployerName.item())
# Out:
# CAS LEARNING DISABILITIES LIMITED
# CYGNET LEARNING DISABILITIES LIMITED
# FIDESSA PLC
# FIDESSA TRADING UK LIMITED
# ASSYSTEM UK LIMITED
# EXPLEO ENGINEERING UK LIMITED
# SEAFOOD HOLDINGS LTD
# BIDFRESH LIMITED
# EMBRACE CARE LIMITED
# SANCTUARY CARE (NORTH) LIMITED

# %%
# show low variation in address
for i in new_comp_num[:5]:
    print(aorig[aorig.CompanyNumber == i].Address.item())
    print(borig[borig.CompanyNumber == i].Address.item())
# Out:
# Nepicar House London Road,
# Wrotham Heath,
# Sevenoaks,
# Kent,
# England,
# TN15 7RS
# Nepicar House London Road,
# Wrotham Heath,
# Sevenoaks,
# Kent,
# England,
# TN15 7RS
# C/O Ion,
# 3rd Floor, One New Change,
# London,
# England,
# EC4M 9AF
# C/O Ion,
# 3rd Floor, One New Change,
# London,
# England,
# EC4M 9AF
# Expleo Engineering Uk Limited Club Street,
# Bamber Bridge,
# Preston,
# Lancashire,
# England,
# PR5 6FN
# Expleo Engineering Uk Limited Club Street,
# Bamber Bridge,
# Preston,
# Lancashire,
# England,
# PR5 6FN
# Unit 10-14 Cedar Way Industrial Estate,
# Camley Street,
# London,
# United Kingdom,
# N1C 4PD
# Unit 10-14 Cedar Way Industrial Estate,
# Camley Street,
# London,
# United Kingdom,
# N1C 4PD
# Sanctuary House, Chamber Court, Castle Street,
# Worcester,
# England,
# WR1 3ZQ
# Sanctuary House, Chamber Court, Castle Street,
# Worcester,
# England,
# WR1 3ZQ

# %%
print(aorig[aorig.CompanyNumber == new_comp_num[0]]['EmployerName'].item())
print(borig[borig.CompanyNumber == new_comp_num[0]]['EmployerName'].item())
# Out:
# CAS LEARNING DISABILITIES LIMITED
# CYGNET LEARNING DISABILITIES LIMITED

# %%
corr_address_num = []
diff_address_num = []

for i in new_comp_num:
    
    if aorig[aorig.CompanyNumber == i].Address.item() == \
        borig[borig.CompanyNumber == i].Address.item():
            
            aorig.at[aorig[aorig.CompanyNumber == i].index.item(), 'EmployerName'] = \
                borig[borig.CompanyNumber == i].EmployerName.item()
            
            corr_address_num.append(i)
            
    else:
        
        diff_address_num.append(i)
    
print(f'# of 2017 companies converted to 2018 name: {len(corr_address_num)}')
print(f'Companies not corrected: {len(diff_address_num)}')
# Out:
# # of 2017 companies converted to 2018 name: 265
# Companies not corrected: 0

# %%
print(aorig[aorig.CompanyNumber == new_comp_num[0]]['EmployerName'].item())
print(borig[borig.CompanyNumber == new_comp_num[0]]['EmployerName'].item())
# Out:
# CYGNET LEARNING DISABILITIES LIMITED
# CYGNET LEARNING DISABILITIES LIMITED

# %%
same_list = []
diff_list = []

for i in list(aorig['EmployerName']):
    if i in list(borig['EmployerName']):
        same_list.append(i)

for i in list(aorig['EmployerName']):
    if i not in list(borig['EmployerName']):
        diff_list.append(i)
        
for i in list(borig['EmployerName']):
    if i not in list(aorig['EmployerName']):
        diff_list.append(i) 

print(f'New length of repeating companies: {len(same_list)}')
print(f'New length of non-repeating companies: {len(diff_list)}')
print(f'New length combined: {len(same_list) + len(diff_list)}')
# Out:
# New length of repeating companies: 9867
# New length of non-repeating companies: 1593
# New length combined: 11460

# %%
# aorig.to_csv('2017clean1.csv')
# borig.to_csv('2018clean1.csv')

# %%
# continued at 03.2
