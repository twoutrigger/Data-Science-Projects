# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_colwidth', -1)

# %%
borig = pd.read_csv('2018clean3.csv', header=0, index_col=0, dtype={'MainSic': object})

print(borig.shape)
borig.head(5)
# Out:
# (10772, 29)
#                          EmployerName  \
# 0  BRYANSTON SCHOOL,INCORPORATED
# 1  RED BAND CHEMICAL COMPANY, LIMITED
# 2  118 LIMITED
# 3  123 EMPLOYEES LTD
# 4  1509 GROUP
#
#                                                                                               Address  \
# 0  Bryanston House,\r\r\r\r\nBlandford,\r\r\r\r\nDorset,\r\r\r\r\nUnited Kingdom,\r\r\r\r\nDT11 0PX
# 1  19 Smith's Place,\r\r\r\r\nLeith Walk,\r\r\r\r\nEdinburgh,\r\r\r\r\nEH6 8NU
# 2  Fusion Point,\r\r\r\r\nDumballs Road,\r\r\r\r\nCardiff,\r\r\r\r\nUnited Kingdom,\r\r\r\r\nCF10 5BF
# 3  34 Roundhay Road,\r\r\r\r\nLeeds,\r\r\r\r\nEngland,\r\r\r\r\nLS7 1AB
# 4  Royal Grammar School, High Street,\r\r\r\r\nGuildford,\r\r\r\r\nSurrey,\r\r\r\r\nGU1 3BB
#
#   CompanyNumber               SicCodes  DiffMeanHourlyPercent  \
# 0  00226143      85310                  19.6
# 1  SC016876      47730                  7.7
# 2  03951948      61900                  7.7
# ...

# %%
borig['MainSection'].value_counts()
# Out:
# Manufacturing                                               1385
# Administrative and support service activities               1264
# Education                                                   1223
# Wholesale and retail trade; repair of motor vehicles and    1008
# Human health and social work activities                     988
# Professional, scientific and technical activities           714
# Accommodation and food service activities                   563
# Public administration and defence; compulsory social        473
# Information and communication                               452
# Financial and insurance activities                          414
# Transportation and storage                                  399
# Construction                                                329
# Arts, entertainment and recreation                          295
# Other service activities                                    218
# Real estate activities                                      132
# ...

# %%
SectionHourlySum = pd.pivot_table(borig, values='DiffMeanHourlyPercent',
                            index=['MainSection'], aggfunc=np.sum)
SectionHourlySum
# Out:
#                                                           DiffMeanHourlyPercent
# MainSection
# Accommodation and food service activities                 3901.1
# Activities of extraterritorial organisations and          53.8
# Activities of households as employers; undifferentiated  -1.5
# Administrative and support service activities             13216.6
# Agriculture, Forestry and Fishing                         703.9
# Arts, entertainment and recreation                        5994.2
# Construction                                              7296.5
# Education                                                 19751.7
# Electricity, gas, steam and air conditioning supply       889.4
# Financial and insurance activities                        10999.5
# Human health and social work activities                   10593.1
# Information and communication                             8809.2
# Manufacturing                                             17449.0
# ...

# %%
SectionHourly = pd.pivot_table(borig, values='DiffMeanHourlyPercent',
                            index=['MainSection'], aggfunc=np.mean)
SectionHourly
# Out:
#                                                           DiffMeanHourlyPercent
# MainSection
# Accommodation and food service activities                 6.929130
# Activities of extraterritorial organisations and          5.977778
# Activities of households as employers; undifferentiated  -0.375000
# Administrative and support service activities             10.456171
# Agriculture, Forestry and Fishing                         14.664583
# Arts, entertainment and recreation                        20.319322
# Construction                                              22.177812
# Education                                                 16.150204
# Electricity, gas, steam and air conditioning supply       15.074576
# Financial and insurance activities                        26.568841
# Human health and social work activities                   10.721761
# Information and communication                             19.489381
# ...

# %%
type(SectionHourly)
# Out:
# pandas.core.frame.DataFrame

# %%
SectionHourly.loc['Real estate activities']['DiffMeanHourlyPercent']
# Out:
# 16.812121212121212

# %%
borig[borig['MainSection'] == 'Professional, scientific and technical activities']
# Out:
#                                            EmployerName  \
# 24     6CATS UK LTD.
# 27     A  PEARSON HOLDINGS LIMITED
# 42     A.C. NIELSEN COMPANY LIMITED
# 43     A.C.S. & T. GRIMSBY  LTD.
# 65     ABARIS HOLDINGS LIMITED
# 75     ABBOTT MEAD VICKERS.BBDO LIMITED
# 90     ABERDEIN CONSIDINE
# 111    ACCENTURE (UK) LIMITED
# 171    ADAPTIMMUNE  LIMITED
# 190    ADMIRAL LAW LIMITED
# 205    ADVANCED MEDICAL SOLUTIONS GROUP PLC
# 206    ADVANCED PERSONNEL MANAGEMENT GROUP (UK) LIMITED
# 215    AECOM INFRASTRUCTURE & ENVIRONMENT UK LIMITED
# 216    AECOM LIMITED
# 254    AGILENT TECHNOLOGIES LDA UK LIMITED
# 292    AJ BELL PLC
# 298    AKQA LIMITED
# 299    AKT II  LIMITED
# 300    AKTRION MANUFACTURING SUPPORT SERVICES LIMITED
# 312    ALCUMUS HOLDINGS LIMITED
# 324    ALERE TOXICOLOGY PLC
# 330    ALFRED H. KNIGHT INTERNATIONAL LIMITED
# 346    ALLEN & OVERY SERVICE COMPANY LIMITED
# 352    ALLFORD HALL MONAGHAN MORRIS LIMITED
# 386    ALS ENVIRONMENTAL LIMITED
# ...

# %%
sic_dict_1={'Manufacturing':'Manufacturing',
            'Administrative and Support Services':'Administrative and support service activities',
            'Education':'Education',
            'Retail Trade and Automobiles':'Wholesale and retail trade; repair of motor vehicles and',
            'Health and Social Work':'Human health and social work activities',
            'Professional and Scientific Services':'Professional, scientific and technical activities',
            'Accommodation and Food Services':'Accommodation and food service activities',
            'Public Administration and Defence':'Public administration and defence; compulsory social',
            'IT and Communications':'Information and communication',
            'Financial and Insurance Services':'Financial and insurance activities',
            'Transportation and Storage':'Transportation and storage',
            'Construction':'Construction',
            'Arts, Entertainment and Recreation':'Arts, entertainment and recreation',
            'Other Services':'Other service activities',
            'Real Estate':'Real estate activities'}

# %%
sic_dict_2={'Manufacturing':'Manufacturing',
            'Administrative and support service activities':'Administrative and Support Services',
            'Education':'Education',
            'Wholesale and retail trade; repair of motor vehicles and':'Retail Trade and Automobiles',
            'Human health and social work activities':'Health and Social Work',
            'Professional, scientific and technical activities':'Professional, Scientific and Technical Services',
            'Accommodation and food service activities':'Accommodation and Food Services',
            'Public administration and defence; compulsory social':'Public Administration and Defence',
            'Information and communication':'IT and Communications',
            'Financial and insurance activities':'Financial and Insurance Services',
            'Transportation and storage':'Transportation and Storage',
            'Construction':'Construction',
            'Arts, entertainment and recreation':'Arts, Entertainment and Recreation',
            'Other service activities':'Other Services',
            'Real estate activities':'Real Estate'}

# %%
# test = [{'label':name, 'value':sic_dict.get(name)} for name in sic_dict],

# test

# %%
pal = sns.color_palette("Set2")
print(pal.as_hex())
# Out:
# ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f']

# %%
import random

# %%
rand_list = list(sic_dict_2.keys())

# %%
rand_1 = random.choice(rand_list)
print(rand_1)
# Out:
# Administrative and support service activities

# %%
remain_list = rand_list
remain_list.remove(rand_1)

rand_2 = random.choice(remain_list)
print(rand_2)
# Out:
# Other service activities

# %%
borig['MainSection'].value_counts()
# Out:
# Manufacturing                                               1385
# Administrative and support service activities               1264
# Education                                                   1223
# Wholesale and retail trade; repair of motor vehicles and    1008
# Human health and social work activities                     988
# Professional, scientific and technical activities           714
# Accommodation and food service activities                   563
# Public administration and defence; compulsory social        473
# Information and communication                               452
# Financial and insurance activities                          414
# Transportation and storage                                  399
# Construction                                                329
# Arts, entertainment and recreation                          295
# Other service activities                                    218
# Real estate activities                                      132
# ...

# %%
len(borig[borig['MainSection'] == 'Manufacturing'])
# Out:
# 1385
