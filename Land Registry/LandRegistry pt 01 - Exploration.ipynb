# %%
import pandas as pd
import numpy as np

# %%
### Explore Nov 2019 updated and full files from HM Land Registry

# %%
rorig = pd.read_csv('CCOD_COU_2019_11.csv', skipfooter=1, 
                    dtype={'Company Registration No. (1)': str,
                           'Company Registration No. (2)': str,
                           'Company Registration No. (3)': str,
                           'Company Registration No. (4)': str})

print(rorig.shape)
rorig.head()
# Out:
# C:\Users\liamk\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """
# (63745, 37)
#   Title Number    Tenure                                   Property Address  \
# 0      NT72787  Freehold              2 Horsham Drive, Top Valley (NG5 9AH)
# 1      LT25408  Freehold            98-100 Melton Road, Leicester (LE4 5EB)
# 2      P183436  Freehold                  81 Queen Street, Barry (CF62 7EE)
# 3      PM26295  Freehold  Flats 1-16, 2 East Shore Way, Portsmouth (PO3 ...
# 4      LN44425  Freehold             10 St James's Place, London (SW1A 1NP)
#
#                 District                 County          Region  Postcode  \
# 0     CITY OF NOTTINGHAM     CITY OF NOTTINGHAM   EAST MIDLANDS   NG5 9AH
# 1              LEICESTER              LEICESTER   EAST MIDLANDS   LE4 5EB
# ...

# %%
print(rorig.iloc[0, :])
# Out:
# Title Number                                                                 NT72787
# Tenure                                                                      Freehold
# Property Address                               2 Horsham Drive, Top Valley (NG5 9AH)
# District                                                          CITY OF NOTTINGHAM
# County                                                            CITY OF NOTTINGHAM
# Region                                                                 EAST MIDLANDS
# Postcode                                                                     NG5 9AH
# Multiple Address Indicator                                                         N
# Price Paid                                                                     30000
# Proprietor Name (1)                                  PLACES FOR PEOPLE HOMES LIMITED
# Company Registration No. (1)                                                IP19447R
# ...

# %%
rorig.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63746 entries, 0 to 63745
# Data columns (total 37 columns):
# Title Number                       63746 non-null object
# Tenure                             63746 non-null object
# Property Address                   63716 non-null object
# District                           63745 non-null object
# County                             63745 non-null object
# Region                             63745 non-null object
# Postcode                           48816 non-null object
# Multiple Address Indicator         63745 non-null object
# Price Paid                         15991 non-null float64
# Proprietor Name (1)                63745 non-null object
# Company Registration No. (1)       59444 non-null object
# Proprietorship Category (1)        63745 non-null object
# Proprietor (1) Address (1)         63744 non-null object
# Proprietor (1) Address (2)         5400 non-null object
# Proprietor (1) Address (3)         369 non-null object
# ...

# %%
rorig[rorig['Proprietor Name (1)'].isnull()]
# Out:
#       Title Number Tenure Property Address District County Region Postcode  \
# 63745   Row Count:  63745              NaN      NaN    NaN    NaN      NaN
#
#       Multiple Address Indicator  Price Paid Proprietor Name (1)  ...  \
# 63745                        NaN         NaN                 NaN  ...
#
#       Proprietor Name (4) Company Registration No. (4)  \
# 63745                 NaN                          NaN
#
#       Proprietorship Category (4) Proprietor (4) Address (1)  \
# 63745                         NaN                        NaN
#
#       Proprietor (4) Address (2) Proprietor (4) Address (3)  \
# 63745                        NaN                        NaN
#
#       Date Proprietor Added Additional Proprietor Indicator Change Indicator  \
# 63745                   NaN                             NaN              NaN
#
#       Change Date
# 63745         NaN
#
# [1 rows x 37 columns]

# %%
print(rorig[rorig['Proprietor Name (4)'].isnull() == False].iloc[8, :])
# Out:
# Title Number                                                         NK236714
# Tenure                                                               Freehold
# Property Address                   10 Market Hill, Diss and garage (IP22 4WJ)
# District                                                        SOUTH NORFOLK
# County                                                                NORFOLK
# Region                                                            EAST ANGLIA
# Postcode                                                             IP22 4WJ
# Multiple Address Indicator                                                  N
# Price Paid                                                                NaN
# Proprietor Name (1)                                            THRUMS LIMITED
# Company Registration No. (1)                                         07549226
# Proprietorship Category (1)         Limited Company or Public Limited Company
# ...

# %%
rorig['Multiple Address Indicator'].value_counts()
# Out:
# N    63461
# Y      284
# Name: Multiple Address Indicator, dtype: int64

# %%
rorig['Change Date'].value_counts()
# Out:
# 01-11-2019    63745
# Name: Change Date, dtype: int64

# %%
# Indicates the title has a Property Schedule and therefore more than one address.
rorig[rorig['Multiple Address Indicator'] == 'Y'].head(2)
# Out:
#     Title Number     Tenure  \
# 97      HD208823  Leasehold
# 119       218477   Freehold
#
#                                       Property Address             District  \
# 97   EDEN BRIDGE TOYOTA ICKNIELD WAY, LETCHWORTH GA...  NORTH HERTFORDSHIRE
# 119                   131 FONTHILL ROAD, LONDON N4 3HH            ISLINGTON
#
#              County          Region Postcode Multiple Address Indicator  \
# 97    HERTFORDSHIRE      SOUTH EAST  SG6 1EF                          Y
# 119  GREATER LONDON  GREATER LONDON   N4 3HH                          Y
#
#      Price Paid           Proprietor Name (1)  ... Proprietor Name (4)  \
# 97          NaN  EDEN BRIDGE CARRIAGE LIMITED  ...                 NaN
# 119         NaN   DAWNELIA PROPERTIES LIMITED  ...                 NaN
#
#     Company Registration No. (4) Proprietorship Category (4)  \
# 97                           NaN                         NaN
# 119                          NaN                         NaN
#
# ...

# %%
rorig[rorig['Title Number'] == 'HD208823']
# Out:
#       Title Number     Tenure  \
# 97        HD208823  Leasehold
# 43190     HD208823  Leasehold
#
#                                         Property Address             District  \
# 97     EDEN BRIDGE TOYOTA ICKNIELD WAY, LETCHWORTH GA...  NORTH HERTFORDSHIRE
# 43190  EDEN BRIDGE TOYOTA ICKNIELD WAY, LETCHWORTH GA...  NORTH HERTFORDSHIRE
#
#               County      Region Postcode Multiple Address Indicator  \
# 97     HERTFORDSHIRE  SOUTH EAST  SG6 1EF                          Y
# 43190  HERTFORDSHIRE  SOUTH EAST  SG6 1EF                          Y
#
#        Price Paid           Proprietor Name (1)  ... Proprietor Name (4)  \
# 97            NaN  EDEN BRIDGE CARRIAGE LIMITED  ...                 NaN
# 43190   1907500.0  EDEN BRIDGE CARRIAGE LIMITED  ...                 NaN
#
#       Company Registration No. (4) Proprietorship Category (4)  \
# 97                             NaN                         NaN
# 43190                          NaN                         NaN
#
# ...

# %%
len(rorig.District.unique())
# Out:
# 340

# %%
print(rorig.columns)
# Out:
# Index(['Title Number', 'Tenure', 'Property Address', 'District', 'County',
#        'Region', 'Postcode', 'Multiple Address Indicator', 'Price Paid',
#        'Proprietor Name (1)', 'Company Registration No. (1)',
#        'Proprietorship Category (1)', 'Proprietor (1) Address (1)',
#        'Proprietor (1) Address (2)', 'Proprietor (1) Address (3)',
#        'Proprietor Name (2)', 'Company Registration No. (2)',
#        'Proprietorship Category (2)', 'Proprietor (2) Address (1)',
#        'Proprietor (2) Address (2)', 'Proprietor (2) Address (3)',
#        'Proprietor Name (3)', 'Company Registration No. (3)',
#        'Proprietorship Category (3)', 'Proprietor (3) Address (1)',
#        'Proprietor (3) Address (2)', 'Proprietor (3) Address (3)',
#        'Proprietor Name (4)', 'Company Registration No. (4)',
#        'Proprietorship Category (4)', 'Proprietor (4) Address (1)',
#        'Proprietor (4) Address (2)', 'Proprietor (4) Address (3)',
# ...

# %%
# FULL is missing columns 'Change Indicator', 'Change Date'

norig = pd.read_csv('CCOD_FULL_2019_11.csv',
                    skipfooter=1, 
                    dtype={'Company Registration No. (1)': str,
                           'Company Registration No. (2)': str,
                           'Company Registration No. (3)': str,
                           'Company Registration No. (4)': str})

print(norig.shape)
norig.head()
# Out:
# C:\Users\liamk\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# (3713107, 35)
#   Title Number    Tenure                                   Property Address  \
# 0        18360  Freehold  Langley Farm, Beech Tree Road, Holmer Green, H...
# 1        18402  Freehold    17 Tolroy Road, St Erth Praze, Hayle (TR27 6EA)
# 2        18481  Freehold  land at Leighton Brook, Off Middlewich Road, L...
# 3        18665  Freehold  Wellfield Farm, Sherborne Road, Sherborne St J...
# 4        18747  Freehold                    Land adjoining Haulfryn, Meifod
#
#                 District           County      Region  Postcode  \
# 0               CHILTERN  BUCKINGHAMSHIRE  SOUTH EAST  HP15 6UZ
# 1               CORNWALL         CORNWALL  SOUTH WEST  TR27 6EA
# 2          CHESHIRE EAST    CHESHIRE EAST  NORTH WEST       NaN
# ...

# %%
norig.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3713107 entries, 0 to 3713106
# Data columns (total 35 columns):
# Title Number                       3713107 non-null object
# Tenure                             3713107 non-null object
# Property Address                   3712687 non-null object
# District                           3713107 non-null object
# County                             3713107 non-null object
# Region                             3713107 non-null object
# Postcode                           2113207 non-null object
# Multiple Address Indicator         3713107 non-null object
# Price Paid                         544523 non-null float64
# Proprietor Name (1)                3713107 non-null object
# Company Registration No. (1)       2719060 non-null object
# Proprietorship Category (1)        3713107 non-null object
# Proprietor (1) Address (1)         3713083 non-null object
# Proprietor (1) Address (2)         343649 non-null object
# ...

# %%
norig.Region.value_counts()
# Out:
# SOUTH EAST          739405
# GREATER LONDON      553280
# NORTH WEST          543881
# SOUTH WEST          357272
# WEST MIDLANDS       329462
# YORKS AND HUMBER    327221
# EAST MIDLANDS       269323
# WALES               216575
# NORTH               195985
# EAST ANGLIA         180703
# Name: Region, dtype: int64

# %%
print(len(norig.County.value_counts()))
norig.County.value_counts()[:10]
# Out:
# 111
# GREATER LONDON        553280
# GREATER MANCHESTER    227154
# WEST MIDLANDS         142922
# WEST YORKSHIRE        121356
# LANCASHIRE            100753
# MERSEYSIDE             99642
# KENT                   97339
# SOUTH YORKSHIRE        85192
# ESSEX                  82997
# SURREY                 74505
# Name: County, dtype: int64

# %%
print(len(norig.District.value_counts()))
norig.District.value_counts()[:10]
# Out:
# 339
# BIRMINGHAM             53824
# LEEDS                  43866
# LIVERPOOL              43203
# CITY OF BRISTOL        39227
# SHEFFIELD              38705
# CITY OF WESTMINSTER    37456
# MANCHESTER             37326
# CORNWALL               37100
# COUNTY DURHAM          33656
# CHESHIRE EAST          32622
# Name: District, dtype: int64

# %%
2113207/len(oorig)
# Out:
# 0.5816846999703819
