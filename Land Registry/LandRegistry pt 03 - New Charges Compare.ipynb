# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from commonregex import CommonRegex
import requests
import re

# %%
### Tie new charges to land registry

# %%
use_cols = ['Title Number', 'Tenure', 'Property Address', 'District', 'County',
            'Region', 'Postcode', 'Multiple Address Indicator', 'Price Paid',
            'Proprietor Name (1)', 'Company Registration No. (1)',
            'Proprietorship Category (1)', 'Proprietor (1) Address (1)',
            'Proprietor (1) Address (2)', 'Proprietor (1) Address (3)']

rorig = pd.read_csv('CCOD_COU_2019_11.csv', skipfooter=1, engine='python',
                    usecols=use_cols,
                    dtype={'Title Number': str,
                           'Company Registration No. (1)': str})

print(rorig.shape)
rorig.head(2)
# Out:
# (63745, 15)
#   Title Number    Tenure                         Property Address  \
# 0      NT72787  Freehold    2 Horsham Drive, Top Valley (NG5 9AH)
# 1      LT25408  Freehold  98-100 Melton Road, Leicester (LE4 5EB)
#
#              District              County         Region Postcode  \
# 0  CITY OF NOTTINGHAM  CITY OF NOTTINGHAM  EAST MIDLANDS  NG5 9AH
# 1           LEICESTER           LEICESTER  EAST MIDLANDS  LE4 5EB
#
#   Multiple Address Indicator  Price Paid              Proprietor Name (1)  \
# 0                          N     30000.0  PLACES FOR PEOPLE HOMES LIMITED
# 1                          N         NaN                 JADEMARK LIMITED
#
#   Company Registration No. (1)                 Proprietorship Category (1)  \
# 0                     IP19447R  Industrial and Provident Society (Company)
# 1                      2847145   Limited Company or Public Limited Company
#
#         Proprietor (1) Address (1)  \
# 0    80 Cheapside, London EC2V 6EE
# 1  98 - 100 Melton Road, Leicester
#
#                           Proprietor (1) Address (2)  \
# 0  4 The Pavilions, Ashton-on-Ribble, Preston PR2...
# 1                                                NaN
#
#   Proprietor (1) Address (3)
# 0                        NaN
# 1                        NaN

# %%
corig = pd.read_csv('charges_tempt.csv', dtype=str, header=0, index_col=None)

print(corig.shape)
corig.head(2)
# Out:
# (37480, 15)
#                CompanyName CompanyNumber CompanyStatus  \
# 0  CHG-MERIDIAN UK LIMITED      01276016        Active
# 1  CHG-MERIDIAN UK LIMITED      01276016        Active
#
#           IncorporationDate  \
# 0  1976-09-06T00:00:00.000Z
# 1  1976-09-06T00:00:00.000Z
#
#                                              SICCode       status  \
# 0  [{"code":"64910","description":"Financial leas...  outstanding
# 1  [{"code":"64910","description":"Financial leas...  outstanding
#
#                                persons_entitled              delivered_on  \
# 0  [{"name":"Bal Global Finance (UK) Limited"}]  2019-08-01T00:00:00.000Z
# 1  [{"name":"Bal Global Finance (UK) Limited"}]  2019-08-01T00:00:00.000Z
#
#   charge_number classification.type classification.description  \
# 0          2529  charge-description        A registered charge
# 1          2528  charge-description        A registered charge
#
#     particulars.type                            particulars.description  \
# 0  brief-description  A security charge dated 31/07/2019 between bal...
# 1  brief-description  A security charge dated 31/07/2019 between bal...
#
#   RegAddress.District RegAddress.PostCode
# 0           RUNNYMEDE            TW20 9AB
# 1           RUNNYMEDE            TW20 9AB

# %% [markdown]
# ### Extract Data

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in str(inputString))

# %%
cedit = corig.copy()

cedit.dropna(subset=['particulars.description'], inplace=True)
cedit['hasNum'] = cedit['particulars.description'].apply(hasNumbers)
cedit = cedit[cedit['hasNum'] == True]

print(cedit.shape)
cedit.tail(2)
# Out:
# (23197, 16)
#                   CompanyName CompanyNumber CompanyStatus  \
# 37478  LITTLE WELLIES LIMITED      09014548        Active
# 37479      LITTONDALE LIMITED      11756098        Active
#
#               IncorporationDate  \
# 37478  2014-04-28T00:00:00.000Z
# 37479  2019-01-08T00:00:00.000Z
#
#                                                  SICCode       status  \
# 37478  [{"code":"88910","description":"Child day-care...  outstanding
# 37479  [{"code":"98000","description":"Residents prop...  outstanding
#
#                                  persons_entitled              delivered_on  \
# 37478  [{"name":"National Westminster Bank PLC"}]  2019-12-02T00:00:00.000Z
# 37479             [{"name":"Gatehouse Bank PLC"}]  2019-11-11T00:00:00.000Z
#
#       charge_number classification.type classification.description  \
# 37478             4  charge-description        A registered charge
# 37479             1  charge-description        A registered charge
#
#         particulars.type                            particulars.description  \
# 37478  brief-description              110 apperley road, bradford BD10 9SR.
# 37479  brief-description  4,6 & 8 church street, clowne, chesterfield, S...
#
#       RegAddress.District RegAddress.PostCode  hasNum
# 37478            BRADFORD             BD2 1NH    True
# 37479              OLDHAM             OL2 6NX    True

# %% [markdown]
# <br>
# <font color=green>Note: Particulars.description plain text is the only clear way to discern land charge</font>
# <br>

# %%
for i in cedit['particulars.description'].sample(5):
    print(i+ '\n')
# Out:
# 63 alumhurst road. Westbourne. Dorset. BH4 8EW.
#
# 26 hatch lane harmondsworth t/no MX434838.
#
# The bungalow, leeming lane farm, great north road, sinderby, thirsk, YO7 4LG. The cottage, leeming lane farm, great north road, sinderby, thirsk, YO7 4LG.
#
# 14 taplow street liverpool.
#
# Leasehold properties - 2305 michigan point tower b, 11 michigan avenue, salford, M50 2HJ - title number GM667953 (part of) and all other properties listed in the schedule of the charge attached hereto.

# %%
### most titles are between the length of 6-8

redit = rorig.copy()
redit['TitleLen'] = redit['Title Number'].apply(len)

redit['TitleLen'].value_counts()
# Out:
# 8    40218
# 9    13893
# 7     8377
# 6     1117
# 5      130
# 4       10
# Name: TitleLen, dtype: int64

# %%
### structure generally 2-3 letters and 5-6 numbers 
redit.loc[redit['TitleLen'] == 8]['Title Number'].sample(5)
# Out:
# 30588    MS441144
# 3107     DT347495
# 51719    DN718514
# 59400    HS228847
# 6773     SF639956
# Name: Title Number, dtype: object

# %%
redit
# Out:
#       Title Number     Tenure  \
# 0          NT72787   Freehold
# 1          LT25408   Freehold
# 2          P183436   Freehold
# 3          PM26295   Freehold
# 4          LN44425   Freehold
# ...            ...        ...
# 63740    TGL170502   Freehold
# 63741    WSX291159   Freehold
# 63742    WSX406286  Leasehold
# 63743    SGL301334   Freehold
# 63744    WSX336543   Freehold
#
#                                         Property Address  \
# 0                  2 Horsham Drive, Top Valley (NG5 9AH)
# 1                98-100 Melton Road, Leicester (LE4 5EB)
# 2                      81 Queen Street, Barry (CF62 7EE)
# 3      Flats 1-16, 2 East Shore Way, Portsmouth (PO3 ...
# 4                 10 St James's Place, London (SW1A 1NP)
# ...                                                  ...
# 63740  2-12 (even) and 9-43 (odd) Watermill Close, 52...
# 63741             89 Lower Street, Pulborough (RH20 2BP)
# 63742  Unit 35, Bolney Grange Industrial Park, Bolney...
# 63743               108 Manor Road, Wallington (SM6 0DW)
# 63744  land on the south side of Hoyle Lane, Heyshott...
#
#                     District                 County          Region  Postcode  \
# 0         CITY OF NOTTINGHAM     CITY OF NOTTINGHAM   EAST MIDLANDS   NG5 9AH
# 1                  LEICESTER              LEICESTER   EAST MIDLANDS   LE4 5EB
# 2      THE VALE OF GLAMORGAN  THE VALE OF GLAMORGAN           WALES  CF62 7EE
# 3                 PORTSMOUTH             PORTSMOUTH      SOUTH EAST   PO3 6GD
# 4        CITY OF WESTMINSTER         GREATER LONDON  GREATER LONDON  SW1A 1NP
# ...                      ...                    ...             ...       ...
# 63740   RICHMOND UPON THAMES         GREATER LONDON  GREATER LONDON       NaN
# 63741                HORSHAM            WEST SUSSEX      SOUTH EAST  RH20 2BP
# 63742             MID SUSSEX            WEST SUSSEX      SOUTH EAST  RH17 5PB
# 63743                 SUTTON         GREATER LONDON  GREATER LONDON   SM6 0DW
# 63744             CHICHESTER            WEST SUSSEX      SOUTH EAST       NaN
#
#       Multiple Address Indicator  Price Paid  \
# 0                              N     30000.0
# 1                              N         NaN
# 2                              N         NaN
# 3                              N         NaN
# 4                              N   5500000.0
# ...                          ...         ...
# 63740                          N         NaN
# 63741                          N     12250.0
# 63742                          N         NaN
# 63743                          N    215000.0
# 63744                          N         NaN
#
#                     Proprietor Name (1) Company Registration No. (1)  \
# 0       PLACES FOR PEOPLE HOMES LIMITED                     IP19447R
# 1                      JADEMARK LIMITED                      2847145
# 2           HURSTON REAL ESTATE LIMITED                     10171850
# 3                JLPPT HOLDCO 6 LIMITED                     09134008
# 4            BEST DRESSED GROUP LIMITED                     08820424
# ...                                 ...                          ...
# 63740                  ISHGUARD LIMITED                      9163587
# 63741             RG SECURITIES LIMITED                     06762017
# 63742  A & A CONSTRUCTION GROUP LIMITED                     02551724
# 63743     HOLLYGRACE PROPERTIES LIMITED                     09967718
# 63744         THE COWDRAY TRUST LIMITED                     00152433
#
#                       Proprietorship Category (1)  \
# 0      Industrial and Provident Society (Company)
# 1       Limited Company or Public Limited Company
# 2       Limited Company or Public Limited Company
# 3       Limited Company or Public Limited Company
# 4       Limited Company or Public Limited Company
# ...                                           ...
# 63740   Limited Company or Public Limited Company
# 63741   Limited Company or Public Limited Company
# 63742   Limited Company or Public Limited Company
# 63743   Limited Company or Public Limited Company
# 63744   Limited Company or Public Limited Company
#
#                               Proprietor (1) Address (1)  \
# 0                          80 Cheapside, London EC2V 6EE
# 1                        98 - 100 Melton Road, Leicester
# 2       Bishopstone, 36 Crescent Road, Worthing BN11 1RL
# 3           Grand Buildings, 1-3 Strand, London WC2N 5HR
# 4       Nuffield House, 41-46 Piccadilly, London W1J 0DS
# ...                                                  ...
# 63740  Berkeley House, 304 Regents Park Road, London ...
# 63741           7 Nelson Street, Southend On Sea SS1 1EH
# 63742  Suite 21, 10 Churchill Square, Kings Hill, Wes...
# 63743  Unit 1, Kensington Court, 108 Manor Road, Wall...
# 63744        4th Floor, 10 Bruton Street, London W1J 6PX
#
#                               Proprietor (1) Address (2)  \
# 0      4 The Pavilions, Ashton-on-Ribble, Preston PR2...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 63740                                                NaN
# 63741                                                NaN
# 63742                                                NaN
# 63743                                                NaN
# 63744                                                NaN
#
#       Proprietor (1) Address (3)  TitleLen
# 0                            NaN         7
# 1                            NaN         7
# 2                            NaN         7
# 3                            NaN         7
# 4                            NaN         7
# ...                          ...       ...
# 63740                        NaN         9
# 63741                        NaN         9
# 63742                        NaN         9
# 63743                        NaN         9
# 63744                        NaN         9
#
# [63745 rows x 16 columns]

# %%
### keep NaN rows due to Tenure and address info available
print(f"Rows with NaN for Price Paid: {len(redit['Price Paid'].isnull())}")
# Out:
# Rows with NaN for Price Paid: 63745

# %%
### return single or multiple titles
def hasTitle(inputString):
    ret = re.findall('([A-Z]{2,3}[0-9]{3,5})\w+', str(inputString))
    if len(ret) > 0:
        return ret
    else:
        pass

# %%
cedit['hasTitle'] = cedit['particulars.description'].apply(hasTitle)

cedit.loc[~cedit['hasTitle'].isnull()][['CompanyNumber', 'hasTitle']].sample(5)
# Out:
#       CompanyNumber              hasTitle
# 20402      02630203             [WK41745]
# 8363       10013047             [MX20735]
# 24551      01166032             [SK19284]
# 2059       09875397  [CYM57434, CYM66700]
# 29577      08906583  [NYK35534, NYK35534]

# %%
### create test descriptions
desc1 = 'The freehold property known as 26B piper close mansfield woodhouse mansfield NG19 7GG registered at h m land registry with title number NT463229.'
desc2 = '22 shedden park road, kelso ROX11811.'
desc3 = '243 plaistow road, london E15 3EU. Title number: EGL211881'
desc4 = 'The freehold land known as 128 cardiff road, reading, RG1 8PQ and 8 trafford road, reading, RG1 8JP registered at the land registry under title numbers BK124548 and BK98452.'

# %%
def hasAddress(inputString):
#     ret = re.findall('(\d{1,10}( \w+){1,10}( ( \w+){1,10})?( \w+){1,10}[,.](( \w+){1,10}(,)? [A-Z]{2}( [0-9]{5})?)?)', str(inputString))
    ret = re.findall('(\d[0-9]{1,3} .+, [a-zA-Z]+[^\s])', str(inputString))
#     ret = re.findall('([A-Za-z0-9]\.\-\s\,])', str(inputString))

    if len(ret) > 0:
        return ret
    else:
        pass

# %%
### ok performance; needs improvement for termination
### will likely need multiple regexs for various forms of input
print(hasAddress(desc1))
print(hasAddress(desc2))
print(hasAddress(desc3))
print(hasAddress(desc4))
# Out:
# None
# ['22 shedden park road, kelso']
# ['243 plaistow road, london']
# ['128 cardiff road, reading, RG1 8PQ and 8 trafford road, reading, RG1']

# %%
### ok performance; unable to extract city + postcode, or n-grams greater than 3
print(CommonRegex(desc1).street_addresses)
print(CommonRegex(desc2).street_addresses)
print(CommonRegex(desc3).street_addresses)
print(CommonRegex(desc4).street_addresses)
# Out:
# []
# ['22 shedden park road,']
# ['243 plaistow road,']
# ['128 cardiff road,', '1 8PQ and 8 trafford road,']

# %%
def hasPostcode(inputString):
    ret = re.findall(r'\b[A-Z]{1,2}[0-9][A-Z0-9]? [0-9][ABD-HJLNP-UW-Z]{2}\b', str(inputString))
    if len(ret) > 0:
        return ret
    else:
        pass

# %%
print(hasPostcode(desc1))
print(hasPostcode(desc2))
print(hasPostcode(desc3))
print(hasPostcode(desc4))
# Out:
# ['NG19 7GG']
# None
# ['E15 3EU']
# ['RG1 8PQ', 'RG1 8JP']

# %%
### hasPostcode as a somewhat indicator of the presence of an address
cedit['hasPostcode'] = cedit['particulars.description'].apply(hasPostcode)

cedit.loc[~cedit.hasPostcode.isnull()]['hasPostcode'].sample(5)
# Out:
# 23757    [BS32 9DU]
# 4508      [SN2 5DN]
# 5105      [FY5 1DB]
# 36725     [SP1 1TT]
# 22739     [S11 8QJ]
# Name: hasPostcode, dtype: object

# %% [markdown]
# ### Matching

# %%
def firstTitle(x):
    if x is not None:
        return x[0]

# %%
pedit = cedit.copy()

pedit['firstTitle'] = pedit.hasTitle.apply(firstTitle)
pedit = pedit[~pedit['firstTitle'].isnull()]

print(pedit.shape)
pedit.sample(5)
# Out:
# (11919, 19)
#                                              CompanyName CompanyNumber  \
# 35527                              CHASE (HERTS) LIMITED      12096590
# 11048  ECOLOGIA ENVIRONMENTAL SOLUTIONS HOLDINGS LIMITED      07330158
# 36464                                JENUIN LETTINGS LTD      11722317
# 20645                               MANC HOUSING LIMITED      10973059
# 9052         CRESCENT ARCH PROPERTIES MANAGEMENT LIMITED      10083850
#
#       CompanyStatus         IncorporationDate  \
# 35527        Active  2019-07-11T00:00:00.000Z
# 11048        Active  2010-07-29T00:00:00.000Z
# 36464        Active  2018-12-11T00:00:00.000Z
# 20645        Active  2017-09-20T00:00:00.000Z
# 9052         Active  2016-03-24T00:00:00.000Z
#
#                                                  SICCode       status  \
# 35527  [{"code":"41100","description":"Development of...  outstanding
# 11048  [{"code":"39000","description":"Remediation ac...  outstanding
# 36464  [{"code":"68209","description":"Other letting ...  outstanding
# 20645  [{"code":"68100","description":"Buying and sel...  outstanding
# 9052   [{"code":"68209","description":"Other letting ...  outstanding
#
#                                         persons_entitled  \
# 35527      [{"name":"Wilson Holdings (London) Limited"}]
# 11048               [{"name":"Ares Management Limited"}]
# 36464  [{"name":"Paratus Amc Trading as Foundation Ho...
# 20645     [{"name":"Manchester Housing Assets Limited"}]
# 9052                    [{"name":"Paratus Amc Limited"}]
#
#                    delivered_on charge_number classification.type  \
# 35527  2019-09-20T00:00:00.000Z             2  charge-description
# 11048  2019-10-24T00:00:00.000Z             3  charge-description
# 36464  2019-11-13T00:00:00.000Z             1  charge-description
# 20645  2019-09-24T00:00:00.000Z            33  charge-description
# 9052   2019-11-07T00:00:00.000Z             6  charge-description
#
#       classification.description   particulars.type  \
# 35527        A registered charge  brief-description
# 11048        A registered charge  brief-description
# 36464        A registered charge  brief-description
# 20645        A registered charge  brief-description
# 9052         A registered charge  brief-description
#
#                                  particulars.description  \
# 35527  All that freehold land known as bircherley gre...
# 11048  The real property known as unit 1, kingsgate b...
# 36464  37 surrey road, barking, essex, IG11 7QT (regi...
# 20645  11 ash street bury BL9 7BT registered under ti...
# 9052   The property known as 48 germander place, cont...
#
#              RegAddress.District RegAddress.PostCode  hasNum  \
# 35527            WELWYN HATFIELD             AL8 6HG    True
# 11048  CHESHIRE WEST AND CHESTER             WA6 0AR    True
# 36464       BARKING AND DAGENHAM             RM6 6XB    True
# 20645                 MANCHESTER              M3 2PJ    True
# 9052                  HILLINGDON             HA4 0AH    True
#
#                  hasTitle hasPostcode firstTitle
# 35527  [HD34749, HD12943]        None    HD34749
# 11048           [DN29382]  [EX14 1YG]    DN29382
# 36464          [NGL17516]  [IG11 7QT]   NGL17516
# 20645  [GM93326, LA29137]   [BL9 7BT]    GM93326
# 9052            [BM13881]  [MK14 7DP]    BM13881

# %%
### brief test only yielded 11 matches; may be due to lack of complete land registry records
rgg = redit[redit['Title Number'].isin(pedit.firstTitle)]

print(rgg.shape)
rgg.head(2)
# Out:
# (11, 17)
#     Title Number    Tenure                                   Property Address  \
# 232      LAN5875  Freehold  land lying to the east of Firswood Road and la...
# 349      EX61590  Freehold         2 Gilwell Park Close, Colchester (CO3 4SP)
#
#             District      County      Region Postcode  \
# 232  WEST LANCASHIRE  LANCASHIRE  NORTH WEST      NaN
# 349       COLCHESTER       ESSEX  SOUTH EAST  CO3 4SP
#
#     Multiple Address Indicator  Price Paid  \
# 232                          N         NaN
# 349                          N         NaN
#
#                               Proprietor Name (1)  \
# 232                   G PARK SKELMERSDALE LIMITED
# 349  MCCARTHY & STONE (EXTRA CARE LIVING) LIMITED
#
#     Company Registration No. (1)                Proprietorship Category (1)  \
# 232                      4926989  Limited Company or Public Limited Company
# 349                     06897363  Limited Company or Public Limited Company
#
#                             Proprietor (1) Address (1)  \
# 232       Sixth Floor, 99 Bishopsgate, London EC2M 3XD
# 349  Fourth Floor, 100 Holdenhurst Road, Bournemout...
#
#     Proprietor (1) Address (2) Proprietor (1) Address (3)  Title Len  TitleLen
# 232                        NaN                        NaN          7         7
# 349                        NaN                        NaN          7         7

# %% [markdown]
# ### Google API

# %%
def ggfind(x):

    S = requests.Session()
    SURL = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"

    SPARAMS = {
        "key": "AIzaSyAcNS706HQAxaJSraVqMjC2YS9MZblBnrY",
        "input": x,
        "inputtype": "textquery"
    }

    SREQ = S.get(url=SURL, params=SPARAMS)
    if SREQ.status_code == 200:
        SDATA = SREQ.json()
        if len(SDATA['candidates']) > 0:
#             return [i['place_id'] for i in SDATA['candidates']]
            return SDATA['candidates'][0]['place_id']

# %%
rgg['ggfind'] = rgg['Property Address'].apply(ggfind)

# %%
def ggdetail(x):

    T = requests.Session()
    TURL = "https://maps.googleapis.com/maps/api/place/details/json?"

    TPARAMS = {
        "key": "",
        "place_id": x,
        "fields": 'name,formatted_address,types,geometry'
    }

    if x[:2] == 'Ch':
        TREQ = T.get(url=TURL, params=TPARAMS)
        TDATA = TREQ.json()

        return TDATA['result']

# %%
rgg['ggdetail'] = rgg['ggfind'].apply(ggdetail)
# Out:
# C:\Users\liamk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
### only ids starting with 'ch' have details; look into this
rgg[['Property Address', 'ggfind', 'ggdetail']]
# Out:
#                                         Property Address  \
# 232    land lying to the east of Firswood Road and la...
# 349           2 Gilwell Park Close, Colchester (CO3 4SP)
# 9506   Flat 26 Monmouth Court, Bassalege Road, Newpor...
# 14971      Heath Rise, Kersfield Road, London (SW15 3HF)
# 19171            141 Morris Green Lane, Bolton (BL3 3JU)
# 30236       227 Tettenhall Road, Wolverhampton (WV6 0DE)
# 37610  land lying to the east of Firswood Road and la...
# 40632      Heath Rise, Kersfield Road, London (SW15 3HF)
# 48761  Flat 26 Monmouth Court, Bassalege Road, Newpor...
# 53684              16 Orchard Avenue, Southall (UB1 1LF)
# 54278       227 Tettenhall Road, Wolverhampton (WV6 0DE)
#
#                                                   ggfind  \
# 232                          ChIJV2GoGzoXe0gRE3KYoYL9u7k
# 349                          ChIJ4VavQWID2UcRpnYNV60Ug9Y
# 9506   EjUyNiwgTW9ubW91dGggQ291cnQsIEJhc3NhbGVnIFJkLC...
# 14971  EjBIZWF0aCBSaXNlICYgS2Vyc2ZpZWxkIFJvYWQsIExvbm...
# 19171                        ChIJW4zAz8Cne0gRCESTKeir2ns
# 30236  EigyMjcgVGV0dGVuaGFsbCBSZCwgV29sdmVyaGFtcHRvbi...
# 37610                        ChIJV2GoGzoXe0gRE3KYoYL9u7k
# 40632  EjBIZWF0aCBSaXNlICYgS2Vyc2ZpZWxkIFJvYWQsIExvbm...
# 48761  EjUyNiwgTW9ubW91dGggQ291cnQsIEJhc3NhbGVnIFJkLC...
# 53684                        ChIJG4FnP6tydkgRk2xkUptFycU
# 54278  EigyMjcgVGV0dGVuaGFsbCBSZCwgV29sdmVyaGFtcHRvbi...
#
#                                                 ggdetail
# 232    {'formatted_address': 'Firswood Rd, United Kin...
# 349    {'formatted_address': '2 Gilwell Park Cl, Colc...
# 9506                                                None
# 14971                                               None
# 19171  {'formatted_address': '141 Morris Green Ln, Bo...
# 30236                                               None
# 37610  {'formatted_address': 'Firswood Rd, United Kin...
# 40632                                               None
# 48761                                               None
# 53684  {'formatted_address': '16 Orchard Ave, Southal...
# 54278                                               None

# %%
### look into extract additional property info
print(rgg.loc[349]['ggdetail'])
print('\n')
print(rgg.loc[19171]['ggdetail'])
print('\n')
print(rgg.loc[53684]['ggdetail'])
# Out:
# {'formatted_address': '2 Gilwell Park Cl, Colchester CO3 4SP, UK', 'geometry': {'location': {'lat': 51.8770652, 'lng': 0.8614945}, 'viewport': {'northeast': {'lat': 51.8783478302915, 'lng': 0.8627517302915021}, 'southwest': {'lat': 51.8756498697085, 'lng': 0.860053769708498}}}, 'name': '2 Gilwell Park Cl', 'types': ['premise']}
#
#
# {'formatted_address': '141 Morris Green Ln, Bolton BL3 3JU, UK', 'geometry': {'location': {'lat': 53.55871339999999, 'lng': -2.450594799999999}, 'viewport': {'northeast': {'lat': 53.56003728029149, 'lng': -2.449308719708498}, 'southwest': {'lat': 53.55733931970849, 'lng': -2.452006680291502}}}, 'name': '141 Morris Green Ln', 'types': ['street_address']}
#
#
# {'formatted_address': '16 Orchard Ave, Southall UB1 1LF, UK', 'geometry': {'location': {'lat': 51.5104889, 'lng': -0.3779815}, 'viewport': {'northeast': {'lat': 51.5117743802915, 'lng': -0.3766410697084979}, 'southwest': {'lat': 51.5090764197085, 'lng': -0.379339030291502}}}, 'name': '16 Orchard Ave', 'types': ['premise']}
