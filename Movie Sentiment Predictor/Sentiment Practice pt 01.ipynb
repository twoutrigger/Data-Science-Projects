# %%
# In this notebook:
# I practice determining movie sentiment with NLP
# AKA predict if a movie comment is positve / negative
# I clean and pre-process text for ML
# I conduct TFIDF and count vectorization
# I conduct logistic regression and Naive Bayes algorithms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from nltk.corpus import stopwords
from textblob import Word

# %%
# expand column width for readability
pd.set_option('display.max_colwidth', 70)

# %%
morig = pd.read_csv('train.tsv',sep='\t')

morig.head(5)
# Out:
#    PhraseId  SentenceId  \
# 0         1           1
# 1         2           1
# 2         3           1
# 3         4           1
# 4         5           1
#
#                                                                   Phrase  \
# 0  A series of escapades demonstrating the adage that what is good fo...
# 1  A series of escapades demonstrating the adage that what is good fo...
# 2                                                               A series
# 3                                                                      A
# 4                                                                 series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
morig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
# PhraseId      156060 non-null int64
# SentenceId    156060 non-null int64
# Phrase        156060 non-null object
# Sentiment     156060 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %%
len(morig['SentenceId'].unique())
# Out:
# 8529

# %%
# bulk of rows are n-grams; remove due to later vectorization 
morig.drop_duplicates(['SentenceId'], inplace=True)

print(morig.shape)

morig.head()
# Out:
# (8529, 4)
#      PhraseId  SentenceId  \
# 0           1           1
# 63         64           2
# 81         82           3
# 116       117           4
# 156       157           5
#
#                                                                     Phrase  \
# 0    A series of escapades demonstrating the adage that what is good fo...
# 63   This quiet , introspective and entertaining independent is worth s...
# 81   Even fans of Ismail Merchant 's work , I suspect , would have a ha...
# 116  A positively thrilling combination of ethnography and all the intr...
# 156           Aggressive self-glorification and a manipulative whitewash .
#
#      Sentiment
# 0            1
# 63           4
# 81           1
# 116          3
# 156          1

# %%
morig['Sentiment'].unique()
# Out:
# array([1, 4, 3, 2, 0], dtype=int64)

# %% [markdown]
# ## Cleaning up phrase text

# %%
medit = morig.copy()

medit.head()
# Out:
#      PhraseId  SentenceId  \
# 0           1           1
# 63         64           2
# 81         82           3
# 116       117           4
# 156       157           5
#
#                                                                     Phrase  \
# 0    A series of escapades demonstrating the adage that what is good fo...
# 63   This quiet , introspective and entertaining independent is worth s...
# 81   Even fans of Ismail Merchant 's work , I suspect , would have a ha...
# 116  A positively thrilling combination of ethnography and all the intr...
# 156           Aggressive self-glorification and a manipulative whitewash .
#
#      Sentiment
# 0            1
# 63           4
# 81           1
# 116          3
# 156          1

# %%
# Need to lowercase, remove low occurance words, stop words, and perform lemmatization

# %%
# upon review, 4 looks to be best (liked), 0 looks to be worst (disliked)

medit['Sentiment'].value_counts()
# Out:
# 3    2321
# 1    2200
# 2    1655
# 4    1281
# 0    1072
# Name: Sentiment, dtype: int64

# %%
medit['Clean'] = medit['Phrase'].apply(lambda x:
                                       " ".join(x.lower()
                                       for x in str(x).split()))
medit['Clean'].head(10)
# Out:
# 0      a series of escapades demonstrating the adage that what is good fo...
# 63     this quiet , introspective and entertaining independent is worth s...
# 81     even fans of ismail merchant 's work , i suspect , would have a ha...
# 116    a positively thrilling combination of ethnography and all the intr...
# 156             aggressive self-glorification and a manipulative whitewash .
# 166    a comedy-drama of nearly epic proportions rooted in a sincere perf...
# 198                     narratively , trouble every day is a plodding mess .
# 213    the importance of being earnest , so thick with wit it plays like ...
# 247                                    but it does n't leave you with much .
# 259                                  you could hate it for the same reason .
# Name: Clean, dtype: object

# %%
medit['Clean'] = medit['Clean'].str.replace('[^\w\s]', ' ')

medit['Clean'].head(10)
# Out:
# 0      a series of escapades demonstrating the adage that what is good fo...
# 63     this quiet   introspective and entertaining independent is worth s...
# 81     even fans of ismail merchant  s work   i suspect   would have a ha...
# 116    a positively thrilling combination of ethnography and all the intr...
# 156             aggressive self glorification and a manipulative whitewash
# 166    a comedy drama of nearly epic proportions rooted in a sincere perf...
# 198                     narratively   trouble every day is a plodding mess
# 213    the importance of being earnest   so thick with wit it plays like ...
# 247                                    but it does n t leave you with much
# 259                                  you could hate it for the same reason
# Name: Clean, dtype: object

# %%
stop = stopwords.words('english')

medit['Clean'] = medit['Clean'].apply(lambda x:
                                      " ".join(x for x in str(x).split()
                                      if x not in stop))

medit['Clean'].head(10)
# Out:
# 0      series escapades demonstrating adage good goose also good gander o...
# 63                quiet introspective entertaining independent worth seeking
# 81        even fans ismail merchant work suspect would hard time sitting one
# 116    positively thrilling combination ethnography intrigue betrayal dec...
# 156                     aggressive self glorification manipulative whitewash
# 166    comedy drama nearly epic proportions rooted sincere performance ti...
# 198                              narratively trouble every day plodding mess
# 213    importance earnest thick wit plays like reading bartlett familiar ...
# 247                                                             n leave much
# 259                                                        could hate reason
# Name: Clean, dtype: object

# %%
medit['Clean'] = medit['Clean'].apply(lambda x:
                                      " ".join([Word(word).lemmatize(pos='v')
                                      for word in x.split()]))

medit['Clean'].head(10)
# Out:
# 0      series escapades demonstrate adage good goose also good gander occ...
# 63                      quiet introspective entertain independent worth seek
# 81             even fan ismail merchant work suspect would hard time sit one
# 116    positively thrill combination ethnography intrigue betrayal deceit...
# 156                     aggressive self glorification manipulative whitewash
# 166    comedy drama nearly epic proportion root sincere performance title...
# 198                                  narratively trouble every day plod mess
# 213    importance earnest thick wit play like read bartlett familiar quot...
# 247                                                             n leave much
# 259                                                        could hate reason
# Name: Clean, dtype: object

# %%
freq_phrase = pd.Series(' '.join(medit['Clean']).split()).value_counts()

freq_phrase[:20]
# Out:
# film         1294
# movie        1008
# n             687
# make          609
# one           576
# like          527
# rrb           352
# lrb           351
# story         350
# character     348
# time          330
# good          294
# work          289
# even          265
# much          264
# comedy        264
# feel          259
# see           249
# get           241
# well          236
# dtype: int64

# %%
print(f'Current phrase count is: {len(freq_phrase)}')

rare_phrase = freq_phrase[(freq_phrase == 1) | (freq_phrase == 2)]

print(f'Rare phrase count is: {len(rare_phrase)}')
# Out:
# Current phrase count is: 12486
# Rare phrase count is: 7513

# %%
medit['Clean'] = medit['Clean'].apply(lambda x:
                                      " ".join(x for x in str(x).split()
                                      if x not in rare_phrase))

medit['Clean'].head(10)
# Out:
# 0      series demonstrate adage good goose also good occasionally amuse n...
# 63                      quiet introspective entertain independent worth seek
# 81                    even fan merchant work suspect would hard time sit one
# 116    positively thrill combination intrigue betrayal murder shakespeare...
# 156                                             aggressive self manipulative
# 166    comedy drama nearly epic proportion root sincere performance title...
# 198                                  narratively trouble every day plod mess
# 213            importance earnest thick wit play like read bartlett familiar
# 247                                                             n leave much
# 259                                                        could hate reason
# Name: Clean, dtype: object

# %% [markdown]
# ## Conduct ML

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
tfv = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
                        stop_words = 'english', ngram_range=(1,1))

tfvec = tfv.fit_transform(medit['Clean'])

tfvec
# Out:
# <8529x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 40911 stored elements in Compressed Sparse Row format>

# %%
tfv.vocabulary_
# Out:
# {'series': 762,
#  'demonstrate': 210,
#  'good': 373,
#  'occasionally': 588,
#  'amuse': 32,
#  'story': 832,
#  'quiet': 679,
#  'entertain': 268,
#  'worth': 988,
#  'seek': 754,
#  'fan': 302,
#  'work': 984,
#  'hard': 394,
#  'time': 893,
#  'sit': 785,
#  'thrill': 890,
#  'intrigue': 459,
#  'murder': 570,
#  'tragedy': 900,
#  'soap': 796,
#  'opera': 595,
#  'self': 755,
#  'manipulative': 521,
#  'comedy': 146,
#  'drama': 238,
#  'nearly': 577,
#  'epic': 272,
#  'root': 730,
#  'performance': 617,
#  'title': 895,
#  'character': 119,
#  'trouble': 908,
#  'day': 194,
#  'plod': 631,
#  'mess': 543,
#  'earnest': 247,
#  'wit': 976,
#  'play': 627,
#  'like': 496,
#  'read': 687,
#  'familiar': 300,
#  'leave': 488,
#  'hate': 396,
#  'reason': 692,
#  'little': 501,
#  'recommend': 694,
#  'dog': 235,
#  'consider': 159,
#  'dialogue': 220,
#  'source': 807,
#  'high': 408,
#  'dream': 241,
#  'flick': 333,
#  'prove': 665,
#  'remain': 702,
#  'performances': 618,
#  'joy': 469,
#  'say': 740,
#  'ways': 962,
#  'chance': 117,
#  'throw': 892,
#  'sense': 757,
#  'better': 70,
#  'damn': 188,
#  'welcome': 966,
#  'movies': 567,
#  'try': 912,
#  'sweet': 865,
#  'ultimately': 920,
#  'win': 972,
#  'woman': 979,
#  'inspire': 453,
#  'gorgeous': 375,
#  'mr': 568,
#  'mood': 561,
#  'love': 508,
#  'movie': 566,
#  'despite': 217,
#  'set': 765,
#  'big': 71,
#  'screen': 747,
#  'remake': 703,
#  'wild': 969,
#  'expect': 289,
#  'best': 69,
#  'indie': 447,
#  'year': 995,
#  'far': 304,
#  'make': 518,
#  'couple': 170,
#  'study': 842,
#  'world': 985,
#  'offer': 591,
#  'case': 106,
#  'exist': 288,
#  'apart': 36,
#  'political': 637,
#  'house': 426,
#  'party': 609,
#  'watch': 958,
#  'gag': 354,
#  'mind': 548,
#  'film': 322,
#  'plot': 632,
#  'romantic': 728,
#  'start': 823,
#  'finish': 329,
#  'arrive': 41,
#  'clearly': 134,
#  'mean': 531,
#  'smile': 795,
#  'theater': 883,
#  'actors': 13,
#  'latest': 483,
#  'actor': 12,
#  'exercise': 287,
#  'structure': 840,
#  'construct': 161,
#  'narrative': 574,
#  'term': 879,
#  'actually': 15,
#  'run': 733,
#  'action': 11,
#  'indulgent': 448,
#  'script': 749,
#  'aim': 24,
#  'poetry': 633,
#  'end': 260,
#  'sound': 805,
#  'satire': 736,
#  'ice': 432,
#  'age': 22,
#  'generate': 361,
#  'feature': 313,
#  'cartoon': 105,
#  'feel': 314,
#  'pace': 602,
#  'serve': 764,
#  'cliches': 137,
#  'considerable': 160,
#  'follow': 335,
#  'success': 852,
#  'different': 222,
#  'easily': 248,
#  'force': 336,
#  'horror': 422,
#  'avoid': 52,
#  'new': 579,
#  'dark': 191,
#  'unexpected': 923,
#  'young': 999,
#  'date': 192,
#  'team': 872,
#  'power': 648,
#  'visual': 945,
#  'charm': 120,
#  'modern': 556,
#  'right': 717,
#  'home': 418,
#  'french': 345,
#  'usual': 932,
#  'bad': 55,
#  'boy': 84,
#  'role': 725,
#  'ride': 716,
#  'minute': 551,
#  'minutes': 552,
#  'decent': 202,
#  'material': 528,
#  'true': 909,
#  'crime': 178,
#  'hell': 405,
#  'storytelling': 833,
#  'lrb': 511,
#  'rrb': 732,
#  'satisfy': 737,
#  'david': 193,
#  'cinematic': 129,
#  'game': 355,
#  'sure': 858,
#  'filmmaker': 323,
#  'point': 635,
#  'subject': 848,
#  'draw': 240,
#  'engage': 263,
#  'memorable': 539,
#  'grace': 376,
#  'place': 625,
#  'war': 954,
#  'tv': 914,
#  'approach': 40,
#  'life': 494,
#  'finally': 327,
#  'come': 144,
#  'deep': 203,
#  'attempt': 46,
#  'strong': 839,
#  'let': 491,
#  'lie': 493,
#  'thank': 882,
#  'largely': 481,
#  'williams': 971,
#  'process': 660,
#  'rest': 710,
#  'waste': 957,
#  'era': 275,
#  'silly': 779,
#  'cliche': 136,
#  'refresh': 697,
#  'lead': 486,
#  'oscar': 598,
#  'live': 502,
#  'mark': 523,
#  'pop': 640,
#  'thriller': 891,
#  'camera': 99,
#  'way': 961,
#  'tension': 878,
#  'smart': 794,
#  'screenplay': 748,
#  'jam': 464,
#  'director': 226,
#  'peter': 622,
#  'particularly': 608,
#  'moment': 557,
#  'history': 413,
#  'generic': 362,
#  'lack': 477,
#  'funny': 352,
#  'scenes': 743,
#  'poorly': 639,
#  'deliver': 208,
#  'deeply': 204,
#  'think': 887,
#  'fun': 350,
#  'sex': 766,
#  'joke': 467,
#  'design': 215,
#  'provocative': 667,
#  'impossible': 444,
#  'skin': 788,
#  'man': 519,
#  'know': 476,
#  'evil': 281,
#  'drive': 242,
#  'things': 886,
#  'sci': 745,
#  'fi': 318,
#  'gay': 358,
#  'york': 998,
#  'middle': 546,
#  'relationship': 698,
#  'struggle': 841,
#  'fear': 312,
#  'wonder': 981,
#  'clever': 135,
#  'credit': 176,
#  'roll': 726,
#  'absorb': 7,
#  'documentary': 234,
#  'look': 504,
#  'line': 499,
#  'major': 517,
#  'problem': 658,
#  'center': 110,
#  'wrong': 993,
#  'attraction': 48,
#  'eventually': 280,
#  'melodramatic': 537,
#  'school': 744,
#  'heartfelt': 402,
#  'involve': 461,
#  'unsettle': 929,
#  'experience': 290,
#  'pretty': 654,
#  'execution': 286,
#  'lot': 506,
#  'ones': 593,
#  'hollywood': 417,
#  'usually': 933,
#  'understand': 921,
#  'version': 936,
#  'american': 31,
#  'quick': 677,
#  'emotional': 257,
#  'steven': 827,
#  'spielberg': 814,
#  'list': 500,
#  'inventive': 460,
#  'sexy': 768,
#  'violent': 942,
#  'tell': 877,
#  'fascinate': 306,
#  'compel': 150,
#  'write': 991,
#  'direct': 224,
#  'barely': 58,
#  'writer': 992,
#  'highly': 409,
#  'view': 938,
#  'ideas': 434,
#  'great': 378,
#  'act': 10,
#  'imax': 441,
#  'short': 775,
#  'wonderful': 982,
#  'shock': 773,
#  'examination': 283,
#  'actress': 14,
#  'non': 583,
#  'enjoy': 265,
#  'music': 572,
#  'comic': 147,
#  'pleasure': 629,
#  'disney': 231,
#  'quirky': 681,
#  'mix': 555,
#  'result': 711,
#  'number': 586,
#  'blow': 78,
#  'company': 149,
#  'contrive': 163,
#  'fail': 297,
#  'second': 753,
#  'guess': 385,
#  'original': 597,
#  'room': 729,
#  'green': 380,
#  'ask': 44,
#  'strike': 838,
#  'surprisingly': 861,
#  'solid': 799,
#  'lee': 489,
#  'john': 466,
#  'record': 695,
#  'change': 118,
#  'stop': 830,
#  'city': 130,
#  'hold': 415,
#  'recent': 693,
#  'memory': 540,
#  'thoughtful': 889,
#  'art': 42,
#  'moral': 563,
#  'probably': 657,
#  'save': 738,
#  'mystery': 573,
#  'guy': 388,
#  'return': 712,
#  'filmmaking': 325,
#  'visually': 946,
#  'weird': 965,
#  'masterpiece': 526,
#  'believe': 68,
#  'battle': 60,
#  'care': 102,
#  'appreciate': 39,
#  'theme': 884,
#  'martin': 524,
#  'viewer': 939,
#  'important': 443,
#  'simply': 782,
#  'ugly': 918,
#  'stir': 829,
#  'sequence': 761,
#  'fit': 330,
#  'entirely': 271,
#  'perfect': 615,
#  'capture': 100,
#  'years': 996,
#  'culture': 184,
#  'filmmakers': 324,
#  'want': 953,
#  'cheap': 122,
#  'succeed': 851,
#  'reveal': 713,
#  'summer': 855,
#  'tone': 898,
#  'stuff': 843,
#  'image': 438,
#  'land': 479,
#  'rivet': 721,
#  'wind': 973,
#  'achieve': 9,
#  'honest': 419,
#  'insight': 451,
#  'relationships': 699,
#  'concept': 154,
#  'beautiful': 63,
#  'star': 822,
#  'affect': 21,
#  'portrait': 642,
#  'dare': 190,
#  'powerful': 649,
#  'people': 614,
#  'eye': 294,
#  'kid': 472,
#  'choose': 127,
#  'lose': 505,
#  'cause': 109,
#  'body': 80,
#  'brilliant': 88,
#  'pay': 613,
#  'triumph': 907,
#  'carry': 104,
#  'light': 495,
#  'fiction': 319,
#  'kind': 475,
#  'production': 662,
#  'funnier': 351,
#  'release': 700,
#  'use': 931,
#  'open': 594,
#  'piece': 624,
#  'fairly': 298,
#  'fresh': 347,
#  'grow': 384,
#  'really': 691,
#  'poor': 638,
#  'edit': 251,
#  'face': 295,
#  'amaze': 28,
#  'create': 174,
#  'shots': 776,
#  'frame': 342,
#  'completely': 152,
#  'miss': 553,
#  'emotions': 259,
#  'humanity': 429,
#  'monster': 560,
#  'handle': 391,
#  'beat': 62,
#  'key': 471,
#  'moments': 558,
#  'low': 510,
#  'budget': 92,
#  'condition': 156,
#  'focus': 334,
#  'near': 576,
#  'future': 353,
#  'america': 30,
#  'mediocre': 533,
#  'drag': 237,
#  'fall': 299,
#  'cool': 166,
#  'artist': 43,
#  'tire': 894,
#  'fight': 320,
#  'form': 339,
#  'stale': 819,
#  'cut': 185,
#  'fully': 349,
#  'rare': 684,
#  'break': 87,
#  'heart': 400,
#  'single': 783,
#  'length': 490,
#  'wear': 963,
#  'universal': 928,
#  'hole': 416,
#  'head': 398,
#  'post': 646,
#  'old': 592,
#  'perfectly': 616,
#  'cross': 180,
#  'death': 199,
#  'journey': 468,
#  'turn': 913,
#  'bizarre': 73,
#  'sort': 803,
#  'adaptation': 16,
#  'emotionally': 258,
#  'audience': 49,
#  'demand': 209,
#  'sexual': 767,
#  'violence': 941,
#  'favor': 311,
#  'parent': 607,
#  'hero': 407,
#  'cinema': 128,
#  'sad': 734,
#  'sharp': 772,
#  'dull': 245,
#  'bite': 72,
#  'heavy': 404,
#  'hand': 390,
#  'message': 544,
#  'taste': 871,
#  'thing': 885,
#  'utterly': 934,
#  'children': 125,
#  'beautifully': 64,
#  'craft': 172,
#  'audiences': 50,
#  'quality': 674,
#  'magic': 513,
#  'punch': 671,
#  'unfortunately': 925,
#  'hit': 414,
#  'base': 59,
#  'melodrama': 536,
#  'style': 846,
#  'need': 578,
#  'teen': 875,
#  'gross': 383,
#  'deal': 198,
#  'uneven': 922,
#  'pointless': 636,
#  'real': 688,
#  'wo': 978,
#  'disappoint': 229,
#  'dramatic': 239,
#  'happen': 392,
#  'manage': 520,
#  'intend': 457,
#  'course': 171,
#  'humorous': 431,
#  'depress': 211,
#  'saw': 739,
#  'convince': 165,
#  'humor': 430,
#  'fast': 308,
#  'hardly': 395,
#  'sophisticate': 802,
#  'picture': 623,
#  'catch': 108,
#  'slight': 790,
#  'chase': 121,
#  'unfold': 924,
#  'tale': 866,
#  'allow': 27,
#  'bond': 81,
#  'bring': 89,
#  'rich': 715,
#  'instead': 454,
#  'routine': 731,
#  'nice': 580,
#  'complex': 153,
#  'predictable': 650,
#  'sequel': 760,
#  'document': 233,
#  'terrific': 881,
#  'learn': 487,
#  'career': 103,
#  'meet': 535,
#  'girl': 370,
#  'typical': 917,
#  'stories': 831,
#  'episode': 273,
#  'huge': 427,
#  'bland': 76,
#  'money': 559,
#  'idea': 433,
#  'boys': 85,
#  'difficult': 223,
#  'imagine': 440,
#  'confuse': 158,
#  'possibly': 645,
#  'road': 722,
#  '2002': 2,
#  'killer': 474,
#  'business': 96,
#  'mindless': 549,
#  'yes': 997,
#  'value': 935,
#  'standard': 821,
#  'rip': 719,
#  'gift': 369,
#  'essentially': 278,
#  'provide': 666,
#  'laugh': 484,
#  'comedies': 145,
#  'happy': 393,
#  'strangely': 837,
#  'core': 168,
#  'robert': 723,
#  'night': 581,
#  'chill': 126,
#  'greatest': 379,
#  'creepy': 177,
#  'human': 428,
#  'remember': 706,
#  'enjoyable': 266,
#  'black': 74,
#  'white': 967,
#  'manner': 522,
#  'add': 17,
#  'suspense': 863,
#  'animation': 34,
#  'overall': 599,
#  'rise': 720,
#  'rock': 724,
#  'atmosphere': 45,
#  'genuinely': 366,
#  'nature': 575,
#  'worthy': 990,
#  'present': 652,
#  'witty': 977,
#  'surprise': 860,
#  'disguise': 230,
#  'bear': 61,
#  'father': 310,
#  'fact': 296,
#  'touch': 899,
#  'special': 811,
#  'walk': 952,
#  'mainstream': 515,
#  'rarely': 685,
#  '10': 0,
#  'franchise': 343,
#  'long': 503,
#  'past': 612,
#  'debut': 200,
#  'small': 793,
#  'away': 53,
#  'solondz': 800,
#  'social': 797,
#  'cast': 107,
#  'flat': 331,
#  'mildly': 547,
#  'book': 82,
#  'direction': 225,
#  'reach': 686,
#  'dumb': 246,
#  'send': 756,
#  'blade': 75,
#  'ii': 436,
#  'cold': 139,
#  'blood': 77,
#  'match': 527,
#  'elements': 255,
#  'entertainment': 269,
#  'sustain': 864,
#  'maintain': 516,
#  'doubt': 236,
#  'question': 676,
#  'country': 169,
#  'spark': 809,
#  'appear': 38,
#  'ca': 98,
#  'shallow': 770,
#  'spirit': 816,
#  'rely': 701,
#  'begin': 66,
#  'conventional': 164,
#  'meditation': 534,
#  'buy': 97,
#  'popcorn': 641,
#  'late': 482,
#  'college': 140,
#  'effort': 254,
#  'emerge': 256,
#  'allen': 26,
#  'deserve': 214,
#  'successful': 853,
#  'intimate': 458,
#  'pass': 610,
#  'soul': 804,
#  'search': 750,
#  'price': 656,
#  'matter': 529,
#  'class': 131,
#  'creative': 175,
#  'seat': 752,
#  'help': 406,
#  'half': 389,
#  'somewhat': 801,
#  'flaw': 332,
#  'treatment': 903,
#  'guilty': 386,
#  'painfully': 605,
#  'surface': 859,
#  'explore': 291,
#  'red': 696,
#  'hot': 423,
#  'directors': 228,
#  'quite': 682,
#  'stand': 820,
#  'passion': 611,
#  'likely': 497,
#  'certainly': 114,
#  'raise': 683,
#  'sandler': 735,
#  'level': 492,
#  'goofy': 374,
#  'affair': 20,
#  'watchable': 959,
#  'especially': 277,
#  'obvious': 587,
#  'dead': 197,
#  'simplistic': 781,
#  'heaven': 403,
#  'hours': 425,
#  'target': 870,
#  'motion': 565,
#  'hip': 411,
#  'hop': 420,
#  'twist': 915,
#  'seriously': 763,
#  'stupid': 845,
#  'ghost': 368,
#  'situation': 786,
#  'master': 525,
#  'depth': 212,
#  'hour': 424,
#  'ambitious': 29,
#  'pull': 670,
#  'effect': 252,
#  'fantasy': 303,
#  'trick': 905,
#  'combine': 143,
#  'drug': 243,
#  'possible': 644,
#  'ill': 437,
#  'project': 663,
#  'talented': 868,
#  'excellent': 284,
#  'figure': 321,
#  'brain': 86,
#  'female': 316,
#  'beauty': 65,
#  'talent': 867,
#  'water': 960,
#  'michael': 545,
#  'maybe': 530,
#  'formula': 340,
#  'general': 359,
#  'tear': 873,
#  'able': 5,
#  'final': 326,
#  'unique': 927,
#  'hearted': 401,
#  'ensemble': 267,
#  'virtually': 943,
#  'soderbergh': 798,
#  'fat': 309,
#  'hilarious': 410,
#  'suffer': 854,
#  'minor': 550,
#  'grip': 382,
#  'family': 301,
#  'television': 876,
#  'today': 896,
#  'believable': 67,
#  'personal': 621,
#  'endear': 261,
#  'extremely': 293,
#  'truth': 911,
#  'child': 124,
#  'animate': 33,
#  'scene': 742,
#  'crimes': 179,
#  'plenty': 630,
#  'shake': 769,
#  'remarkable': 704,
#  '20': 1,
#  'ago': 23,
#  'damage': 187,
#  'poignant': 634,
#  'straight': 834,
#  'shoot': 774,
#  'accomplish': 8,
#  'speak': 810,
#  'definitely': 205,
#  'air': 25,
#  'cop': 167,
#  'community': 148,
#  'cute': 186,
#  'delight': 206,
#  'edge': 250,
#  'issue': 462,
#  'women': 980,
#  'hope': 421,
#  'scary': 741,
#  'intelligent': 456,
#  'dry': 244,
#  'stay': 824,
#  'provoke': 668,
#  'contemporary': 162,
#  'directorial': 227,
#  'stylish': 847,
#  'step': 826,
#  'absolutely': 6,
#  'energy': 262,
#  'subtle': 850,
#  'quietly': 680,
#  'strange': 836,
#  'gangster': 357,
#  'promise': 664,
#  'truly': 910,
#  'badly': 56,
#  'escape': 276,
#  'simple': 780,
#  'lovely': 509,
#  'notice': 584,
#  'layer': 485,
#  'cultural': 183,
#  'worse': 986,
#  'events': 279,
#  'previous': 655,
#  'crowd': 181,
#  'engross': 264,
#  'historical': 412,
#  'plain': 626,
#  'forget': 337,
#  'stunt': 844,
#  'answer': 35,
#  'days': 195,
#  '90': 3,
#  'desire': 216,
#  'tedious': 874,
#  'blue': 79,
#  'crush': 182,
#  'conflict': 157,
#  'novel': 585,
#  'queen': 675,
#  'meander': 532,
#  'color': 141,
#  'chan': 116,
#  'bore': 83,
#  'decades': 201,
#  'hear': 399,
#  'voice': 949,
#  'felt': 315,
#  'sign': 778,
#  'appeal': 37,
#  'build': 93,
#  'fine': 328,
#  'type': 916,
#  'machine': 512,
#  'overcome': 600,
#  'adventure': 19,
#  'overly': 601,
#  'spectacle': 812,
#  'gentle': 364,
#  'easy': 249,
#  'reality': 689,
#  'limit': 498,
#  'pleasant': 628,
#  'grind': 381,
#  'purpose': 673,
#  'worst': 987,
#  'period': 619,
#  'pack': 603,
#  'strain': 835,
#  'impact': 442,
#  'space': 808,
#  'warm': 955,
#  'sentimental': 759,
#  'challenge': 115,
#  'intelligence': 455,
#  'close': 138,
#  'average': 51,
#  'impressive': 445,
#  'romance': 727,
#  'tragic': 901,
#  'potential': 647,
#  'premise': 651,
#  'girls': 371,
#  'classic': 132,
#  'mother': 564,
#  'gun': 387,
#  'warmth': 956,
#  'vivid': 948,
#  'oddly': 590,
#  'terrible': 880,
#  'painful': 604,
#  'spend': 813,
#  'century': 112,
#  'dazzle': 196,
#  'produce': 661,
#  'paint': 606,
#  'vision': 944,
#  'haunt': 397,
#  'word': 983,
#  'wed': 964,
#  'support': 856,
#  'suppose': 857,
#  'british': 90,
#  'men': 541,
#  'talk': 869,
#  'inside': 450,
#  'job': 465,
#  'substance': 849,
#  'treat': 902,
#  'ring': 718,
#  'jackson': 463,
#  'kill': 473,
#  'person': 620,
#  'dance': 189,
#  'fashion': 307,
#  'genre': 363,
#  'concern': 155,
#  'balance': 57,
#  'ultimate': 919,
#  'require': 709,
#  'george': 367,
#  'score': 746,
#  'gang': 356,
#  'ms': 569,
#  'genuine': 365,
#  'urban': 930,
#  'exactly': 282,
#  'burn': 95,
#  'insightful': 452,
#  'sport': 817,
#  'identity': 435,
#  'large': 480,
#  'effective': 253,
#  'develop': 218,
#  'free': 344,
#  'pretentious': 653,
#  'tom': 897,
#  'trip': 906,
#  'share': 771,
#  'loud': 507,
#  'spy': 818,
#  'surround': 862,
#  'slightly': 791,
#  'remarkably': 705,
#  'fare': 305,
#  'season': 751,
#  'soundtrack': 806,
#  'chemistry': 123,
#  'extreme': 292,
#  'wait': 951,
#  'car': 101,
#  'die': 221,
#  'central': 111,
#  'devoid': 219,
#  'remind': 707,
#  'video': 937,
#  'ya': 994,
#  'slap': 789,
#  'bullock': 94,
#  'grant': 377,
#  'slow': 792,
#  'sensitive': 758,
#  'realize': 690,
#  'industry': 449,
#  'equally': 274,
#  'unfunny': 926,
#  'include': 446,
#  'viewers': 940,
#  'lame': 478,
#  'thoroughly': 888,
#  'situations': 787,
#  'reward': 714,
#  'merely': 542,
#  'quickly': 678,
#  'formulaic': 341,
#  'niro': 582,
#  'imagination': 439,
#  'wise': 974,
#  'visuals': 947,
#  'spin': 815,
#  'friendship': 348,
#  'festival': 317,
#  'justice': 470,
#  'wish': 975,
#  'pure': 672,
#  'odd': 589,
#  'ability': 4,
#  'divert': 232,
#  'certain': 113,
#  'wife': 968,
#  'murphy': 571,
#  'mistake': 554,
#  'clear': 133,
#  'sight': 777,
#  'tribute': 904,
#  'forgettable': 338,
#  'frequently': 346,
#  'stick': 828,
#  'awful': 54,
#  'psychological': 669,
#  'adults': 18,
#  'excite': 285,
#  'main': 514,
#  'brown': 91,
#  'entire': 270,
#  'represent': 708,
#  'worthwhile': 989,
#  'portray': 643,
#  'attention': 47,
#  'opportunity': 596,
#  'moore': 562,
#  'problems': 659,
#  'complete': 151,
#  'wildly': 970,
#  'generally': 360,
#  'delightful': 207,
#  'steal': 825,
#  'crazy': 173,
#  'vs': 950,
#  'glimpse': 372,
#  'colorful': 142,
#  'derivative': 213,
#  'sink': 784,
#  'members': 538}

# %%
print(dict(zip(tfv.get_feature_names(), tfv.idf_)))
# Out:
# {'10': 7.106905661319284, '20': 7.343294439383515, '2002': 7.16097288258956, '90': 6.793248102464243, 'ability': 7.106905661319284, 'able': 6.832468815617524, 'absolutely': 7.16097288258956, 'absorb': 7.006822202762302, 'accomplish': 7.343294439383515, 'achieve': 7.106905661319284, 'act': 5.047398334540266, 'action': 5.07461089806515, 'actor': 6.524984115869564, 'actors': 5.733856526949414, 'actress': 7.055612366931734, 'actually': 6.0259929497505755, 'adaptation': 6.9158504245565755, 'add': 6.495996578996311, 'adults': 6.873290810137779, 'adventure': 6.387782994356078, 'affair': 7.278755918245944, 'affect': 7.16097288258956, 'age': 5.656895485813286, 'ago': 7.106905661319284, 'aim': 7.006822202762302, 'air': 6.719140130310521, 'allen': 6.960302187127409, 'allow': 6.585608737685998, 'amaze': 7.278755918245944, 'ambitious': 6.873290810137779, 'america': 6.9158504245565755, 'american': 5.681896788018704, 'amuse': 6.0259929497505755, 'animate': 6.873290810137779, 'animation': 6.617357436000579, 'answer': 7.106905661319284, 'apart': 7.055612366931734, 'appeal': 6.139321635057579, 'appear': 6.755507774481396, 'appreciate': 7.343294439383515, 'approach': 6.684048810499251, 'arrive': 7.218131296429509, 'art': 5.990901629939305, 'artist': 6.9158504245565755, 'ask': 6.832468815617524, 'atmosphere': 7.218131296429509, 'attempt': 6.159524342375098, 'attention': 6.832468815617524, 'attraction': 7.343294439383515, 'audience': 5.359996758256581, 'audiences': 6.5548370790192445, 'average': 7.16097288258956, 'avoid': 7.218131296429509, 'away': 6.008293372651175, 'awful': 6.873290810137779, 'bad': 4.969940275501262, 'badly': 7.218131296429509, 'balance': 7.006822202762302, 'barely': 6.873290810137779, 'base': 6.719140130310521, 'battle': 7.106905661319284, 'bear': 6.719140130310521, 'beat': 6.9158504245565755, 'beautiful': 6.313675022202356, 'beautifully': 6.244682150715405, 'beauty': 6.9158504245565755, 'begin': 6.4137584807593395, 'believable': 7.278755918245944, 'believe': 6.244682150715405, 'best': 4.963748305253341, 'better': 5.176147317284573, 'big': 5.2638528977036785, 'bite': 5.6086933839954085, 'bizarre': 7.278755918245944, 'black': 6.313675022202356, 'blade': 7.16097288258956, 'bland': 6.617357436000579, 'blood': 6.873290810137779, 'blow': 7.278755918245944, 'blue': 7.006822202762302, 'body': 6.9158504245565755, 'bond': 7.006822202762302, 'book': 6.244682150715405, 'bore': 5.990901629939305, 'boy': 6.5548370790192445, 'boys': 7.055612366931734, 'brain': 7.055612366931734, 'break': 6.267155006567464, 'brilliant': 6.684048810499251, 'bring': 5.892461557126053, 'british': 7.218131296429509, 'brown': 7.218131296429509, 'budget': 6.755507774481396, 'build': 6.719140130310521, 'bullock': 7.218131296429509, 'burn': 7.006822202762302, 'business': 7.16097288258956, 'buy': 7.343294439383515, 'ca': 5.6086933839954085, 'camera': 6.3624651863717885, 'capture': 6.337772573781417, 'car': 7.343294439383515, 'care': 5.908209914094192, 'career': 6.832468815617524, 'carry': 6.650147258823569, 'cartoon': 6.873290810137779, 'case': 6.5548370790192445, 'cast': 5.176147317284573, 'catch': 6.684048810499251, 'cause': 7.343294439383515, 'center': 7.218131296429509, 'central': 7.278755918245944, 'century': 7.16097288258956, 'certain': 6.9158504245565755, 'certainly': 6.201197038775666, 'challenge': 7.006822202762302, 'chan': 7.106905661319284, 'chance': 7.16097288258956, 'change': 6.313675022202356, 'character': 4.207800223454365, 'charm': 5.518745147332469, 'chase': 7.16097288258956, 'cheap': 6.9158504245565755, 'chemistry': 7.106905661319284, 'child': 7.343294439383515, 'children': 6.180143629577834, 'chill': 6.832468815617524, 'choose': 7.16097288258956, 'cinema': 5.831836935309618, 'cinematic': 6.100100921904297, 'city': 6.650147258823569, 'class': 6.719140130310521, 'classic': 6.467825702029615, 'clear': 6.793248102464243, 'clearly': 7.16097288258956, 'clever': 6.119519007761399, 'cliche': 7.343294439383515, 'cliches': 6.719140130310521, 'close': 6.44042 ...

# %%
cv = CountVectorizer()

cvec = cv.fit_transform(medit['Clean'])

cvec
# Out:
# <8529x4947 sparse matrix of type '<class 'numpy.int64'>'
# 	with 71005 stored elements in Compressed Sparse Row format>

# %%
cv.vocabulary_
# Out:
# {'series': 3864,
#  'demonstrate': 1140,
#  'adage': 83,
#  'good': 1895,
#  'goose': 1902,
#  'also': 165,
#  'occasionally': 3020,
#  'amuse': 191,
#  'none': 2973,
#  'amount': 190,
#  'much': 2865,
#  'story': 4196,
#  'quiet': 3461,
#  'introspective': 2324,
#  'entertain': 1458,
#  'independent': 2221,
#  'worth': 4904,
#  'seek': 3833,
#  'even': 1502,
#  'fan': 1621,
#  'merchant': 2749,
#  'work': 4898,
#  'suspect': 4312,
#  'would': 4907,
#  'hard': 1987,
#  'time': 4467,
#  'sit': 3977,
#  'one': 3043,
#  'positively': 3303,
#  'thrill': 4454,
#  'combination': 837,
#  'intrigue': 2321,
#  'betrayal': 421,
#  'murder': 2874,
#  'shakespearean': 3892,
#  'tragedy': 4519,
#  'juicy': 2405,
#  'soap': 4046,
#  'opera': 3051,
#  'aggressive': 130,
#  'self': 3841,
#  'manipulative': 2664,
#  'comedy': 843,
#  'drama': 1299,
#  'nearly': 2922,
#  'epic': 1471,
#  'proportion': 3406,
#  'root': 3706,
#  'sincere': 3967,
#  'performance': 3189,
#  'title': 4477,
#  'character': 684,
#  'crisis': 1010,
#  'narratively': 2906,
#  'trouble': 4563,
#  'every': 1509,
#  'day': 1080,
#  'plod': 3260,
#  'mess': 2755,
#  'importance': 2187,
#  'earnest': 1351,
#  'thick': 4434,
#  'wit': 4875,
#  'play': 3246,
#  'like': 2551,
#  'read': 3510,
#  'bartlett': 374,
#  'familiar': 1616,
#  'leave': 2515,
#  'could': 966,
#  'hate': 2002,
#  'reason': 3521,
#  'little': 2574,
#  'recommend': 3531,
#  'snow': 4044,
#  'dog': 1270,
#  'unless': 4658,
#  'consider': 915,
#  'cliched': 787,
#  'dialogue': 1192,
#  'perverse': 3206,
#  'escapism': 1487,
#  'source': 4092,
#  'high': 2050,
#  'hilarity': 2056,
#  'kung': 2461,
#  'pow': 3321,
#  'oedekerk': 3029,
#  'realization': 3517,
#  'childhood': 723,
#  'dream': 1307,
#  'martial': 2685,
#  'arts': 266,
#  'flick': 1719,
#  'prove': 3413,
#  'sometimes': 4068,
#  'youth': 4937,
#  'remain': 3579,
#  'performances': 3190,
#  'absolute': 41,
#  'joy': 2399,
#  'something': 4067,
#  'serious': 3865,
#  'say': 3767,
#  'ways': 4803,
#  'extravagant': 1588,
#  'chance': 678,
#  'perspective': 3203,
#  'throw': 4458,
#  'us': 4687,
#  'path': 3155,
#  'sense': 3846,
#  'still': 4180,
#  'moonlight': 2835,
#  'mile': 2779,
#  'better': 423,
#  'damn': 1056,
#  'welcome': 4822,
#  'relief': 3575,
#  'movies': 2860,
#  'try': 4571,
#  'mythic': 2893,
#  'sweet': 4323,
#  'modest': 2819,
#  'ultimately': 4593,
#  'win': 4862,
#  'charmer': 697,
#  'woman': 4887,
#  'inspire': 2283,
#  'less': 2526,
#  'gorgeous': 1904,
#  'companion': 861,
#  'mr': 2861,
#  'mood': 2832,
#  'love': 2606,
#  'hong': 2089,
#  'kong': 2453,
#  'movie': 2856,
#  'despite': 1171,
#  'set': 3872,
#  'inept': 2234,
#  'big': 430,
#  'screen': 3805,
#  'remake': 3580,
#  'wild': 4853,
#  'west': 4828,
#  'everything': 1513,
#  'expect': 1558,
#  'nothing': 2985,
#  'best': 419,
#  'indie': 2226,
#  'year': 4925,
#  'far': 1626,
#  'make': 2650,
#  'oddest': 3024,
#  'couple': 972,
#  'become': 392,
#  'study': 4232,
#  'gamble': 1827,
#  'publish': 3426,
#  'world': 4900,
#  'offer': 3033,
#  'case': 646,
#  'exist': 1551,
#  'apart': 231,
#  'political': 3282,
#  'go': 1888,
#  'house': 2112,
#  'party': 3143,
#  'watch': 4795,
#  'host': 2107,
#  'gag': 1824,
#  'occur': 3021,
#  'windtalkers': 4865,
#  'indication': 2224,
#  'mind': 2785,
#  'film': 1677,
#  'plot': 3261,
#  'romantic': 3702,
#  'start': 4157,
#  'finish': 1691,
#  'arrive': 255,
#  'impeccable': 2181,
#  'pedigree': 3175,
#  'almost': 160,
#  'complications': 878,
#  'clearly': 781,
#  'mean': 2716,
#  'preach': 3332,
#  'convert': 947,
#  'opportunities': 3054,
#  'occasional': 3019,
#  'smile': 4029,
#  'chuckle': 750,
#  'give': 1875,
#  'theater': 4422,
#  'beyond': 426,
#  'wilde': 4854,
#  'actors': 76,
#  'latest': 2491,
#  'vapid': 4707,
#  'actor': 75,
#  'exercise': 1547,
#  'appropriate': 242,
#  'structure': 4225,
#  'schnitzler': 3789,
#  'vaudeville': 4713,
#  'show': 3928,
#  'well': 4823,
#  'construct': 923,
#  'narrative': 2905,
#  'term': 4402,
#  'inoffensive': 2265,
#  'actually': 80,
#  'rather': 3498,
#  'run': 3723,
#  'mill': 2781,
#  'action': 74,
#  'hamper': 1972,
#  'indulgent': 2232,
#  'script': 3812,
#  'aim': 137,
#  'poetry': 3271,
#  'end': 1428,
#  'sound': 4089,
#  'satire': 3758,
#  'ice': 2143,
#  'age': 127,
#  'first': 1694,
#  'computer': 884,
#  'generate': 1846,
#  'feature': 1650,
#  'cartoon': 641,
#  'feel': 1653,
#  'pace': 3103,
#  'early': 1349,
#  'makers': 2652,
#  'serve': 3868,
#  'cliches': 788,
#  'considerable': 916,
#  'dash': 1071,
#  'cattaneo': 655,
#  'follow': 1738,
#  'success': 4260,
#  'full': 1810,
#  'monty': 2831,
#  'different': 1204,
#  'easily': 1357,
#  'force': 1747,
#  'whatever': 4832,
#  'terror': 4409,
#  'heroes': 2041,
#  'horror': 2103,
#  'avoid': 326,
#  'interest': 2311,
#  'ramble': 3483,
#  'incoherence': 2209,
#  'new': 2946,
#  'phrase': 3218,
#  'fatal': 1638,
#  'judge': 2404,
#  'soon': 4076,
#  'dark': 1065,
#  'gritty': 1942,
#  'take': 4340,
#  'totally': 4502,
#  'unexpected': 4631,
#  'directions': 1220,
#  'keep': 2425,
#  'young': 4935,
#  'date': 1073,
#  'team': 4371,
#  'power': 3322,
#  'visual': 4756,
#  'charm': 696,
#  'five': 1699,
#  'writers': 4916,
#  'slip': 4014,
#  'modern': 2817,
#  'vincent': 4745,
#  'right': 3667,
#  'home': 2084,
#  'french': 1787,
#  'usual': 4690,
#  'bad': 345,
#  'boy': 511,
#  'role': 3694,
#  'primary': 3366,
#  'goal': 1889,
#  'frighten': 1799,
#  'disturb': 1260,
#  'spectacularly': 4111,
#  'shiver': 3914,
#  'induce': 2229,
#  'nerve': 2939,
#  'rattle': 3500,
#  'ride': 3662,
#  '100': 1,
#  'minute': 2794,
#  'minutes': 2795,
#  'decent': 1098,
#  'material': 2701,
#  'sensational': 3845,
#  'true': 4565,
#  'crime': 1005,
#  'hell': 2034,
#  'might': 2774,
#  'storytelling': 4199,
#  'lrb': 2612,
#  'though': 4446,
#  'horrify': 2102,
#  'rrb': 3716,
#  'satisfy': 3760,
#  'david': 1076,
#  'mamet': 2658,
#  'airless': 141,
#  'cinematic': 756,
#  'game': 1828,
#  'sure': 4297,
#  'filmmaker': 1678,
#  'honestly': 2087,
#  'see': 3832,
#  'point': 3274,
#  'jones': 2395,
#  'tackle': 4337,
#  'subject': 4245,
#  'draw': 1304,
#  'engage': 1438,
#  'pepper': 3182,
#  'page': 3109,
#  'memorable': 2740,
#  'bloody': 470,
#  'sunday': 4284,
#  'grace': 1910,
#  'call': 602,
#  'place': 3241,
#  'blame': 454,
#  'war': 4785,
#  'ever': 1507,
#  'clunky': 808,
#  'tv': 4581,
#  'approach': 241,
#  'detail': 1179,
#  'life': 2541,
#  'celebrate': 659,
#  'irish': 2335,
#  'playwright': 3250,
#  'finally': 1683,
#  'come': 839,
#  'miramax': 2798,
#  'deep': 1107,
#  'attempt': 298,
#  'wake': 4772,
#  'reno': 3592,
#  'strong': 4221,
#  'let': 2530,
#  'sleep': 4004,
#  'lie': 2540,
#  'thank': 4420,
#  'largely': 2485,
#  'williams': 4858,
#  'developments': 1187,
#  'process': 3380,
#  '60': 27,
#  'rest': 3629,
#  'waste': 4794,
#  'across': 72,
#  'era': 1481,
#  'silly': 3955,
#  'perhaps': 3192,
#  'cliche': 786,
#  'refresh': 3551,
#  'lead': 2506,
#  'oscar': 3071,
#  'size': 3983,
#  'live': 2575,
#  'mark': 2678,
#  'pellington': 3177,
#  'pop': 3291,
#  'thriller': 4455,
#  'spooky': 4130,
#  'subtly': 4256,
#  'myth': 2892,
#  'claude': 774,
#  'chabrol': 671,
#  'camera': 607,
#  'way': 4801,
#  'gently': 1857,
#  'sway': 4318,
#  'back': 340,
#  'forth': 1761,
#  'tension': 4399,
#  'beneath': 414,
#  'otherwise': 3073,
#  'tender': 4395,
#  'movements': 2855,
#  'transform': 4525,
#  'shakespeare': 3891,
#  'deepest': 1109,
#  'tragedies': 4518,
#  'smart': 4025,
#  'screenplay': 3806,
#  'jam': 2361,
#  'eric': 1482,
#  'director': 1222,
#  'peter': 3207,
#  'pat': 3153,
#  'teeth': 4386,
#  'hurt': 2135,
#  'particularly': 3140,
#  'moment': 2822,
#  'history': 2064,
#  'tie': 4465,
#  'bind': 437,
#  'generic': 1849,
#  'villains': 4743,
#  'lack': 2468,
#  'funny': 1818,
#  'accent': 53,
#  'scenes': 3779,
#  'poorly': 3290,
#  'deliver': 1133,
#  'deeply': 1110,
#  'think': 4438,
#  'gratuitous': 1924,
#  'impress': 2191,
#  'upon': 4681,
#  'fun': 1813,
#  'downright': 1288,
#  'transparent': 4530,
#  'endless': 1431,
#  'assault': 279,
#  'ham': 1969,
#  'fisted': 1697,
#  'sex': 3880,
#  'joke': 2390,
#  'reek': 3545,
#  'rewrite': 3652,
#  'design': 1165,
#  'pg': 3208,
#  '13': 5,
#  'rat': 3496,
#  'provocative': 3415,
#  'impossible': 2189,
#  'get': 1865,
#  'skin': 3993,
#  'man': 2659,
#  'know': 2450,
#  'evil': 1517,
#  'monstrous': 2830,
#  'lunatic': 2621,
#  'drive': 1313,
#  'many': 2671,
#  'things': 4437,
#  'midnight': 2772,
#  'sci': 3794,
#  'fi': 1668,
#  'gay': 1838,
#  'two': 4586,
#  'york': 4933,
#  'middle': 2771,
#  'stumble': 4234,
#  'relationship': 3564,
#  'struggle': 4226,
#  'furiously': 1819,
#  'fear': 1644,
#  'foibles': 1735,
#  'ambition': 181,
#  'willingness': 4859,
#  'scherfig': 3784,
#  'wonder': 4889,
#  'clever': 783,
#  'credit': 1000,
#  'roll': 3696,
#  'absorb': 43,
#  'documentary': 1269,
#  'hack': 1959,
#  'vignettes': 4740,
#  'look': 2594,
#  'common': 857,
#  'line': 2560,
#  'major': 2649,
#  'problem': 3376,
#  'center': 664,
#  'wrong': 4917,
#  'swimfan': 4328,
#  'attraction': 302,
#  'eventually': 1506,
#  'melodramatic': 2735,
#  'school': 3790,
#  'swim': 4327,
#  'pool': 3288,
#  'substitute': 4251,
#  'heartfelt': 2023,
#  'involve': 2333,
#  'unsettle': 4671,
#  'experience': 1562,
#  'predecessors': 3338,
#  'proud': 3412,
#  'pretty': 3358,
#  'execution': 1546,
#  'lot': 2602,
#  'richer': 3658,
#  'ones': 3044,
#  'hollywood': 2079,
#  'screenwriters': 3808,
#  'usually': 4691,
#  'noyce': 2992,
#  'christopher': 748,
#  'understand': 4623,
#  'delicate': 1126,
#  'greene': 1933,
#  'prose': 3407,
#  'version': 4723,
#  'american': 184,
#  'pianist': 3220,
#  'quick': 3458,
#  'emotional': 1413,
#  'connections': 908,
#  'steven': 4175,
#  'spielberg': 4118,
#  'list': 2566,
#  'inventive': 2328,
#  'sexy': 3884,
#  'violent': 4748,
#  'tell': 4389,
#  'fascinate': 1632,
#  'compel': 866,
#  'write': 4914,
#  'direct': 1218,
#  'barely': 368,
#  'mary': 2690,
#  'co': 810,
#  'writer': 4915,
#  'ed': 1366,
#  'highly': 2054,
#  'view': 4737,
#  'courage': 973,
#  'ideas': 2150,
#  'technical': 4375,
#  'great': 1927,
#  'act': 73,
#  'imax': 2170,
#  'short': 3922,
#  'wonderful': 4890,
#  'slice': 4007,
#  'yet': 4931,
#  'instantly': 2286,
#  'recognizable': 3529,
#  'amid': 187,
#  'shock': 3915,
#  'curiosity': 1037,
#  'factor': 1601,
#  'corny': 960,
#  'examination': 1525,
#  'actress': 77,
#  'find': 1685,
#  'lazy': 2504,
#  'distract': 1259,
#  'another': 217,
#  'guide': 1952,
#  'non': 2972,
#  'enjoy': 1445,
#  'music': 2881,
#  'comic': 846,
#  'antic': 221,
#  'pleasure': 3256,
#  'disney': 1246,
#  'bottom': 505,
#  'barrel': 371,
#  'burr': 583,
#  'steer': 4168,
#  'emphasize': 1419,
#  'quirky': 3465,
#  'mix': 2810,
#  'result': 3632,
#  'scarcely': 3771,
#  'mention': 2748,
#  'report': 3603,
#  'number': 2998,
#  'blow': 471,
#  'empty': 1424,
#  'theatres': 4425,
#  'company': 862,
#  'surreal': 4304,
#  'resonant': 3619,
#  'emotion': 1412,
#  'analyze': 195,
#  'crass': 987,
#  'contrive': 939,
#  'sequels': 3861,
#  'fail': 1604,
#  'second': 3824,
#  'guess': 1951,
#  'affection': 117,
#  'original': 3069,
#  'card': 629,
#  'exalt': 1524,
#  'room': 3705,
#  'improvement': 2198,
#  'neither': 2935,
#  'tsai': 4572,
#  'may': 2709,
#  'often': 3035,
#  'green': 1932,
#  'equivalent': 1479,
#  'ready': 3511,
#  'ask': 272,
#  'strike': 4216,
#  'surprisingly': 4303,
#  'solid': 4059,
#  'achievement': 68,
#  'malcolm': 2655,
#  'lee': 2518,
#  'john': 2388,
#  'record': 3533,
#  'tenacious': 4393,
#  'humane': 2120,
#  'victim': 4731,
#  'change': 679,
#  'lanes': 2480,
#  'shyamalan': 3940,
#  'stop': 4193,
#  'please': 3253,
#  'macabre': 2632,
#  'stylize': 4242,
#  'swedish': 4321,
#  'city': 763,
#  'religious': 3576,
#  'virtues': 4750,
#  'hold': 2074,
#  'society': 4051,
#  'recent': 3527,
#  'memory': 2742,
#  'thoughtful': 4447,
#  'art': 256,
#  'cost': 963,
#  'moral': 2837,
#  'compromise': 882,
#  'consistently': 918,
#  'unimaginative': 4646,
#  'probably': 3374,
#  'save': 3764,
#  'aid': 136,
#  'mystery': 2891,
#  'science': 3795,
#  '3000': 21,
#  'guy': 1957,
#  'tian': 4462,
#  'return': 3639,
#  'filmmaking': 1680,
#  'visually': 4757,
#  'masterful': 2697,
#  'parody': 3136,
#  'weird': 4819,
#  'masterpiece': 2699,
#  'sketch': 3986,
#  'believe': 406,
#  'put': 3443,
#  'battle': 381,
#  'will': 4857,
#  'care': 630,
#  'appreciate': 239,
#  'side': 3943,
#  'theme': 4429,
#  'lawrence': 2500,
#  'knock': 2449,
#  'postcard': 3311,
#  'glorify': 1881,
#  'martin': 2686,
#  'whole': 4844,
#  'viewer': 4738,
#  'important': 2188,
#  'simply': 3963,
#  'ugly': 4591,
#  'product': 3385,
#  'whenever': 4834,
#  'threaten': 4452,
#  'bogged': 482,
#  'stir': 4186,
#  'sequence': 3862,
#  'leap': 2511,
#  'rouse': 3711,
#  'swing': 4329,
#  'seem': 3834,
#  'attract': 301,
#  'fit': 1698,
#  'entirely': 1466,
#  'perfect': 3186,
#  'capture': 627,
#  'innocence': 2259,
#  'demons': 1139,
#  'within': 4878,
#  '300': 20,
#  'years': 4927,
#  'russian': 3727,
#  'culture': 1034,
#  'sumptuous': 4281,
#  'stream': 4209,
#  'consciousness': 912,
#  'filmmakers': 1679,
#  'want': 4784,
#  'else': 1404,
#  'cheap': 701,
#  'succeed': 4259,
#  'polanski': 3278,
#  'element': 1396,
#  'alone': 161,
#  'abandon': 37,
#  'reveal': 3641,
#  'spiritual': 4123,
#  'survival': 4308,
#  'spider': 4117,
#  'summer': 4279,
#  'blockbuster': 467,
#  'endure': 1434,
#  'last': 2488,
#  'hopefully': 2096,
#  'tone': 4489,
#  'stuff': 4233,
#  'vulgar': 4769,
#  'image': 2164,
#  'land': 2476,
#  'potent': 3316,
#  'rivet': 3680,
#  'unlikely': 4661,
#  'sarah': 3754,
#  'wind': 4863,
#  'revelatory': 3645,
#  'achieve': 67,
#  'honest': 2086,
#  'insight': 2274,
#  'relationships': 3565,
#  'concept': 889,
#  'candy': 616,
#  'coat': 813,
#  'storylines': 4198,
#  'precious': 3334,
#  'circumstances': 761,
#  'beautiful': 389,
#  'star': 4155,
#  'mostly': 2845,
#  'martha': 2684,
#  'unsurprising': 4672,
#  'diversion': 1262,
#  'affect': 116,
#  'portrait': 3298,
#  'screw': 3810,
#  'dare': 1064,
#  'powerful': 3323,
#  'people': 3180,
#  'eye': 1594,
#  'kid': 2431,
#  'choose': 739,
#  'champion': 676,
#  'lose': 2599,
#  'cause': 656,
#  'observe': 3011,
#  'refreshingly': 3552,
#  'natural': 2915,
#  'clothe': 801,
#  'body': 479,
#  'beach': 383,
#  'adrenaline': 103,
#  'jolt': 2392,
#  'sudden': 4266,
#  'lunch': 2622,
#  'rush': 3725,
#  'brilliant': 541,
#  'expense': 1561,
#  'pay': 3166,
#  'triumph': 4557,
#  'carry': 639,
#  'effortlessly': 1381,
#  'darkness': 1068,
#  'light': 2546,
#  'everyone': 1512,
#  'coast': 812,
#  'hook': 2091,
#  'delicious': 1128,
#  'lurid': 2623,
#  'fiction': 1669,
#  'kind': 2439,
#  'production': 3386,
#  'funnier': 1816,
#  'release': 3569,
#  'outtakes': 3085,
#  'use': 4688,
#  'dvd': 1342,
#  'daughter': 1074,
#  'efforts': 1382,
#  'toward': 4507,
#  'open': 3049,
#  'wound': 4908,
#  'weirdly': 4820,
#  'unpredictable': 4667,
#  'piece': 3227,
#  'intoxicate': 2319,
#  'although': 170,
#  'fairly': 1607,
#  'fresh': 1790,
#  'grow': 1947,
#  'catholic': 654,
#  'really': 3519,
#  'anything': 228,
#  'comprehension': 881,
#  'arty': 268,
#  'poor': 3289,
#  'edit': 1370,
#  'ultra': 4594,
#  'cheesy': 710,
#  'highlight': 2053,
#  'radical': 3474,
#  'cho': 733,
#  'face': 1598,
#  'amaze': 177,
#  'slapstick': 4001,
#  'create': 991,
#  'mug': 2867,
#  'shots': 3925,
#  'frame': 1771,
#  'completely': 873,
#  'miss': 2807,
#  'emotions': 1415,
#  'initial': 2256,
#  'strangeness': 4206,
#  'rote': 3707,
#  'sentimentality': 3856,
#  'tenderness': 4396,
#  'brush': 565,
#  'humanity': 2121,
#  'psycho': 3420,
#  'without': 4879,
#  'hartley': 1997,
#  'monster': 2828,
#  'handle': 1975,
#  'beg': 395,
#  'feet': 1654,
#  'scruffy': 3814,
#  'madonna': 2638,
#  'since': 3966,
#  'ferrara': 1661,
#  'beat': 388,
#  'pulp': 3429,
#  'dangerous': 1061,
#  'clumsy': 807,
#  'key': 2429,
#  'moments': 2823,
#  'splash': 4125,
#  'eight': 1385,
#  'legged': 2522,
#  'freak': 1780,
#  'partly': 3141,
#  'homage': 2083,
#  'low': 2609,
#  'budget': 571,
#  'thrillers': 4456,
#  '1950s': 8,
#  '60s': 28,
#  'sophomoric': 4079,
#  'romp': 3703,
#  'condition': 895,
#  'focus': 1734,
#  'bigger': 432,
#  'near': 2921,
#  'future': 1822,
#  'america': 183,
#  'discern': 1232,
#  'producers': 3384,
#  'mediocre': 2725,
#  'drag': 1294,
#  'speed': 4113,
#  'explosions': 1575,
#  'fall': 1612,
#  'cool': 953,
#  'never': 2944,
#  'aware': 330,
#  'artist': 262,
#  'tire': 4473,
#  'fight': 1674,
#  'weight': 4817,
#  'shoulder': 3926,
#  'form': 1756,
#  'stale': 4151,
#  'uninspired': 4647,
#  'cut': 1046,
#  'song': 4072,
#  'fully': 1811,
#  'example': 1527,
#  'lush': 2625,
#  'envelop': 1468,
#  'rare': 3493,
#  'capability': 620,
#  'break': 525,
#  'heart': 2018,
#  'single': 3971,
#  'stroke': 4220,
#  'eerily': 1376,
#  'accurate': 63,
#  'depiction': 1152,
#  'depression': 1156,
#  'length': 2525,
#  'wear': 4806,
#  'gem': 1842,
#  'universal': 4654,
#  'lecture': 2517,
#  'scratch': 3803,
#  'hole': 2075,
#  'head': 2011,
#  'post': 3310,
#  'camp': 609,
#  'old': 3038,
#  'perfectly': 3187,
#  'creature': 996,
#  'cross': 1017,
#  'bunch': 579,
#  'exotic': 1556,
#  'creatures': 997,
#  'around': 253,
#  'scream': 3804,
#  'death': 1090,
#  'bet': 420,
#  'convolute': 952,
#  'journey': 2398,
#  'turn': 4579,
#  'devolve': 1190,
#  'bizarre': 450,
#  'sort': 4083,
#  'adaptation': 87,
#  'harrow': 1994,
#  'brilliantly': 542,
#  'kim': 2438,
#  'emotionally': 1414,
#  'least': 2513,
#  'adolescent': 101,
#  'audience': 307,
#  'demand': 1135,
#  'sexual': 3881,
#  'violence': 4747,
#  'employ': 1421,
#  'owe': 3101,
#  'favor': 1642,
#  'famous': 1620,
#  'parent': 3133,
#  'scatter': 3775,
#  'whose': 4847,
#  'hero': 2040,
#  'cinema': 755,
#  'paradiso': 3129,
#  'improve': 2197,
#  'campanella': 611,
#  'sad': 3732,
#  'hopeful': 2095,
#  'amiable': 186,
#  'unfocused': 4635,
#  'loosely': 2596,
#  'connect': 906,
#  'string': 4217,
#  'sharp': 3902,
#  'dull': 1331,
#  'wallace': 4775,
#  'bite': 445,
#  'heavy': 2029,
#  'hand': 1973,
#  'message': 2756,
#  'flair': 1705,
#  'poetic': 3270,
#  'taste': 4356,
#  'thing': 4436,
#  'chimps': 730,
#  'spiral': 4121,
#  'downward': 1290,
#  'utterly': 4694,
#  'incompetent': 2211,
#  'conclusion': 892,
#  'children': 726,
#  'amateurish': 176,
#  'incomprehensible': 2212,
#  'beautifully': 390,
#  'craft': 981,
#  'audiences': 308,
#  'hungry': 2131,
#  'quality': 3450,
#  'yarn': 4923,
#  'awkwardly': 337,
#  'magic': 2641,
#  'realism': 3513,
#  'punch': 3434,
#  'unfortunately': 4640,
#  'hit': 2066,
#  'three': 4453,
#  'smoke': 4032,
#  'signal': 3947,
#  'imbue': 2171,
#  'familial': 1615,
#  'move': 2853,
#  'stoop': 4192,
#  'base': 375,
#  'melodrama': 2734,
#  'evoke': 1519,
#  ...}

# %%
(tx_train, tx_test, ty_train, ty_test) = train_test_split(tfvec,medit['Sentiment'], test_size=0.25)

print(f'tx_train: {tx_train.shape}\nty_train: {ty_train.shape}')
print(f'tx_test: {tx_test.shape}\nty_test: {ty_test.shape}')
# Out:
# tx_train: (6396, 1000)
# ty_train: (6396,)
# tx_test: (2133, 1000)
# ty_test: (2133,)

# %%
(cx_train, cx_test, cy_train, cy_test) = train_test_split(cvec,medit['Sentiment'], test_size=0.25)

print(f'cx_train: {cx_train.shape}\ncy_train: {cy_train.shape}')
print(f'cx_test: {cx_test.shape}\ncy_test: {cy_test.shape}')
# Out:
# cx_train: (6396, 4947)
# cy_train: (6396,)
# cx_test: (2133, 4947)
# cy_test: (2133,)

# %%
for c in [0.01, 0.05, 0.25, 0.5, 1]:
    
    tlreg = LogisticRegression(C=c)
    tlreg.fit(tx_train, ty_train)
    print (f'TFIDF Vectorization Accuracy: C={c} {accuracy_score(ty_test, tlreg.predict(tx_test))}')
# Out:
# TFIDF Vectorization Accuracy: C=0.01 0.32583216127519926
# TFIDF Vectorization Accuracy: C=0.05 0.3530239099859353
# TFIDF Vectorization Accuracy: C=0.25 0.3670886075949367
# TFIDF Vectorization Accuracy: C=0.5 0.36802625410220347
# TFIDF Vectorization Accuracy: C=1 0.3628691983122363

# %%
for c in [0.01, 0.05, 0.25, 0.5, 1]:
    
    clreg = LogisticRegression(C=c)
    clreg.fit(cx_train, cy_train)
    print (f'Count Vectorization Accuracy: C={c} {accuracy_score(cy_test, clreg.predict(cx_test))}')
# Out:
# Count Vectorization Accuracy: C=0.01 0.356305672761369
# Count Vectorization Accuracy: C=0.05 0.39709329582747305
# Count Vectorization Accuracy: C=0.25 0.39052977027660574
# Count Vectorization Accuracy: C=0.5 0.38068448195030474
# Count Vectorization Accuracy: C=1 0.3755274261603376

# %%
# Naive Bayes model

mnb = MultinomialNB()
mnbmodel = mnb.fit(tx_train, ty_train)

print (f'Naive Bayes Accuracy: {accuracy_score(ty_test, mnbmodel.predict(tx_test))}')
# Out:
# Naive Bayes Accuracy: 0.3647444913267698

# %%
test_phrase = ['it was a pretty good movie', 'the flick is mediocre', 'Jake was terrible in the second act',
               'Life Itself is full of cliche, but fits a certain artsy crowd', 'will watch again!',
               'Entertaining movie, shallow story, good action, I would rate 4 out of 5', 'damn good movie!']

test_c_vec = cv.transform(test_phrase)
test_t_vec = tfv.transform(test_phrase)

# %%
test_mnb_pred = mnbmodel.predict(test_t_vec)

for name, pred in zip(test_phrase, test_mnb_pred):
    print(f'Naive Bayes prediction: {pred} Phrase: {name}')
# Out:
# Naive Bayes prediction: 3 Phrase: it was a pretty good movie
# Naive Bayes prediction: 1 Phrase: the flick is mediocre
# Naive Bayes prediction: 0 Phrase: Jake was terrible in the second act
# Naive Bayes prediction: 2 Phrase: Life Itself is full of cliche, but fits a certain artsy crowd
# Naive Bayes prediction: 3 Phrase: will watch again!
# Naive Bayes prediction: 1 Phrase: Entertaining movie, shallow story, good action, I would rate 4 out of 5
# Naive Bayes prediction: 3 Phrase: damn good movie!

# %%
logreg = LogisticRegression(C=1)
logmodel = logreg.fit(tx_train, ty_train)

test_log_pred = logmodel.predict(test_t_vec)

for name, pred in zip(test_phrase, test_log_pred):
    print(f'Logistic regression prediction: {pred} Phrase: {name}')
# Out:
# Logistic regression prediction: 3 Phrase: it was a pretty good movie
# Logistic regression prediction: 1 Phrase: the flick is mediocre
# Logistic regression prediction: 0 Phrase: Jake was terrible in the second act
# Logistic regression prediction: 3 Phrase: Life Itself is full of cliche, but fits a certain artsy crowd
# Logistic regression prediction: 0 Phrase: will watch again!
# Logistic regression prediction: 1 Phrase: Entertaining movie, shallow story, good action, I would rate 4 out of 5
# Logistic regression prediction: 3 Phrase: damn good movie!

# %%
# Closing thoughts for pt 1:
# we see pretty good predictions with TFIDF vectorization + ML
# however overall acuuracy can be imporved
# this will likely require better preprocessing, or ensamble algorithms
