# %%
## veteran dataset for survival analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
orig = pd.read_csv('../Datasets/veteran.csv')
print(orig.shape)
orig.head(2)
# Out:
# (137, 8)
#    time  status  karno  diagtime  age  prior  trt  celltype
# 0    72       1     60         7   69      0    1         1
# 1   411       1     70         5   64     10    1         1

# %%
orig.status.value_counts()
# Out:
# 1    128
# 0      9
# Name: status, dtype: int64

# %%
sns.pairplot(orig, hue='status')

# %%
orig.describe()
# Out:
#              time      status       karno    diagtime         age       prior  \
# count  137.000000  137.000000  137.000000  137.000000  137.000000  137.000000
# mean   121.627737    0.934307   58.569343    8.773723   58.306569    2.919708
# std    157.816722    0.248655   20.039592   10.612141   10.541628    4.563375
# min      1.000000    0.000000   10.000000    1.000000   34.000000    0.000000
# 25%     25.000000    1.000000   40.000000    3.000000   51.000000    0.000000
# 50%     80.000000    1.000000   60.000000    5.000000   62.000000    0.000000
# 75%    144.000000    1.000000   75.000000   11.000000   66.000000   10.000000
# max    999.000000    1.000000   99.000000   87.000000   81.000000   10.000000
#
#               trt    celltype
# count  137.000000  137.000000
# mean     1.496350    2.335766
# std      0.501821    1.066036
# min      1.000000    1.000000
# 25%      1.000000    1.000000
# 50%      1.000000    2.000000
# 75%      2.000000    3.000000
# ...

# %%
dh = orig.copy()

# %%
dh.time.nlargest(10)
# Out:
# 69     999
# 74     991
# 77     587
# 57     553
# 82     467
# 1      411
# 43     392
# 78     389
# 16     384
# 135    378
# Name: time, dtype: int64

# %%
dh.trt.value_counts()
# Out:
# 1    69
# 2    68
# Name: trt, dtype: int64

# %%
sns.boxplot(data=dh, x='trt', y='age')

# %%
dh.prior.value_counts()
# Out:
# 0     97
# 10    40
# Name: prior, dtype: int64

# %%
sns.histplot(data=dh, x='age', bins=25)

# %%
sns.violinplot(data=dh, x='status', y='time')

# %%
sns.violinplot(data=dh, x='status', y='age')

# %%
sns.pairplot(data=dh[['time', 'karno', 'diagtime', 'age']])

# %%
dh.celltype.value_counts()
# Out:
# 2    48
# 1    35
# 3    27
# 4    27
# Name: celltype, dtype: int64

# %%
dh.columns
# Out:
# Index(['time', 'status', 'karno', 'diagtime', 'age', 'prior', 'trt',
#        'celltype'],
#       dtype='object')

# %%
## Next steps:
## filter out outliers using standard deviation for age
## filter out outliers using standard deviation for time
## understand relevance for karno, diagtime, prior, trt and celltype
## attempt survival analysis
